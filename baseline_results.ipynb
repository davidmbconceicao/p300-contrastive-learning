# %%
import os
import process_results
from importlib import reload

scripts_folder = os.path.join(os.getcwd(), 'scripts')

# %%
reload(process_results)
files = [
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/EEGNet_results/EEGNet_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/EEGNet_Original_results/EEGNet_Original_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/EEGInception_results/EEGInception_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/EEGInception_Original_results/EEGInception_Original_50Folfd_evaluation_results.txt'),
    # os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/Conformer_results/Conformer_50Folfd_evaluation_results.txt'
]

model_names = ['EEGNet Modified', 'EEGNet Original', 'EEG-Inception Modified', 'EEG-Inception Original']

process_results.plot_baseline_comparisons(files, model_names)
# Out:
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4872.0, p_value = 0.7548063563663994)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5422.5, p_value = 0.30150746782788995)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4486.0, p_value = 0.20878407787747622)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4304.5, p_value = 0.08869898573079957)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4135.5, p_value = 0.03437457393783475)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4707.5, p_value = 0.4745167872772321)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5495.0, p_value = 0.22555966558473084)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5827.5, p_value = 0.0429696853267824)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4965.0, p_value = 0.9325916435085585)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4503.5, p_value = 0.2242317909856265)
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4811.0, p_value = 0.6440409750717063)
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4778.0, p_value = 0.5865591383377826)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4544.5, p_value = 0.26467851176716384)
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4464.5, p_value = 0.18884280183006386)
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4274.0, p_value = 0.07489560466057749)
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4658.5, p_value = 0.4036918811660847)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5035.0, p_value = 0.9326964662824951)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4372.0, p_value = 0.12461034436689841)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4076.0, p_value = 0.023806439306444223)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 3910.5, p_value = 0.007680270911053855)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4253.0, p_value = 0.06760447305485537)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4033.0, p_value = 0.01802801888084815)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4181.0, p_value = 0.045247700173558864)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4236.0, p_value = 0.06141456712107515)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 3817.0, p_value = 0.003784603244468195)
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 3899.0, p_value = 0.007025724186898635)
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4293.0, p_value = 0.08305161860239513)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 3742.0, p_value = 0.002068532520231765)
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 3958.0, p_value = 0.010712327275036435)
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4251.0, p_value = 0.06632163194998221)

# %% [markdown]
# ## Baseline Comparison on BCI Comp Dataset

# %%
files = [
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/EEGNet_results/EEGNet_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/EEGInception_results/EEGInception_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/Conformer_results/Conformer_50Folfd_evaluation_results.txt'),
]

model_names = ['EEGNet', 'EEG-Inception', 'Conformer']

plot_baseline(files, model_names)
# Out:
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between EEG-Inception and Conformer: p-value = 1.1561547993493218e-06
# Wilcoxon test between EEGNet and Conformer: p-value = 1.2492074464319978e-05
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 0.3419995576934111
#
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between EEGNet and Conformer: p-value = 3.38916735193084e-14
# Wilcoxon test between EEG-Inception and Conformer: p-value = 1.4624216688848689e-07
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 3.808645212942071e-06
#
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between EEGNet and Conformer: p-value = 2.1976010198583166e-13
# Wilcoxon test between EEG-Inception and Conformer: p-value = 6.229636697018064e-07
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 7.38883639662201e-05
#
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between EEGNet and Conformer: p-value = 8.661624027378349e-16
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 1.4875854101789068e-07
# Wilcoxon test between EEG-Inception and Conformer: p-value = 1.1508791815627887e-07
#
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between EEGNet and Conformer: p-value = 5.750326388164656e-14
# Wilcoxon test between EEG-Inception and Conformer: p-value = 2.405587843573898e-07
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 1.783947304933932e-06
#
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between EEGNet and Conformer: p-value = 3.911205731433047e-09
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 6.67289567574573e-07
# Wilcoxon test between EEG-Inception and Conformer: p-value = 0.0531545964180016
#
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between EEGNet and Conformer: p-value = 1.3088786050522977e-10
# Wilcoxon test between EEG-Inception and Conformer: p-value = 0.00024903378300168385
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 0.00016788106988652432
#
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between EEGNet and Conformer: p-value = 9.228250379057595e-14
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 1.3083151460988158e-06
# Wilcoxon test between EEG-Inception and Conformer: p-value = 4.741376736903495e-06
#
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between EEGNet and Conformer: p-value = 2.633916990957682e-15
# Wilcoxon test between EEG-Inception and Conformer: p-value = 2.6757672305109855e-09
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 4.785526377703197e-06
#
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between EEGNet and Conformer: p-value = 3.262401288681333e-13
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 1.2376388409651212e-07
# Wilcoxon test between EEG-Inception and Conformer: p-value = 4.253254653167305e-05
#
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between EEGNet and Conformer: p-value = 5.720550703267734e-17
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 3.7367481212837846e-10
# Wilcoxon test between EEG-Inception and Conformer: p-value = 9.719888696118386e-05
#
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between EEGNet and Conformer: p-value = 8.894104805099932e-15
# Wilcoxon test between EEG-Inception and Conformer: p-value = 5.67589467809661e-09
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 2.386347382196079e-07
#
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between EEGNet and Conformer: p-value = 2.3339405155947973e-15
# Wilcoxon test between EEG-Inception and Conformer: p-value = 5.4411903868965865e-09
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 5.622445714117923e-08
#
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between EEGNet and Conformer: p-value = 6.379270594757365e-11
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 6.9789081897971835e-06
# Wilcoxon test between EEG-Inception and Conformer: p-value = 5.572287124571034e-06
#
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between EEGNet and Conformer: p-value = 2.2952541610284405e-09
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 0.00022861919706793752
# Wilcoxon test between EEG-Inception and Conformer: p-value = 0.00015618237273021365
# EEGNet:
# Mean = [20.49 31.64 42.16 51.69 56.55 64.25 68.89 72.55 75.3  77.89 80.58 84.04
#  85.02 85.82 87.62]
#
# [4.695803121574699, 6.833942580450299, 8.324702220781841, 9.318124564418133, 9.016921046814174, 9.51901155840438, 9.348020628258915, 9.05934346487932, 8.681785729806155, 8.358305198627038, 8.117913105731947, 8.05329891031096, 7.635339920624805, 7.2482617481828715, 7.0495300056786565]
# EEG-Inception:
# Mean = [20.9  29.68 40.53 49.4  54.66 61.94 67.3  70.19 73.73 75.96 78.03 82.25
#  82.94 84.37 86.27]
#
# [4.866459281734426, 6.140321074881124, 7.810730460602753, 8.6675871820416, 8.541152224372027, 8.977172994807368, 9.002852008080824, 8.586310245979742, 8.387856769012599, 8.019933271403794, 7.6954738811490975, 7.765126231990988, 7.32039026731763, 7.039813215757476, 6.862148120875438]
# Conformer:
# Mean = [18.93 27.42 38.17 46.7  52.33 61.09 65.79 68.25 71.12 74.38 76.49 80.2
#  80.84 82.79 84.87]
#
# [4.064484056281553, 5.370128649802123, 7.085832792591691, 7.921990615175844, 7.967828326703041, 8.781078235915372, 8.680406451695909, 8.206431887613023, 7.9105289387773015, 7.74854012682865, 7.446642690023258, 7.443502414912051, 7.011438549436182, 6.8175971973759495, 6.671965525702106]

# %% [markdown]
# ## Baseline Comparison on ALS Dataset

# %%
reload(process_results)
files = [
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/EEGNet_results_ALS/EEGNet_50Folfd_evaluation_results_ALS.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/EEGInception_results_ALS/EEGInception_50Folfd_evaluation_results_ALS.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/Conformer_results_ALS/Conformer_50Folfd_evaluation_results_ALS.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SimCLR_results/EEGNet_1CLS_50Folfd_evaluation_results.txt')
]

model_names = ['EEGNet', 'EEG-Inception', 'Conformer', 'EEGNet SimCLR']

process_results.plot_baseline(files, model_names, dataset='ALS')
# Out:
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between EEGNet and EEGNet SimCLR: p-value = 1.6283628165924253e-22
# Wilcoxon test between EEG-Inception and EEGNet SimCLR: p-value = 3.3418141001547317e-19
# Wilcoxon test between EEG-Inception and Conformer: p-value = 8.72251778245689e-08
# Wilcoxon test between Conformer and EEGNet SimCLR: p-value = 1.5503488289076415e-07
# Wilcoxon test between EEGNet and Conformer: p-value = 0.0002568102057783982
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 0.11832887976810479
#
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between EEGNet and EEGNet SimCLR: p-value = 1.1664568435169125e-59
# Wilcoxon test between EEG-Inception and EEGNet SimCLR: p-value = 1.0809838308615467e-53
# Wilcoxon test between Conformer and EEGNet SimCLR: p-value = 4.836393417231672e-22
# Wilcoxon test between EEGNet and Conformer: p-value = 1.9842516335086805e-15
# Wilcoxon test between EEG-Inception and Conformer: p-value = 3.7492042030641994e-14
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 0.21109415972148804
#
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between EEGNet and EEGNet SimCLR: p-value = 2.1203555257012134e-52
# Wilcoxon test between EEG-Inception and EEGNet SimCLR: p-value = 3.127877364115663e-34
# Wilcoxon test between EEGNet and Conformer: p-value = 4.1659342091694066e-32
# Wilcoxon test between EEG-Inception and Conformer: p-value = 1.0533049405097515e-21
# Wilcoxon test between Conformer and EEGNet SimCLR: p-value = 8.711096230957309e-11
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 1.6293783039684215e-05
#
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between EEGNet and EEGNet SimCLR: p-value = 6.781246422308509e-37
# Wilcoxon test between EEGNet and Conformer: p-value = 1.3719152945497298e-34
# Wilcoxon test between EEG-Inception and Conformer: p-value = 2.8386289416450847e-27
# Wilcoxon test between EEG-Inception and EEGNet SimCLR: p-value = 8.816950710048731e-25
# Wilcoxon test between Conformer and EEGNet SimCLR: p-value = 7.76847296539783e-06
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 0.00013935100035793437
#
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between EEGNet and EEGNet SimCLR: p-value = 1.1903726961154292e-53
# Wilcoxon test between EEGNet and Conformer: p-value = 2.497353366306791e-48
# Wilcoxon test between EEG-Inception and EEGNet SimCLR: p-value = 2.703474200648092e-39
# Wilcoxon test between EEG-Inception and Conformer: p-value = 1.3044585409261297e-35
# Wilcoxon test between Conformer and EEGNet SimCLR: p-value = 2.318134951918976e-12
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 1.0972122745191949e-06
#
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between EEGNet and EEGNet SimCLR: p-value = 3.3344982465660227e-44
# Wilcoxon test between EEGNet and Conformer: p-value = 1.5430104749378627e-39
# Wilcoxon test between EEG-Inception and Conformer: p-value = 3.868924118734562e-31
# Wilcoxon test between EEG-Inception and EEGNet SimCLR: p-value = 1.3435808087015865e-30
# Wilcoxon test between Conformer and EEGNet SimCLR: p-value = 2.5912184748184124e-09
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 0.0027310161642941557
#
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between EEGNet and Conformer: p-value = 5.141930860603079e-41
# Wilcoxon test between EEGNet and EEGNet SimCLR: p-value = 6.957924329138569e-39
# Wilcoxon test between EEG-Inception and Conformer: p-value = 3.805827188349925e-32
# Wilcoxon test between EEG-Inception and EEGNet SimCLR: p-value = 6.731224835404485e-26
# Wilcoxon test between Conformer and EEGNet SimCLR: p-value = 4.4247285843993435e-06
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 0.0007510534882217311
#
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between EEGNet and EEGNet SimCLR: p-value = 1.2516382919025002e-46
# Wilcoxon test between EEGNet and Conformer: p-value = 1.9253410887326465e-44
# Wilcoxon test between EEG-Inception and Conformer: p-value = 7.068675476463774e-35
# Wilcoxon test between EEG-Inception and EEGNet SimCLR: p-value = 3.964329560397889e-34
# Wilcoxon test between Conformer and EEGNet SimCLR: p-value = 4.053445207042597e-08
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 0.0069351287506458905
#
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between EEGNet and EEGNet SimCLR: p-value = 3.542880580997199e-54
# Wilcoxon test between EEGNet and Conformer: p-value = 4.530229215424077e-43
# Wilcoxon test between EEG-Inception and EEGNet SimCLR: p-value = 8.549444578726598e-43
# Wilcoxon test between EEG-Inception and Conformer: p-value = 3.1913449517254296e-36
# Wilcoxon test between Conformer and EEGNet SimCLR: p-value = 5.227698572420603e-13
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 0.04325010572973858
#
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between EEGNet and EEGNet SimCLR: p-value = 8.460707415545717e-53
# Wilcoxon test between EEG-Inception and EEGNet SimCLR: p-value = 2.26294910993207e-36
# Wilcoxon test between EEGNet and Conformer: p-value = 7.031787079901601e-36
# Wilcoxon test between EEG-Inception and Conformer: p-value = 4.689204048449389e-30
# Wilcoxon test between Conformer and EEGNet SimCLR: p-value = 7.075413531801404e-10
# Wilcoxon test between EEGNet and EEG-Inception: p-value = 0.015328374517879875
# EEGNet:
# Mean = [20.96025 38.00875 48.69025 57.052   63.92    68.44225 72.503   75.499
#  79.3235  80.94225]
#
# [4.0912394415329505, 7.285514441613083, 8.027466459623119, 8.198887180001542, 8.146060946637334, 7.761165463340179, 7.432391059700297, 7.041342867454141, 6.862607428636769, 6.442562001474329]
# EEG-Inception:
# Mean = [21.274   37.4445  46.7815  55.18075 62.05025 67.0705  71.22125 74.6045
#  78.84525 79.8785 ]
#
# [4.201724119394393, 7.110016411540287, 7.529679066765294, 7.774250385037132, 7.768075099905137, 7.512214521288344, 7.220260664604726, 6.905278301644073, 6.794049491984102, 6.301818220930755]
# Conformer:
# Mean = [18.9295  33.09475 41.24125 48.97175 54.70125 59.8415  63.87025 67.37075
#  71.67225 73.65825]
#
# [3.399221350756424, 5.804286172475335, 6.147508754402701, 6.425572690715095, 6.352493342322802, 6.25818049327427, 6.0586542819649445, 5.853248865716766, 5.810921171674962, 5.514318148350206]
# EEGNet SimCLR:
# Mean = [17.042   26.123   37.0965  45.5725  49.2585  53.52175 59.545   61.9395
#  65.25075 66.22925]
#
# [2.7939243987869102, 3.896243252648851, 5.175737187576027, 5.726267843904983, 5.373972035593696, 5.237577517856333, 5.416145181031576, 5.115228779718092, 4.9947029203748885, 4.6432977780789075]

# %% [markdown]
# ### Baseline Vs Best performing models on BCI Comp Dataset Evaluation

# %%
files = [
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/EEGNet_results/EEGNet_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SimCLR_results/EEGNet_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/EEGInception_results/EEGInception_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/Supervised_results/EEGInception_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/Conformer_results/Conformer_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SimCLR_results/Conformer_1CLS_50Folfd_evaluation_results.txt')  
]

model_names = ['EEGNet', 'EEGNet SimCLR', 'EEGInception', 'EEGInception Supervised', 'Conformer', 'Conformer SimCLR']

process_results.plot_baseline_and_studied(files, model_names)
# Out:
# EEGNet:
# Mean = [20.49 31.64 42.16 51.69 56.55 64.25 68.89 72.55 75.3  77.89 80.58 84.04
#  85.02 85.82 87.62]
# ITR = [4.695803121574699, 6.833942580450299, 8.324702220781841, 9.318124564418133, 9.016921046814174, 9.51901155840438, 9.348020628258915, 9.05934346487932, 8.681785729806155, 8.358305198627038, 8.117913105731947, 8.05329891031096, 7.635339920624805, 7.2482617481828715, 7.0495300056786565]
#
# EEGNet SimCLR:
# Mean = [19.91 29.27 44.03 48.53 56.01 62.17 67.99 72.1  74.74 77.66 79.92 84.31
#  84.55 86.75 85.8 ]
# ITR = [4.457710359442028, 5.998205388981012, 8.927547696214946, 8.424807117889308, 8.880003243103614, 9.030535328895859, 9.151923268109103, 8.968198072400691, 8.5763412102086, 8.317572226032645, 8.007280685773427, 8.097398504774636, 7.563348034172002, 7.384401638113438, 6.797848326914674]
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5067.5, p_value = 0.8695720127748714)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 6231.0, p_value = 0.0025746870558532218)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4308.5, p_value = 0.09065014444958529)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 6460.0, p_value = 0.00035024207258586637)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5475.0, p_value = 0.2445489087378353)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 6461.5, p_value = 0.00034021040706359314)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5632.5, p_value = 0.12106353572994455)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5094.0, p_value = 0.8188390720793965)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5360.5, p_value = 0.3773824058024039)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4939.0, p_value = 0.8820439002125453)
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5652.0, p_value = 0.10893883685562068)
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4989.5, p_value = 0.9804081466047797)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5317.0, p_value = 0.4362185480496521)
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 3974.0, p_value = 0.011671761767930564)
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 6006.5, p_value = 0.01332721496289975)
#
# EEGInception:
# Mean = [20.9  29.68 40.53 49.4  54.66 61.94 67.3  70.19 73.73 75.96 78.03 82.25
#  82.94 84.37 86.27]
# ITR = [4.866459281734426, 6.140321074881124, 7.810730460602753, 8.6675871820416, 8.541152224372027, 8.977172994807368, 9.002852008080824, 8.586310245979742, 8.387856769012599, 8.019933271403794, 7.6954738811490975, 7.765126231990988, 7.32039026731763, 7.039813215757476, 6.862148120875438]
#
# EEGInception Supervised:
# Mean = [ 6.3   7.94 15.3  15.61 20.4  26.14 28.   30.36 33.79 36.06 39.37 41.94
#  43.79 47.45 49.75]
# ITR = [0.32017007960796207, 0.42846751727271637, 1.4190349248694514, 1.1913342675534808, 1.6484280138782832, 2.195701642832996, 2.167640995401647, 2.214233822762956, 2.3860703469181073, 2.4180799991106845, 2.5614723821154244, 2.622432890436749, 2.613243725347599, 2.7768598403685636, 2.8102558573952092]
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 9719.0, p_value = 6.50428018396827e-31)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 1.8202085622628887e-34)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 1.8000388525789148e-34)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 1.4867901364036983e-34)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 2.161970874151191e-34)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 2.0092977342747436e-34)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 1.8487742041970795e-34)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 2.157693292400065e-34)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 1.8850419903434335e-34)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 1.8007554377399167e-34)
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 2.2299059265151943e-34)
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 2.1506228617767613e-34)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 1.7857653115275219e-34)
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 1.8522439002586293e-34)
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 2.1355823439654388e-34)
#
# Conformer:
# Mean = [18.93 27.42 38.17 46.7  52.33 61.09 65.79 68.25 71.12 74.38 76.49 80.2
#  80.84 82.79 84.87]
# ITR = [4.064484056281553, 5.370128649802123, 7.085832792591691, 7.921990615175844, 7.967828326703041, 8.781078235915372, 8.680406451695909, 8.206431887613023, 7.9105289387773015, 7.74854012682865, 7.446642690023258, 7.443502414912051, 7.011438549436182, 6.8175971973759495, 6.671965525702106]
#
# Conformer SimCLR:
# Mean = [16.18 27.39 34.96 39.09 43.17 45.93 50.9  54.92 57.67 59.29 59.74 63.81
#  63.86 69.05 69.09]
# ITR = [3.0255859276101886, 5.360124271551964, 6.1372432716468, 5.946610024226064, 5.8544107640414715, 5.568105640917761, 5.761677102353336, 5.796808362355949, 5.651610672744634, 5.379169218894075, 4.997869840443321, 5.1322493275689, 4.776569713811436, 5.0592159060804205, 4.751173748696073]
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5510.5, p_value = 0.2115092679299625)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4960.0, p_value = 0.922932443405063)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 6390.5, p_value = 0.0006634750753196805)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 7156.0, p_value = 1.3374035845396845e-07)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 7204.5, p_value = 6.994981712367179e-08)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 7742.5, p_value = 1.9835454697924652e-11)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 7504.0, p_value = 9.224076552619008e-10)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 7506.5, p_value = 8.854656052427347e-10)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 8546.5, p_value = 3.8179865459289515e-18)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 9434.0, p_value = 1.8317644803706614e-27)
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 9851.5, p_value = 1.722050100368198e-32)
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 9928.5, p_value = 1.5923338762430874e-33)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 9989.0, p_value = 3.0374721935939318e-34)
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 9989.5, p_value = 2.3973139112706464e-34)
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 10000.0, p_value = 1.796051528842778e-34)

# %% [markdown]
# ### Baseline Vs Best performing models on ALS Dataset Evaluation

# %%
files = [
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/EEGNet_results_ALS/EEGNet_50Folfd_evaluation_results_ALS.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SimCLR_results/EEGNet_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/EEGInception_results_ALS/EEGInception_50Folfd_evaluation_results_ALS.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SimCLR_results/EEGInception_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/Baseline Results/Conformer_results_ALS/Conformer_50Folfd_evaluation_results_ALS.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SimCLR_results/Conformer_1CLS_50Folfd_evaluation_results.txt') 
]

model_names = ['EEGNet', 'EEGNet SimCLR', 'EEGInception', 'EEGInception Supervised', 'Conformer', 'Conformer SimCLR']

process_results.plot_baseline_and_studied(files, model_names, dataset='ALS')
# Out:
# EEGNet:
# Mean = [20.96025 38.00875 48.69025 57.052   63.92    68.44225 72.503   75.499
#  79.3235  80.94225]
# ITR = [4.891699332267659, 9.24281682891212, 10.49043912337112, 10.90677652385526, 10.965851274319487, 10.53668158930289, 10.154720343195171, 9.668165077074338, 9.460136408634797, 8.909926172251732]
#
# EEGNet SimCLR:
# Mean = [17.042   26.123   37.0965  45.5725  49.2585  53.52175 59.545   61.9395
#  65.25075 66.22925]
# ITR = [3.340561781158262, 4.94299517127093, 6.7637474610368535, 7.617512269414886, 7.2341931248376685, 7.110618484506941, 7.3999657996652335, 7.023500656089608, 6.885221315470056, 6.421582033513383]
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 105791.0, p_value = 2.0248713762377727e-15)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 122219.5, p_value = 2.0644489559706962e-38)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 114449.5, p_value = 4.639733415443221e-26)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 107868.5, p_value = 1.3470937244218141e-17)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 116596.0, p_value = 3.5342528198954496e-29)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 114754.5, p_value = 1.8143498454010323e-26)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 114861.0, p_value = 1.198642622037549e-26)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 116059.0, p_value = 2.0392015817839457e-28)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 122618.5, p_value = 5.30474707608547e-39)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 124150.5, p_value = 9.754645491925119e-42)
#
# EEGInception:
# Mean = [21.274   37.4445  46.7815  55.18075 62.05025 67.0705  71.22125 74.6045
#  78.84525 79.8785 ]
# ITR = [5.023800577536774, 9.020170074342156, 9.839921507704645, 10.34189271404022, 10.457024172949222, 10.198701833537154, 9.864891024314595, 9.481340673241862, 9.365628972594905, 8.715280518308493]
#
# EEGInception Supervised:
# Mean = [ 4.1475   6.84025  9.1345  12.21325 14.17125 15.47925 16.36775 15.89175
#  16.595   16.01225]
# ITR = [0.05692676672396224, 0.28266403784095884, 0.46522467440976784, 0.7245929090982103, 0.8253199384793525, 0.8460071994427687, 0.8272850383090724, 0.6965634656495457, 0.6826844820220007, 0.5804759269218056]
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 157240.5, p_value = 3.7399990510730516e-125)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 156755.0, p_value = 1.0031172616378891e-122)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 158874.5, p_value = 3.333906706041306e-129)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 157740.5, p_value = 2.034694641186828e-125)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 159027.0, p_value = 1.9325791132196435e-129)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 158782.0, p_value = 1.1428157251184314e-128)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 158995.5, p_value = 2.0016414552548407e-129)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 159697.5, p_value = 1.1598915000826146e-131)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 159915.5, p_value = 1.7431980136136358e-132)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 159937.0, p_value = 1.4394370510798287e-132)
#
# Conformer:
# Mean = [18.9295  33.09475 41.24125 48.97175 54.70125 59.8415  63.87025 67.37075
#  71.67225 73.65825]
# ITR = [4.064286397643551, 7.363646636722439, 8.033676213139893, 8.547780184896226, 8.551433345434543, 8.496205305438577, 8.277812536405591, 8.03684429748675, 8.010381988991185, 7.626184673250284]
#
# Conformer SimCLR:
# Mean = [ 6.0445  12.23275 16.26925 19.5435  21.90475 27.029   30.2365  31.118
#  33.04325 34.3465 ]
# ITR = [0.28007765798985135, 1.1828056205345978, 1.598357228704349, 1.8186044635570333, 1.872803805883559, 2.325120917534964, 2.467656874083961, 2.3074862192307593, 2.299503222166272, 2.2321920912406914]
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 150314.5, p_value = 9.444687306287838e-104)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 153834.0, p_value = 1.6741626646302917e-113)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 155438.0, p_value = 3.0538270729661883e-118)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 155588.5, p_value = 1.1826046765193289e-118)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 156054.5, p_value = 4.862342242703569e-120)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 153633.5, p_value = 1.153608368508936e-112)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 152655.5, p_value = 1.109108000278442e-109)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 154448.0, p_value = 4.64365358451061e-115)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 157773.0, p_value = 2.0321580919623571e-125)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 156447.0, p_value = 2.5994379722483764e-121)
