# %%
import os
import process_results
from importlib import reload

scripts_folder = os.path.join(os.getcwd(), 'scripts')

# %% [markdown]
# ## BCI Comp Dataset Evaluation

# %%
filename = os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SupCon_results/Conformer_1CLS_50Folfd_evaluation_results.txt') 
block_averages = process_results.parse_file(filename)

for i, mean in enumerate(block_averages, 1):
    print(f"Block {i} Mean: {list(mean)}")

overall_indices = [0,1]

# Compute statistics
ft_values = [1, 5, 10, 25, 40, 85]
for i in range(len(ft_values)):
    print(f'Performance for {ft_values[i]} chars')
    overall_mean, overall_std = process_results.compute_group_statistics(block_averages[i*2:(i+1)*2], overall_indices)

    # Print results
    print("Performance Analysis:")
    print(f"Overall: {process_results.format_mean_std(overall_mean, overall_std)}")

print()

selected_indices = [0, 4, 9, 14]
for i in range(len(ft_values)):
    print()
    print(f'Performance for {ft_values[i]} chars')
    overall_mean, overall_std = process_results.compute_group_statistics(block_averages[i*2:(i+1)*2], overall_indices)

    # Print results
    print("Performance Analysis:")
    print(f"Overall: {process_results.format_mean_std(overall_mean, overall_std, selected_indices)}")
# Out:
# Block 1 Mean: [2.88, 3.76, 3.64, 4.34, 4.56, 5.6, 6.0, 6.24, 6.3, 6.26, 7.02, 7.1, 7.54, 7.66, 8.62]
# Block 2 Mean: [3.24, 3.74, 3.68, 3.96, 4.0, 4.26, 4.76, 5.48, 4.72, 5.24, 5.08, 5.12, 5.24, 5.58, 5.84]
# Block 3 Mean: [4.3, 6.78, 7.4, 8.86, 11.72, 14.28, 15.54, 17.1, 18.34, 19.62, 20.66, 23.24, 25.6, 27.64, 28.76]
# Block 4 Mean: [6.58, 9.1, 10.04, 10.3, 11.9, 12.5, 14.3, 15.78, 17.34, 18.7, 18.98, 20.38, 21.48, 22.42, 23.92]
# Block 5 Mean: [5.08, 9.48, 9.58, 11.9, 16.26, 20.68, 23.2, 25.18, 26.74, 29.68, 30.88, 35.64, 39.6, 42.18, 43.32]
# Block 6 Mean: [9.24, 13.58, 15.92, 16.48, 18.26, 19.96, 23.86, 26.86, 27.74, 29.28, 31.78, 34.1, 35.74, 38.18, 40.54]
# Block 7 Mean: [6.44, 12.08, 13.42, 16.82, 22.38, 28.32, 31.96, 35.2, 37.64, 41.56, 44.24, 49.6, 54.0, 56.12, 57.1]
# Block 8 Mean: [13.8, 19.06, 24.28, 24.8, 28.36, 31.98, 37.3, 41.48, 41.4, 42.82, 46.26, 49.32, 51.04, 54.62, 56.78]
# Block 9 Mean: [6.36, 12.58, 13.62, 16.58, 23.58, 30.8, 33.82, 37.46, 40.46, 44.44, 46.74, 52.48, 57.48, 58.86, 58.9]
# Block 10 Mean: [16.74, 21.08, 26.3, 26.8, 31.36, 35.74, 40.46, 43.88, 44.52, 46.42, 49.88, 52.92, 53.86, 57.92, 60.36]
# Block 11 Mean: [6.58, 13.58, 15.32, 16.78, 23.84, 33.4, 37.02, 40.2, 44.32, 47.4, 49.42, 55.78, 59.88, 60.72, 61.48]
# Block 12 Mean: [18.66, 21.86, 27.16, 28.18, 33.88, 38.3, 42.58, 47.26, 46.6, 48.64, 54.04, 54.06, 55.14, 61.88, 62.5]
# Performance for 1 chars
# Performance Analysis:
# Overall: 3.06 ± 0.18 & 3.75 ± 0.01 & 3.66 ± 0.02 & 4.15 ± 0.19 & 4.28 ± 0.28 & 4.93 ± 0.67 & 5.38 ± 0.62 & 5.86 ± 0.38 & 5.51 ± 0.79 & 5.75 ± 0.51 & 6.05 ± 0.97 & 6.11 ± 0.99 & 6.39 ± 1.15 & 6.62 ± 1.04 & 7.23 ± 1.39
# Performance for 5 chars
# Performance Analysis:
# Overall: 5.44 ± 1.14 & 7.94 ± 1.16 & 8.72 ± 1.32 & 9.58 ± 0.72 & 11.81 ± 0.09 & 13.39 ± 0.89 & 14.92 ± 0.62 & 16.44 ± 0.66 & 17.84 ± 0.5 & 19.16 ± 0.46 & 19.82 ± 0.84 & 21.81 ± 1.43 & 23.54 ± 2.06 & 25.03 ± 2.61 & 26.34 ± 2.42
# Performance for 10 chars
# Performance Analysis:
# Overall: 7.16 ± 2.08 & 11.53 ± 2.05 & 12.75 ± 3.17 & 14.19 ± 2.29 & 17.26 ± 1.0 & 20.32 ± 0.36 & 23.53 ± 0.33 & 26.02 ± 0.84 & 27.24 ± 0.5 & 29.48 ± 0.2 & 31.33 ± 0.45 & 34.87 ± 0.77 & 37.67 ± 1.93 & 40.18 ± 2.0 & 41.93 ± 1.39
# Performance for 25 chars
# Performance Analysis:
# Overall: 10.12 ± 3.68 & 15.57 ± 3.49 & 18.85 ± 5.43 & 20.81 ± 3.99 & 25.37 ± 2.99 & 30.15 ± 1.83 & 34.63 ± 2.67 & 38.34 ± 3.14 & 39.52 ± 1.88 & 42.19 ± 0.63 & 45.25 ± 1.01 & 49.46 ± 0.14 & 52.52 ± 1.48 & 55.37 ± 0.75 & 56.94 ± 0.16
# Performance for 40 chars
# Performance Analysis:
# Overall: 11.55 ± 5.19 & 16.83 ± 4.25 & 19.96 ± 6.34 & 21.69 ± 5.11 & 27.47 ± 3.89 & 33.27 ± 2.47 & 37.14 ± 3.32 & 40.67 ± 3.21 & 42.49 ± 2.03 & 45.43 ± 0.99 & 48.31 ± 1.57 & 52.7 ± 0.22 & 55.67 ± 1.81 & 58.39 ± 0.47 & 59.63 ± 0.73
# Performance for 85 chars
# Performance Analysis:
# Overall: 12.62 ± 6.04 & 17.72 ± 4.14 & 21.24 ± 5.92 & 22.48 ± 5.7 & 28.86 ± 5.02 & 35.85 ± 2.45 & 39.8 ± 2.78 & 43.73 ± 3.53 & 45.46 ± 1.14 & 48.02 ± 0.62 & 51.73 ± 2.31 & 54.92 ± 0.86 & 57.51 ± 2.37 & 61.3 ± 0.58 & 61.99 ± 0.51
#
#
# Performance for 1 chars
# Performance Analysis:
# Overall: 3.06 ± 0.18 & 4.28 ± 0.28 & 5.75 ± 0.51 & 7.23 ± 1.39
#
# Performance for 5 chars
# Performance Analysis:
# Overall: 5.44 ± 1.14 & 11.81 ± 0.09 & 19.16 ± 0.46 & 26.34 ± 2.42
#
# Performance for 10 chars
# Performance Analysis:
# Overall: 7.16 ± 2.08 & 17.26 ± 1.0 & 29.48 ± 0.2 & 41.93 ± 1.39
#
# Performance for 25 chars
# Performance Analysis:
# Overall: 10.12 ± 3.68 & 25.37 ± 2.99 & 42.19 ± 0.63 & 56.94 ± 0.16
#
# Performance for 40 chars
# Performance Analysis:
# Overall: 11.55 ± 5.19 & 27.47 ± 3.89 & 45.43 ± 0.99 & 59.63 ± 0.73
#
# Performance for 85 chars
# Performance Analysis:
# Overall: 12.62 ± 6.04 & 28.86 ± 5.02 & 48.02 ± 0.62 & 61.99 ± 0.51

# %% [markdown]
# ### EEGNet Results

# %%
file_paths = [
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/Supervised_results/EEGNet_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SimCLR_results/EEGNet_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SupCon_results/EEGNet_1CLS_50Folfd_evaluation_results.txt')
]
process_results.get_differences(file_paths, 'EEGNet', retraining_chars=[1, 5, 10, 25, 40, 85], dataset='BCI')
# Out:
# ALL SUBJECTS
#
# Analysing data from 1 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 26.17391304347818, p_value = 2.0720822845413334e-06)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.018359730471054e-08: diff -> 6.22 - 3.53 = 2.69
# Wilcoxon test between SupCon and SimCLR: p-value = 8.007923650807664e-05: diff -> 4.24 - 6.22 = -1.98
# Wilcoxon test between SupCon and Supervised: p-value = 0.01648990718167938: diff -> 4.24 - 3.53 = 0.71
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 35.36927223719683, p_value = 2.0876616781488336e-08)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.4053909989413864e-09: diff -> 8.63 - 4.19 = 4.44
# Wilcoxon test between SupCon and SimCLR: p-value = 0.00032271176992745837: diff -> 5.83 - 8.63 = -2.80
# Wilcoxon test between SupCon and Supervised: p-value = 0.00024058813879265965: diff -> 5.83 - 4.19 = 1.64
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 38.490861618798974, p_value = 4.383445362206613e-09)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 6.952779580116704e-11: diff -> 10.70 - 4.46 = 6.24
# Wilcoxon test between SupCon and Supervised: p-value = 4.108878993067274e-06: diff -> 7.25 - 4.46 = 2.79
# Wilcoxon test between SupCon and SimCLR: p-value = 0.00013713103200584226: diff -> 7.25 - 10.70 = -3.45
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 41.64304461942253, p_value = 9.064164028191752e-10)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.198795221444397e-11: diff -> 12.20 - 5.25 = 6.95
# Wilcoxon test between SupCon and SimCLR: p-value = 2.5009589825295265e-05: diff -> 8.02 - 12.20 = -4.18
# Wilcoxon test between SupCon and Supervised: p-value = 0.0001477849902170015: diff -> 8.02 - 5.25 = 2.77
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 53.549738219895396, p_value = 2.3540847387992365e-12)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.768453621544952e-12: diff -> 13.74 - 5.31 = 8.43
# Wilcoxon test between SupCon and SimCLR: p-value = 1.1268674134151967e-05: diff -> 8.81 - 13.74 = -4.93
# Wilcoxon test between SupCon and Supervised: p-value = 8.191592302675773e-06: diff -> 8.81 - 5.31 = 3.50
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 48.09793814432987, p_value = 3.5947230504179114e-11)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.49414707339151e-13: diff -> 15.52 - 5.47 = 10.05
# Wilcoxon test between SupCon and Supervised: p-value = 1.5874543831175922e-06: diff -> 9.77 - 5.47 = 4.30
# Wilcoxon test between SupCon and SimCLR: p-value = 6.5221789159897155e-06: diff -> 9.77 - 15.52 = -5.75
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 53.882051282051364, p_value = 1.9937065115070517e-12)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.054738407686288e-13: diff -> 17.29 - 5.76 = 11.53
# Wilcoxon test between SupCon and Supervised: p-value = 9.620863269910203e-07: diff -> 10.81 - 5.76 = 5.05
# Wilcoxon test between SupCon and SimCLR: p-value = 1.0106875850838408e-05: diff -> 10.81 - 17.29 = -6.48
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 59.26666666666675, p_value = 1.3502272013540307e-13)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1134017244076051e-13: diff -> 19.26 - 6.17 = 13.09
# Wilcoxon test between SupCon and Supervised: p-value = 1.2178692191732274e-06: diff -> 11.85 - 6.17 = 5.68
# Wilcoxon test between SupCon and SimCLR: p-value = 3.1143961201488102e-06: diff -> 11.85 - 19.26 = -7.41
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 53.74424552429676, p_value = 2.135921893637303e-12)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.7910331774190312e-13: diff -> 20.53 - 6.34 = 14.19
# Wilcoxon test between SupCon and Supervised: p-value = 5.180405035271969e-07: diff -> 12.21 - 6.34 = 5.87
# Wilcoxon test between SupCon and SimCLR: p-value = 1.9210034001620395e-06: diff -> 12.21 - 20.53 = -8.32
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 51.56632653061233, p_value = 6.3462104207384e-12)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.2161659701319846e-13: diff -> 21.71 - 6.97 = 14.74
# Wilcoxon test between SupCon and SimCLR: p-value = 3.7228341301485002e-06: diff -> 12.74 - 21.71 = -8.97
# Wilcoxon test between SupCon and Supervised: p-value = 1.0823172471094433e-05: diff -> 12.74 - 6.97 = 5.77
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 57.908396946564864, p_value = 2.662878646681809e-13)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.922312964938872e-13: diff -> 23.33 - 7.15 = 16.18
# Wilcoxon test between SupCon and SimCLR: p-value = 5.425797284220506e-07: diff -> 13.15 - 23.33 = -10.18
# Wilcoxon test between SupCon and Supervised: p-value = 5.2018842798615565e-06: diff -> 13.15 - 7.15 = 6.00
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 55.42857142857137, p_value = 9.201076560336883e-13)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.8394519262617943e-13: diff -> 24.94 - 7.39 = 17.55
# Wilcoxon test between SupCon and SimCLR: p-value = 6.417447942007225e-07: diff -> 14.09 - 24.94 = -10.85
# Wilcoxon test between SupCon and Supervised: p-value = 2.605569537441769e-06: diff -> 14.09 - 7.39 = 6.70
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 51.0126582278481, p_value = 8.370319049581722e-12)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1666108161394715e-13: diff -> 26.26 - 7.45 = 18.81
# Wilcoxon test between SupCon and SimCLR: p-value = 2.1854382912613307e-07: diff -> 14.36 - 26.26 = -11.90
# Wilcoxon test between SupCon and Supervised: p-value = 4.163751789368441e-06: diff -> 14.36 - 7.45 = 6.91
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 45.46428571428578, p_value = 1.341392257614552e-10)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.002125270589794e-13: diff -> 27.61 - 8.05 = 19.56
# Wilcoxon test between SupCon and SimCLR: p-value = 5.533070733927704e-07: diff -> 15.38 - 27.61 = -12.23
# Wilcoxon test between SupCon and Supervised: p-value = 3.927984758557779e-06: diff -> 15.38 - 8.05 = 7.33
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 46.06122448979602, p_value = 9.952500021339731e-11)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 7.870941891851374e-13: diff -> 28.09 - 8.17 = 19.92
# Wilcoxon test between SupCon and Supervised: p-value = 2.0287767147495797e-06: diff -> 16.18 - 8.17 = 8.01
# Wilcoxon test between SupCon and SimCLR: p-value = 1.5688839539921583e-06: diff -> 16.18 - 28.09 = -11.91
#
#  ALL SUBJECTS Differences 1: {'SimCLR': [2.69, 4.44, 6.239999999999999, 6.949999999999999, 8.43, 10.05, 11.53, 13.090000000000002, 14.190000000000001, 14.740000000000002, 16.18, 17.55, 18.810000000000002, 19.56, 19.92], 'SupCon': [0.7100000000000004, 1.6399999999999997, 2.79, 2.7699999999999996, 3.500000000000001, 4.3, 5.050000000000001, 5.68, 5.870000000000001, 5.7700000000000005, 6.0, 6.7, 6.909999999999999, 7.33, 8.01]}
#
# Average Difference: (12.29, 4.87)
#
# Analysing data from 5 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 49.42631578947361, p_value = 1.8501711127617195e-11)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 8.187602054204666e-12: diff -> 13.18 - 6.79 = 6.39
# Wilcoxon test between SupCon and Supervised: p-value = 9.342517525789647e-09: diff -> 10.64 - 6.79 = 3.85
# Wilcoxon test between SupCon and SimCLR: p-value = 6.973840588203858e-05: diff -> 10.64 - 13.18 = -2.54
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 48.20967741935488, p_value = 3.3993944514900686e-11)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.5450653045345377e-11: diff -> 18.56 - 10.11 = 8.45
# Wilcoxon test between SupCon and Supervised: p-value = 3.9013611918748085e-10: diff -> 15.79 - 10.11 = 5.68
# Wilcoxon test between SupCon and SimCLR: p-value = 0.0022041012456964315: diff -> 15.79 - 18.56 = -2.77
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 91.34704370179952, p_value = 1.4596256649577392e-20)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.2356944473394058e-14: diff -> 25.32 - 12.07 = 13.25
# Wilcoxon test between SupCon and Supervised: p-value = 3.89020758331106e-13: diff -> 20.86 - 12.07 = 8.79
# Wilcoxon test between SupCon and SimCLR: p-value = 1.136699258226829e-05: diff -> 20.86 - 25.32 = -4.46
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 84.79898218829521, p_value = 3.85598186138381e-19)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SupCon and Supervised: p-value = 1.5087341703521614e-13: diff -> 25.78 - 14.98 = 10.80
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1589393065079122e-13: diff -> 29.63 - 14.98 = 14.65
# Wilcoxon test between SupCon and SimCLR: p-value = 0.00017463347174233594: diff -> 25.78 - 29.63 = -3.85
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 90.6598465473147, p_value = 2.058090448642024e-20)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 5.950957314561025e-15: diff -> 34.24 - 17.20 = 17.04
# Wilcoxon test between SupCon and Supervised: p-value = 2.186336817788977e-13: diff -> 29.56 - 17.20 = 12.36
# Wilcoxon test between SupCon and SimCLR: p-value = 3.218350608404358e-05: diff -> 29.56 - 34.24 = -4.68
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 93.73979591836736, p_value = 4.412268665007415e-21)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.330076423256355e-15: diff -> 39.28 - 19.31 = 19.97
# Wilcoxon test between SupCon and Supervised: p-value = 4.307201492803438e-14: diff -> 33.92 - 19.31 = 14.61
# Wilcoxon test between SupCon and SimCLR: p-value = 2.669006107390233e-05: diff -> 33.92 - 39.28 = -5.36
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 124.39285714285711, p_value = 9.737204191004664e-28)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.251027594831744e-16: diff -> 43.96 - 20.91 = 23.05
# Wilcoxon test between SupCon and Supervised: p-value = 3.201248594607399e-15: diff -> 38.51 - 20.91 = 17.60
# Wilcoxon test between SupCon and SimCLR: p-value = 4.358277153390965e-06: diff -> 38.51 - 43.96 = -5.45
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 112.71065989847715, p_value = 3.3511292400313066e-25)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.574809965369002e-16: diff -> 48.42 - 22.67 = 25.75
# Wilcoxon test between SupCon and Supervised: p-value = 1.2360113492767659e-14: diff -> 41.34 - 22.67 = 18.67
# Wilcoxon test between SupCon and SimCLR: p-value = 3.288935322636852e-07: diff -> 41.34 - 48.42 = -7.08
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 114.90306122448982, p_value = 1.119740220707158e-25)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.2221270398718903e-16: diff -> 51.25 - 24.24 = 27.01
# Wilcoxon test between SupCon and Supervised: p-value = 9.621310202670555e-15: diff -> 44.64 - 24.24 = 20.40
# Wilcoxon test between SupCon and SimCLR: p-value = 1.8683981132981327e-06: diff -> 44.64 - 51.25 = -6.61
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 124.52791878172597, p_value = 9.101354175719977e-28)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 8.962183295225114e-17: diff -> 54.48 - 25.81 = 28.67
# Wilcoxon test between SupCon and Supervised: p-value = 2.176185669500251e-15: diff -> 47.12 - 25.81 = 21.31
# Wilcoxon test between SupCon and SimCLR: p-value = 5.8598418424164044e-08: diff -> 47.12 - 54.48 = -7.36
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 125.40050377833757, p_value = 5.883375810878593e-28)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.439263571471552e-16: diff -> 56.78 - 27.68 = 29.10
# Wilcoxon test between SupCon and Supervised: p-value = 1.6123528055275217e-15: diff -> 49.73 - 27.68 = 22.05
# Wilcoxon test between SupCon and SimCLR: p-value = 2.2844865488885777e-07: diff -> 49.73 - 56.78 = -7.05
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 123.89898989898998, p_value = 1.2464538022788036e-27)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.5758693081066563e-16: diff -> 60.07 - 29.93 = 30.14
# Wilcoxon test between SupCon and Supervised: p-value = 2.1145024747745143e-15: diff -> 52.76 - 29.93 = 22.83
# Wilcoxon test between SupCon and SimCLR: p-value = 1.6899847148141433e-07: diff -> 52.76 - 60.07 = -7.31
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 120.56060606060608, p_value = 6.616023306983802e-27)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.1218179556015946e-16: diff -> 61.93 - 30.88 = 31.05
# Wilcoxon test between SupCon and Supervised: p-value = 1.5558543269948265e-15: diff -> 55.30 - 30.88 = 24.42
# Wilcoxon test between SupCon and SimCLR: p-value = 1.07592691370485e-06: diff -> 55.30 - 61.93 = -6.63
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 122.59746835443043, p_value = 2.389450285985039e-27)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.909427684320857e-16: diff -> 64.09 - 32.80 = 31.29
# Wilcoxon test between SupCon and Supervised: p-value = 2.9454718217572194e-15: diff -> 57.53 - 32.80 = 24.73
# Wilcoxon test between SupCon and SimCLR: p-value = 5.221287750752588e-07: diff -> 57.53 - 64.09 = -6.56
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 121.90379746835454, p_value = 3.3800779679238364e-27)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 5.04404306843288e-16: diff -> 65.85 - 34.35 = 31.50
# Wilcoxon test between SupCon and Supervised: p-value = 4.982843715858527e-15: diff -> 59.55 - 34.35 = 25.20
# Wilcoxon test between SupCon and SimCLR: p-value = 1.9506825553100794e-06: diff -> 59.55 - 65.85 = -6.30
#
#  ALL SUBJECTS Differences 5: {'SimCLR': [6.39, 8.45, 13.25, 14.649999999999999, 17.040000000000003, 19.970000000000002, 23.05, 25.75, 27.01, 28.669999999999998, 29.1, 30.14, 31.05, 31.290000000000006, 31.499999999999993], 'SupCon': [3.8500000000000005, 5.68, 8.79, 10.8, 12.36, 14.610000000000003, 17.599999999999998, 18.67, 20.400000000000002, 21.31, 22.049999999999997, 22.83, 24.419999999999998, 24.730000000000004, 25.199999999999996]}
#
# Average Difference: (22.49, 16.89)
#
# Analysing data from 10 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 96.45092838196284, p_value = 1.1374884999906594e-21)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 7.1966611732251145e-16: diff -> 16.89 - 9.99 = 6.90
# Wilcoxon test between SupCon and Supervised: p-value = 1.1249110324840796e-10: diff -> 13.91 - 9.99 = 3.92
# Wilcoxon test between SupCon and SimCLR: p-value = 1.1673382434924018e-07: diff -> 13.91 - 16.89 = -2.98
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 73.63020833333329, p_value = 1.0266050817790975e-16)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.7936730168852852e-13: diff -> 23.75 - 15.57 = 8.18
# Wilcoxon test between SupCon and Supervised: p-value = 4.874673876405759e-12: diff -> 20.96 - 15.57 = 5.39
# Wilcoxon test between SupCon and SimCLR: p-value = 0.00011069804905631599: diff -> 20.96 - 23.75 = -2.79
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 91.32283464566942, p_value = 1.4774011094298717e-20)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.6455450800679208e-15: diff -> 32.76 - 20.02 = 12.74
# Wilcoxon test between SupCon and Supervised: p-value = 1.9187104092149574e-14: diff -> 28.02 - 20.02 = 8.00
# Wilcoxon test between SupCon and SimCLR: p-value = 1.503065736557131e-06: diff -> 28.02 - 32.76 = -4.74
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 112.29081632653069, p_value = 4.1338912785782795e-25)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 6.739926095538732e-16: diff -> 39.24 - 25.30 = 13.94
# Wilcoxon test between SupCon and Supervised: p-value = 3.2762786844612174e-14: diff -> 34.24 - 25.30 = 8.94
# Wilcoxon test between SupCon and SimCLR: p-value = 5.859235991199114e-10: diff -> 34.24 - 39.24 = -5.00
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 90.37017994858611, p_value = 2.3788374110574738e-20)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.708240510210717e-16: diff -> 43.85 - 29.25 = 14.60
# Wilcoxon test between SupCon and Supervised: p-value = 1.9041003161243507e-13: diff -> 39.65 - 29.25 = 10.40
# Wilcoxon test between SupCon and SimCLR: p-value = 8.969844120186133e-07: diff -> 39.65 - 43.85 = -4.20
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 133.45408163265316, p_value = 1.049093943296127e-29)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.860659016304514e-17: diff -> 51.22 - 33.04 = 18.18
# Wilcoxon test between SupCon and Supervised: p-value = 8.216831241627939e-15: diff -> 45.42 - 33.04 = 12.38
# Wilcoxon test between SupCon and SimCLR: p-value = 5.883722329507784e-10: diff -> 45.42 - 51.22 = -5.80
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 139.3553299492387, p_value = 5.48750071224893e-31)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.0226056202660364e-17: diff -> 56.38 - 35.88 = 20.50
# Wilcoxon test between SupCon and Supervised: p-value = 3.129240544967874e-16: diff -> 50.48 - 35.88 = 14.60
# Wilcoxon test between SupCon and SimCLR: p-value = 1.948037884065656e-10: diff -> 50.48 - 56.38 = -5.90
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 141.35353535353542, p_value = 2.020550918274691e-31)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.7874244706454104e-17: diff -> 60.33 - 39.48 = 20.85
# Wilcoxon test between SupCon and Supervised: p-value = 6.913314159091871e-16: diff -> 53.61 - 39.48 = 14.13
# Wilcoxon test between SupCon and SimCLR: p-value = 6.224745153217812e-12: diff -> 53.61 - 60.33 = -6.72
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 154.0911392405063, p_value = 3.4636520615997067e-34)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.6855747645707083e-17: diff -> 63.65 - 42.98 = 20.67
# Wilcoxon test between SupCon and Supervised: p-value = 5.39066428471667e-16: diff -> 57.70 - 42.98 = 14.72
# Wilcoxon test between SupCon and SimCLR: p-value = 3.86182897399591e-10: diff -> 57.70 - 63.65 = -5.95
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 150.59746835443028, p_value = 1.9868965356669595e-33)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.953384716727626e-17: diff -> 67.37 - 46.29 = 21.08
# Wilcoxon test between SupCon and Supervised: p-value = 2.9185998457850814e-16: diff -> 61.45 - 46.29 = 15.16
# Wilcoxon test between SupCon and SimCLR: p-value = 4.368992327246232e-10: diff -> 61.45 - 67.37 = -5.92
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 133.28426395939096, p_value = 1.1420623616381896e-29)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.5482695691825306e-17: diff -> 69.51 - 49.04 = 20.47
# Wilcoxon test between SupCon and Supervised: p-value = 3.105962987764518e-16: diff -> 64.68 - 49.04 = 15.64
# Wilcoxon test between SupCon and SimCLR: p-value = 1.4133254534997168e-08: diff -> 64.68 - 69.51 = -4.83
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 133.97953964194363, p_value = 8.067010510458544e-30)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.625190186620322e-17: diff -> 72.74 - 51.97 = 20.77
# Wilcoxon test between SupCon and Supervised: p-value = 3.7079956206798364e-17: diff -> 68.76 - 51.97 = 16.79
# Wilcoxon test between SupCon and SimCLR: p-value = 1.9782724518417507e-06: diff -> 68.76 - 72.74 = -3.98
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 133.89340101522842, p_value = 8.422041709783963e-30)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.6553882871789263e-17: diff -> 74.44 - 53.92 = 20.52
# Wilcoxon test between SupCon and Supervised: p-value = 6.9261106363929e-17: diff -> 70.53 - 53.92 = 16.61
# Wilcoxon test between SupCon and SimCLR: p-value = 2.9783065757018215e-07: diff -> 70.53 - 74.44 = -3.91
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 137.5959595959596, p_value = 1.3225649457228052e-30)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.6821862824422362e-17: diff -> 76.57 - 56.60 = 19.97
# Wilcoxon test between SupCon and Supervised: p-value = 4.9803485084378385e-17: diff -> 73.14 - 56.60 = 16.54
# Wilcoxon test between SupCon and SimCLR: p-value = 7.069492118027739e-06: diff -> 73.14 - 76.57 = -3.43
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 135.61439588688944, p_value = 3.562116342195657e-30)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.815284001959849e-17: diff -> 78.22 - 57.98 = 20.24
# Wilcoxon test between SupCon and Supervised: p-value = 4.497027003529395e-17: diff -> 74.96 - 57.98 = 16.98
# Wilcoxon test between SupCon and SimCLR: p-value = 1.0396561419280323e-05: diff -> 74.96 - 78.22 = -3.26
#
#  ALL SUBJECTS Differences 10: {'SimCLR': [6.9, 8.18, 12.739999999999998, 13.940000000000001, 14.600000000000001, 18.18, 20.5, 20.85, 20.67, 21.080000000000005, 20.470000000000006, 20.769999999999996, 20.519999999999996, 19.96999999999999, 20.240000000000002], 'SupCon': [3.92, 5.390000000000001, 8.0, 8.940000000000001, 10.399999999999999, 12.380000000000003, 14.599999999999994, 14.130000000000003, 14.720000000000006, 15.160000000000004, 15.640000000000008, 16.790000000000006, 16.61, 16.54, 16.979999999999997]}
#
# Average Difference: (17.31, 12.68)
#
# Analysing data from 25 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 97.96373056994827, p_value = 5.338831244227917e-22)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SupCon and Supervised: p-value = 3.415614948739294e-15: diff -> 18.55 - 14.63 = 3.92
# Wilcoxon test between SimCLR and Supervised: p-value = 1.6744930111163823e-14: diff -> 19.59 - 14.63 = 4.96
# Wilcoxon test between SupCon and SimCLR: p-value = 0.007000715842689467: diff -> 18.55 - 19.59 = -1.04
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 40.98437500000003, p_value = 1.2599579368407145e-09)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.8217949752740636e-10: diff -> 27.78 - 22.07 = 5.71
# Wilcoxon test between SupCon and Supervised: p-value = 8.80038819868546e-09: diff -> 25.10 - 22.07 = 3.03
# Wilcoxon test between SupCon and SimCLR: p-value = 0.00019670763128986943: diff -> 25.10 - 27.78 = -2.68
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 87.83896103896112, p_value = 8.433579871395314e-20)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 5.73627058890959e-14: diff -> 38.98 - 29.65 = 9.33
# Wilcoxon test between SupCon and Supervised: p-value = 4.2643590614861873e-14: diff -> 35.15 - 29.65 = 5.50
# Wilcoxon test between SupCon and SimCLR: p-value = 5.177566489222905e-06: diff -> 35.15 - 38.98 = -3.83
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 92.2063492063492, p_value = 9.498295388341609e-21)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 5.89835210109348e-15: diff -> 45.22 - 37.37 = 7.85
# Wilcoxon test between SupCon and Supervised: p-value = 4.221176925070483e-10: diff -> 41.62 - 37.37 = 4.25
# Wilcoxon test between SupCon and SimCLR: p-value = 4.85309779515871e-10: diff -> 41.62 - 45.22 = -3.60
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 103.91214470284245, p_value = 2.727498223625463e-23)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.675976880008642e-15: diff -> 50.22 - 42.11 = 8.11
# Wilcoxon test between SupCon and Supervised: p-value = 8.117807957906648e-14: diff -> 47.50 - 42.11 = 5.39
# Wilcoxon test between SupCon and SimCLR: p-value = 2.111385874101547e-07: diff -> 47.50 - 50.22 = -2.72
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 142.96640826873377, p_value = 9.020672081496971e-32)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 6.116780891503019e-17: diff -> 58.15 - 47.37 = 10.78
# Wilcoxon test between SupCon and Supervised: p-value = 9.194963267296272e-17: diff -> 53.86 - 47.37 = 6.49
# Wilcoxon test between SupCon and SimCLR: p-value = 1.643951381822536e-10: diff -> 53.86 - 58.15 = -4.29
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 141.27411167512687, p_value = 2.1024052474788553e-31)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.323874564670975e-17: diff -> 64.26 - 51.60 = 12.66
# Wilcoxon test between SupCon and Supervised: p-value = 6.458611091010619e-17: diff -> 59.67 - 51.60 = 8.07
# Wilcoxon test between SupCon and SimCLR: p-value = 2.020421868907176e-09: diff -> 59.67 - 64.26 = -4.59
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 148.6820512820512, p_value = 5.177293491714558e-33)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.2186617541078477e-17: diff -> 68.37 - 56.54 = 11.83
# Wilcoxon test between SupCon and Supervised: p-value = 8.515920568182176e-16: diff -> 62.99 - 56.54 = 6.45
# Wilcoxon test between SupCon and SimCLR: p-value = 4.322379289972105e-13: diff -> 62.99 - 68.37 = -5.38
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 160.04591836734696, p_value = 1.7638855439865013e-35)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.6478613051657964e-17: diff -> 71.72 - 60.16 = 11.56
# Wilcoxon test between SupCon and Supervised: p-value = 3.5084919911759875e-16: diff -> 67.14 - 60.16 = 6.98
# Wilcoxon test between SupCon and SimCLR: p-value = 7.677145043035201e-13: diff -> 67.14 - 71.72 = -4.58
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 137.54822335025395, p_value = 1.3545118277506813e-30)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.1482372066057203e-17: diff -> 74.00 - 63.87 = 10.13
# Wilcoxon test between SupCon and Supervised: p-value = 2.3879952442513353e-16: diff -> 71.43 - 63.87 = 7.56
# Wilcoxon test between SupCon and SimCLR: p-value = 6.620339787112616e-07: diff -> 71.43 - 74.00 = -2.57
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 139.91214470284237, p_value = 4.153974269955739e-31)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 5.815585026879642e-17: diff -> 76.48 - 66.99 = 9.49
# Wilcoxon test between SupCon and Supervised: p-value = 5.2786944614855986e-17: diff -> 74.16 - 66.99 = 7.17
# Wilcoxon test between SupCon and SimCLR: p-value = 1.1303387438213543e-05: diff -> 74.16 - 76.48 = -2.32
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 157.67095115681238, p_value = 5.783463220712604e-35)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1130377890720449e-17: diff -> 80.25 - 70.03 = 10.22
# Wilcoxon test between SupCon and Supervised: p-value = 8.471695303204997e-18: diff -> 78.96 - 70.03 = 8.93
# Wilcoxon test between SupCon and SimCLR: p-value = 7.314699803636267e-05: diff -> 78.96 - 80.25 = -1.29
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 132.16103896103888, p_value = 2.0026037649242145e-29)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.197661607621425e-17: diff -> 81.46 - 72.26 = 9.20
# Wilcoxon test between SupCon and Supervised: p-value = 1.681183890849922e-16: diff -> 79.78 - 72.26 = 7.52
# Wilcoxon test between SupCon and SimCLR: p-value = 2.345364664930639e-05: diff -> 79.78 - 81.46 = -1.68
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 125.51145038167944, p_value = 5.565892854918248e-28)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.9003791725788634e-17: diff -> 83.14 - 74.55 = 8.59
# Wilcoxon test between SupCon and Supervised: p-value = 4.538413026413629e-17: diff -> 81.91 - 74.55 = 7.36
# Wilcoxon test between SupCon and SimCLR: p-value = 0.000993645279396135: diff -> 81.91 - 83.14 = -1.23
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 107.04145077720216, p_value = 5.704850872918105e-24)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.4620379216538083e-16: diff -> 83.93 - 76.06 = 7.87
# Wilcoxon test between SupCon and Supervised: p-value = 4.005492962867185e-16: diff -> 83.05 - 76.06 = 6.99
# Wilcoxon test between SupCon and SimCLR: p-value = 0.012572896933167115: diff -> 83.05 - 83.93 = -0.88
#
#  ALL SUBJECTS Differences 25: {'SimCLR': [4.959999999999999, 5.710000000000001, 9.329999999999998, 7.850000000000001, 8.11, 10.780000000000001, 12.660000000000004, 11.830000000000005, 11.560000000000002, 10.130000000000003, 9.490000000000009, 10.219999999999999, 9.199999999999989, 8.590000000000003, 7.8700000000000045], 'SupCon': [3.92, 3.030000000000001, 5.5, 4.25, 5.390000000000001, 6.490000000000002, 8.07, 6.450000000000003, 6.980000000000004, 7.560000000000009, 7.170000000000002, 8.929999999999993, 7.519999999999996, 7.359999999999999, 6.989999999999995]}
#
# Average Difference: (9.22, 6.37)
#
# Analysing data from 40 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 63.20643431635395, p_value = 1.883203175484252e-14)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SupCon and Supervised: p-value = 4.598574491624976e-13: diff -> 19.61 - 15.90 = 3.71
# Wilcoxon test between SimCLR and Supervised: p-value = 6.269808743682064e-11: diff -> 19.28 - 15.90 = 3.38
# Wilcoxon test between SupCon and SimCLR: p-value = 0.35560883394843534: diff -> 19.61 - 19.28 = 0.33
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 50.43733333333342, p_value = 1.116020637607299e-11)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.31328646736001e-11: diff -> 28.94 - 23.96 = 4.98
# Wilcoxon test between SupCon and Supervised: p-value = 2.3931366461562562e-08: diff -> 26.39 - 23.96 = 2.43
# Wilcoxon test between SupCon and SimCLR: p-value = 1.1682144534270954e-05: diff -> 26.39 - 28.94 = -2.55
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 105.47894736842098, p_value = 1.2460561139854961e-23)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.826954530131447e-15: diff -> 40.68 - 32.58 = 8.10
# Wilcoxon test between SupCon and Supervised: p-value = 5.543863443923717e-15: diff -> 37.57 - 32.58 = 4.99
# Wilcoxon test between SupCon and SimCLR: p-value = 1.0240737384891046e-05: diff -> 37.57 - 40.68 = -3.11
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 91.47643979057605, p_value = 1.368180786841793e-20)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.9734278816466946e-16: diff -> 47.37 - 40.40 = 6.97
# Wilcoxon test between SupCon and Supervised: p-value = 1.2308903503712669e-10: diff -> 44.46 - 40.40 = 4.06
# Wilcoxon test between SupCon and SimCLR: p-value = 3.234613192485233e-09: diff -> 44.46 - 47.37 = -2.91
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 95.06878306878299, p_value = 2.2702623976322335e-21)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.24952878352312e-15: diff -> 53.03 - 46.15 = 6.88
# Wilcoxon test between SupCon and Supervised: p-value = 2.2248007181813592e-10: diff -> 50.07 - 46.15 = 3.92
# Wilcoxon test between SupCon and SimCLR: p-value = 1.79862778016625e-09: diff -> 50.07 - 53.03 = -2.96
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 140.10741687979532, p_value = 3.767567029692891e-31)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0841898318038651e-17: diff -> 60.28 - 50.89 = 9.39
# Wilcoxon test between SupCon and Supervised: p-value = 2.1398187143117397e-15: diff -> 56.42 - 50.89 = 5.53
# Wilcoxon test between SupCon and SimCLR: p-value = 9.445412543104902e-11: diff -> 56.42 - 60.28 = -3.86
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 120.9642857142858, p_value = 5.406785039777075e-27)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0814180483893503e-17: diff -> 66.38 - 55.85 = 10.53
# Wilcoxon test between SupCon and Supervised: p-value = 8.345101596609634e-13: diff -> 61.60 - 55.85 = 5.75
# Wilcoxon test between SupCon and SimCLR: p-value = 7.939946132396212e-10: diff -> 61.60 - 66.38 = -4.78
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 134.64615384615382, p_value = 5.780417238926634e-30)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.312098855198657e-17: diff -> 70.45 - 60.72 = 9.73
# Wilcoxon test between SupCon and Supervised: p-value = 2.2808525915851034e-13: diff -> 65.12 - 60.72 = 4.40
# Wilcoxon test between SupCon and SimCLR: p-value = 7.663476132034105e-13: diff -> 65.12 - 70.45 = -5.33
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 148.37851662404088, p_value = 6.0257970240862345e-33)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.2534620532712685e-17: diff -> 73.80 - 64.85 = 8.95
# Wilcoxon test between SupCon and SimCLR: p-value = 4.192272148292378e-15: diff -> 69.01 - 73.80 = -4.79
# Wilcoxon test between SupCon and Supervised: p-value = 2.8246311590874347e-13: diff -> 69.01 - 64.85 = 4.16
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 124.39583333333341, p_value = 9.722725079635424e-28)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.609858397427885e-16: diff -> 75.95 - 69.02 = 6.93
# Wilcoxon test between SupCon and Supervised: p-value = 4.300537564347609e-15: diff -> 73.59 - 69.02 = 4.57
# Wilcoxon test between SupCon and SimCLR: p-value = 2.44375330997257e-06: diff -> 73.59 - 75.95 = -2.36
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 124.37894736842115, p_value = 9.805161391377158e-28)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.0648075623148787e-16: diff -> 78.58 - 71.65 = 6.93
# Wilcoxon test between SupCon and Supervised: p-value = 1.158488624041184e-15: diff -> 76.87 - 71.65 = 5.22
# Wilcoxon test between SupCon and SimCLR: p-value = 3.7849833730639564e-06: diff -> 76.87 - 78.58 = -1.71
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 153.34715025906738, p_value = 5.024460235043368e-34)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.063261657116674e-17: diff -> 82.67 - 74.83 = 7.84
# Wilcoxon test between SupCon and Supervised: p-value = 1.891254574649758e-17: diff -> 81.07 - 74.83 = 6.24
# Wilcoxon test between SupCon and SimCLR: p-value = 5.73274319226446e-06: diff -> 81.07 - 82.67 = -1.60
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 135.25130890052353, p_value = 4.271215040441224e-30)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.466829321177548e-17: diff -> 83.48 - 76.69 = 6.79
# Wilcoxon test between SupCon and Supervised: p-value = 1.551228883533796e-15: diff -> 81.66 - 76.69 = 4.97
# Wilcoxon test between SupCon and SimCLR: p-value = 1.0289673676975021e-07: diff -> 81.66 - 83.48 = -1.82
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 106.11609498680747, p_value = 9.06113817417652e-24)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 6.514692547217285e-16: diff -> 84.41 - 78.49 = 5.92
# Wilcoxon test between SupCon and Supervised: p-value = 4.1183669188765767e-16: diff -> 84.04 - 78.49 = 5.55
# Wilcoxon test between SupCon and SimCLR: p-value = 0.19902179331622127: diff -> 84.04 - 84.41 = -0.37
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 91.44444444444441, p_value = 1.3902445093201967e-20)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SupCon and Supervised: p-value = 1.7751863711957122e-15: diff -> 84.84 - 80.24 = 4.60
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1828610528487894e-14: diff -> 85.39 - 80.24 = 5.15
# Wilcoxon test between SupCon and SimCLR: p-value = 0.07564101966968788: diff -> 84.84 - 85.39 = -0.55
#
#  ALL SUBJECTS Differences 40: {'SimCLR': [3.380000000000001, 4.98, 8.100000000000001, 6.969999999999999, 6.880000000000003, 9.39, 10.529999999999994, 9.730000000000004, 8.950000000000003, 6.930000000000007, 6.929999999999993, 7.840000000000003, 6.790000000000006, 5.920000000000002, 5.150000000000006], 'SupCon': [3.709999999999999, 2.4299999999999997, 4.990000000000002, 4.060000000000002, 3.9200000000000017, 5.530000000000001, 5.75, 4.400000000000006, 4.160000000000011, 4.570000000000007, 5.219999999999999, 6.239999999999995, 4.969999999999999, 5.550000000000011, 4.6000000000000085]}
#
# Average Difference: (7.23, 4.67)
#
# Analysing data from 85 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 38.43258426966284, p_value = 4.5130522665747355e-09)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.4464259418510956e-10: diff -> 19.91 - 18.16 = 1.75
# Wilcoxon test between SupCon and Supervised: p-value = 8.707012851276434e-09: diff -> 20.42 - 18.16 = 2.26
# Wilcoxon test between SupCon and SimCLR: p-value = 0.1860620773189805: diff -> 20.42 - 19.91 = 0.51
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 52.088772845953, p_value = 4.8872740445665215e-12)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SupCon and Supervised: p-value = 1.5022856504690507e-16: diff -> 29.38 - 25.34 = 4.04
# Wilcoxon test between SimCLR and Supervised: p-value = 4.67640650395904e-07: diff -> 29.27 - 25.34 = 3.93
# Wilcoxon test between SupCon and SimCLR: p-value = 0.7219039409815071: diff -> 29.38 - 29.27 = 0.11
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 103.20942408376969, p_value = 3.8757728844871905e-23)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SupCon and Supervised: p-value = 5.36853027412934e-16: diff -> 40.23 - 36.45 = 3.78
# Wilcoxon test between SimCLR and Supervised: p-value = 2.3161443829552826e-15: diff -> 44.03 - 36.45 = 7.58
# Wilcoxon test between SupCon and SimCLR: p-value = 1.0769732231223113e-06: diff -> 40.23 - 44.03 = -3.80
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 81.85789473684221, p_value = 1.6779692885630534e-18)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.713343198613196e-17: diff -> 48.53 - 44.38 = 4.15
# Wilcoxon test between SupCon and Supervised: p-value = 7.369567531431141e-09: diff -> 47.17 - 44.38 = 2.79
# Wilcoxon test between SupCon and SimCLR: p-value = 0.00029349907698407495: diff -> 47.17 - 48.53 = -1.36
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 164.734375, p_value = 1.6919400815908883e-36)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0056478085170678e-17: diff -> 56.01 - 50.47 = 5.54
# Wilcoxon test between SupCon and SimCLR: p-value = 1.171018618574631e-16: diff -> 53.00 - 56.01 = -3.01
# Wilcoxon test between SupCon and Supervised: p-value = 1.740695851600174e-13: diff -> 53.00 - 50.47 = 2.53
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 127.81912144702838, p_value = 1.7556196654409718e-28)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.841568691003724e-18: diff -> 62.17 - 55.88 = 6.29
# Wilcoxon test between SupCon and SimCLR: p-value = 2.2060606754232476e-15: diff -> 57.94 - 62.17 = -4.23
# Wilcoxon test between SupCon and Supervised: p-value = 2.428568026248969e-05: diff -> 57.94 - 55.88 = 2.06
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 81.27225130890054, p_value = 2.248820866335045e-18)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.17076568139784e-18: diff -> 67.99 - 59.46 = 8.53
# Wilcoxon test between SupCon and SimCLR: p-value = 3.83625917991583e-08: diff -> 63.17 - 67.99 = -4.82
# Wilcoxon test between SupCon and Supervised: p-value = 7.673459760941692e-07: diff -> 63.17 - 59.46 = 3.71
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 113.95755968169759, p_value = 1.7965128565741367e-25)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 8.810028493581308e-16: diff -> 72.10 - 65.83 = 6.27
# Wilcoxon test between SupCon and Supervised: p-value = 2.707637646955176e-12: diff -> 67.77 - 65.83 = 1.94
# Wilcoxon test between SupCon and SimCLR: p-value = 2.5389353746847817e-11: diff -> 67.77 - 72.10 = -4.33
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 96.85245901639357, p_value = 9.305843513944002e-22)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SupCon and SimCLR: p-value = 3.3366253897402344e-15: diff -> 70.45 - 74.74 = -4.29
# Wilcoxon test between SimCLR and Supervised: p-value = 3.335651846551633e-14: diff -> 74.74 - 69.05 = 5.69
# Wilcoxon test between SupCon and Supervised: p-value = 1.3479469755426676e-06: diff -> 70.45 - 69.05 = 1.40
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 98.92800000000013, p_value = 3.296535425360804e-22)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 6.938972574057729e-17: diff -> 77.66 - 72.67 = 4.99
# Wilcoxon test between SupCon and Supervised: p-value = 1.1600359818238813e-12: diff -> 75.66 - 72.67 = 2.99
# Wilcoxon test between SupCon and SimCLR: p-value = 1.0656542159558568e-05: diff -> 75.66 - 77.66 = -2.00
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 119.83202099737544, p_value = 9.523734127221311e-27)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SupCon and Supervised: p-value = 4.197889780632291e-17: diff -> 80.38 - 76.25 = 4.13
# Wilcoxon test between SimCLR and Supervised: p-value = 2.015565201912636e-15: diff -> 79.92 - 76.25 = 3.67
# Wilcoxon test between SupCon and SimCLR: p-value = 0.09036038399539349: diff -> 80.38 - 79.92 = 0.46
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 149.22955145118732, p_value = 3.937446210408686e-33)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.3614310797336736e-17: diff -> 84.31 - 79.82 = 4.49
# Wilcoxon test between SupCon and Supervised: p-value = 1.1310592274118225e-17: diff -> 83.57 - 79.82 = 3.75
# Wilcoxon test between SupCon and SimCLR: p-value = 0.001663728212235045: diff -> 83.57 - 84.31 = -0.74
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 120.45125348189417, p_value = 6.98783492876062e-27)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 8.445693811026013e-15: diff -> 84.55 - 81.70 = 2.85
# Wilcoxon test between SupCon and SimCLR: p-value = 3.538130142470198e-10: diff -> 83.16 - 84.55 = -1.39
# Wilcoxon test between SupCon and Supervised: p-value = 4.590029715502456e-08: diff -> 83.16 - 81.70 = 1.46
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 106.37900874635571, p_value = 7.944960741393508e-24)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.273656631890553e-16: diff -> 86.75 - 83.09 = 3.66
# Wilcoxon test between SupCon and Supervised: p-value = 1.5382690278915896e-13: diff -> 86.12 - 83.09 = 3.03
# Wilcoxon test between SupCon and SimCLR: p-value = 0.00013887564727353767: diff -> 86.12 - 86.75 = -0.63
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 116.42541436464089, p_value = 5.23049142053853e-26)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SupCon and Supervised: p-value = 3.932275462665943e-16: diff -> 87.03 - 83.03 = 4.00
# Wilcoxon test between SimCLR and Supervised: p-value = 3.009218178348505e-11: diff -> 85.80 - 83.03 = 2.77
# Wilcoxon test between SupCon and SimCLR: p-value = 4.6080618777121997e-10: diff -> 87.03 - 85.80 = 1.23
#
#  ALL SUBJECTS Differences 85: {'SimCLR': [1.75, 3.9299999999999997, 7.579999999999998, 4.149999999999999, 5.539999999999999, 6.289999999999999, 8.529999999999994, 6.269999999999996, 5.689999999999998, 4.989999999999995, 3.6700000000000017, 4.490000000000009, 2.8499999999999943, 3.6599999999999966, 2.769999999999996], 'SupCon': [2.2600000000000016, 4.039999999999999, 3.779999999999994, 2.789999999999999, 2.530000000000001, 2.059999999999995, 3.710000000000001, 1.9399999999999977, 1.4000000000000057, 2.989999999999995, 4.1299999999999955, 3.75, 1.4599999999999937, 3.030000000000001, 4.0]}
#
# Average Difference: (4.81, 2.92)

# %%
reload(process_results)
file_paths = [
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/Supervised_results/EEGNet_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SimCLR_results/EEGNet_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SupCon_results/EEGNet_1CLS_50Folfd_evaluation_results.txt')
]
process_results.plot_intra_and_BCI(file_paths, 'EEGNet', retraining_chars=[1, 5, 10, 25, 40, 85], 
                                   dataset='BCI', significance_legend_loc = ['upper right', 'upper right', 'lower right', 'lower right', 'lower right', 'lower right'])
# Out:
# Analysing data from 1 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 26.17391304347818, p_value = 2.0720822845413334e-06)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.018359730471054e-08
# Wilcoxon test between SimCLR and SupCon: p-value = 8.007923650807664e-05
# Wilcoxon test between Supervised and SupCon: p-value = 0.01648990718167938
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 35.36927223719683, p_value = 2.0876616781488336e-08)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.4053909989413864e-09
# Wilcoxon test between SimCLR and SupCon: p-value = 0.00032271176992745837
# Wilcoxon test between Supervised and SupCon: p-value = 0.00024058813879265965
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 38.490861618798974, p_value = 4.383445362206613e-09)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 6.952779580116704e-11
# Wilcoxon test between Supervised and SupCon: p-value = 4.108878993067274e-06
# Wilcoxon test between SimCLR and SupCon: p-value = 0.00013713103200584226
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 41.64304461942253, p_value = 9.064164028191752e-10)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.198795221444397e-11
# Wilcoxon test between SimCLR and SupCon: p-value = 2.5009589825295265e-05
# Wilcoxon test between Supervised and SupCon: p-value = 0.0001477849902170015
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 53.549738219895396, p_value = 2.3540847387992365e-12)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.768453621544952e-12
# Wilcoxon test between SimCLR and SupCon: p-value = 1.1268674134151967e-05
# Wilcoxon test between Supervised and SupCon: p-value = 8.191592302675773e-06
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 48.09793814432987, p_value = 3.5947230504179114e-11)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.49414707339151e-13
# Wilcoxon test between Supervised and SupCon: p-value = 1.5874543831175922e-06
# Wilcoxon test between SimCLR and SupCon: p-value = 6.5221789159897155e-06
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 53.882051282051364, p_value = 1.9937065115070517e-12)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.054738407686288e-13
# Wilcoxon test between Supervised and SupCon: p-value = 9.620863269910203e-07
# Wilcoxon test between SimCLR and SupCon: p-value = 1.0106875850838408e-05
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 59.26666666666675, p_value = 1.3502272013540307e-13)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1134017244076051e-13
# Wilcoxon test between Supervised and SupCon: p-value = 1.2178692191732274e-06
# Wilcoxon test between SimCLR and SupCon: p-value = 3.1143961201488102e-06
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 53.74424552429676, p_value = 2.135921893637303e-12)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.7910331774190312e-13
# Wilcoxon test between Supervised and SupCon: p-value = 5.180405035271969e-07
# Wilcoxon test between SimCLR and SupCon: p-value = 1.9210034001620395e-06
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 51.56632653061233, p_value = 6.3462104207384e-12)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.2161659701319846e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 3.7228341301485002e-06
# Wilcoxon test between Supervised and SupCon: p-value = 1.0823172471094433e-05
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 57.908396946564864, p_value = 2.662878646681809e-13)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.922312964938872e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 5.425797284220506e-07
# Wilcoxon test between Supervised and SupCon: p-value = 5.2018842798615565e-06
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 55.42857142857137, p_value = 9.201076560336883e-13)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.8394519262617943e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 6.417447942007225e-07
# Wilcoxon test between Supervised and SupCon: p-value = 2.605569537441769e-06
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 51.0126582278481, p_value = 8.370319049581722e-12)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1666108161394715e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 2.1854382912613307e-07
# Wilcoxon test between Supervised and SupCon: p-value = 4.163751789368441e-06
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 45.46428571428578, p_value = 1.341392257614552e-10)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.002125270589794e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 5.533070733927704e-07
# Wilcoxon test between Supervised and SupCon: p-value = 3.927984758557779e-06
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 46.06122448979602, p_value = 9.952500021339731e-11)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 7.870941891851374e-13
# Wilcoxon test between Supervised and SupCon: p-value = 2.0287767147495797e-06
# Wilcoxon test between SimCLR and SupCon: p-value = 1.5688839539921583e-06
# [array([3.53, 4.19, 4.46, 5.25, 5.31, 5.47, 5.76, 6.17, 6.34, 6.97, 7.15,
#        7.39, 7.45, 8.05, 8.17]), array([ 6.22,  8.63, 10.7 , 12.2 , 13.74, 15.52, 17.29, 19.26, 20.53,
#        21.71, 23.33, 24.94, 26.26, 27.61, 28.09]), array([ 4.24,  5.83,  7.25,  8.02,  8.81,  9.77, 10.81, 11.85, 12.21,
#        12.74, 13.15, 14.09, 14.36, 15.38, 16.18])]
# Analysing data from 5 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 49.42631578947361, p_value = 1.8501711127617195e-11)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 8.187602054204666e-12
# Wilcoxon test between Supervised and SupCon: p-value = 9.342517525789647e-09
# Wilcoxon test between SimCLR and SupCon: p-value = 6.973840588203858e-05
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 48.20967741935488, p_value = 3.3993944514900686e-11)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.5450653045345377e-11
# Wilcoxon test between Supervised and SupCon: p-value = 3.9013611918748085e-10
# Wilcoxon test between SimCLR and SupCon: p-value = 0.0022041012456964315
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 91.34704370179952, p_value = 1.4596256649577392e-20)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.2356944473394058e-14
# Wilcoxon test between Supervised and SupCon: p-value = 3.89020758331106e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 1.136699258226829e-05
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 84.79898218829521, p_value = 3.85598186138381e-19)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SupCon: p-value = 1.5087341703521614e-13
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1589393065079122e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 0.00017463347174233594
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 90.6598465473147, p_value = 2.058090448642024e-20)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 5.950957314561025e-15
# Wilcoxon test between Supervised and SupCon: p-value = 2.186336817788977e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 3.218350608404358e-05
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 93.73979591836736, p_value = 4.412268665007415e-21)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.330076423256355e-15
# Wilcoxon test between Supervised and SupCon: p-value = 4.307201492803438e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 2.669006107390233e-05
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 124.39285714285711, p_value = 9.737204191004664e-28)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.251027594831744e-16
# Wilcoxon test between Supervised and SupCon: p-value = 3.201248594607399e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 4.358277153390965e-06
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 112.71065989847715, p_value = 3.3511292400313066e-25)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.574809965369002e-16
# Wilcoxon test between Supervised and SupCon: p-value = 1.2360113492767659e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 3.288935322636852e-07
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 114.90306122448982, p_value = 1.119740220707158e-25)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.2221270398718903e-16
# Wilcoxon test between Supervised and SupCon: p-value = 9.621310202670555e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 1.8683981132981327e-06
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 124.52791878172597, p_value = 9.101354175719977e-28)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 8.962183295225114e-17
# Wilcoxon test between Supervised and SupCon: p-value = 2.176185669500251e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 5.8598418424164044e-08
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 125.40050377833757, p_value = 5.883375810878593e-28)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.439263571471552e-16
# Wilcoxon test between Supervised and SupCon: p-value = 1.6123528055275217e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 2.2844865488885777e-07
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 123.89898989898998, p_value = 1.2464538022788036e-27)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.5758693081066563e-16
# Wilcoxon test between Supervised and SupCon: p-value = 2.1145024747745143e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 1.6899847148141433e-07
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 120.56060606060608, p_value = 6.616023306983802e-27)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.1218179556015946e-16
# Wilcoxon test between Supervised and SupCon: p-value = 1.5558543269948265e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 1.07592691370485e-06
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 122.59746835443043, p_value = 2.389450285985039e-27)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.909427684320857e-16
# Wilcoxon test between Supervised and SupCon: p-value = 2.9454718217572194e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 5.221287750752588e-07
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 121.90379746835454, p_value = 3.3800779679238364e-27)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 5.04404306843288e-16
# Wilcoxon test between Supervised and SupCon: p-value = 4.982843715858527e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 1.9506825553100794e-06
# [array([ 6.79, 10.11, 12.07, 14.98, 17.2 , 19.31, 20.91, 22.67, 24.24,
#        25.81, 27.68, 29.93, 30.88, 32.8 , 34.35]), array([13.18, 18.56, 25.32, 29.63, 34.24, 39.28, 43.96, 48.42, 51.25,
#        54.48, 56.78, 60.07, 61.93, 64.09, 65.85]), array([10.64, 15.79, 20.86, 25.78, 29.56, 33.92, 38.51, 41.34, 44.64,
#        47.12, 49.73, 52.76, 55.3 , 57.53, 59.55])]
# Analysing data from 10 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 96.45092838196284, p_value = 1.1374884999906594e-21)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 7.1966611732251145e-16
# Wilcoxon test between Supervised and SupCon: p-value = 1.1249110324840796e-10
# Wilcoxon test between SimCLR and SupCon: p-value = 1.1673382434924018e-07
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 73.63020833333329, p_value = 1.0266050817790975e-16)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.7936730168852852e-13
# Wilcoxon test between Supervised and SupCon: p-value = 4.874673876405759e-12
# Wilcoxon test between SimCLR and SupCon: p-value = 0.00011069804905631599
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 91.32283464566942, p_value = 1.4774011094298717e-20)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.6455450800679208e-15
# Wilcoxon test between Supervised and SupCon: p-value = 1.9187104092149574e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 1.503065736557131e-06
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 112.29081632653069, p_value = 4.1338912785782795e-25)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 6.739926095538732e-16
# Wilcoxon test between Supervised and SupCon: p-value = 3.2762786844612174e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 5.859235991199114e-10
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 90.37017994858611, p_value = 2.3788374110574738e-20)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.708240510210717e-16
# Wilcoxon test between Supervised and SupCon: p-value = 1.9041003161243507e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 8.969844120186133e-07
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 133.45408163265316, p_value = 1.049093943296127e-29)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.860659016304514e-17
# Wilcoxon test between Supervised and SupCon: p-value = 8.216831241627939e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 5.883722329507784e-10
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 139.3553299492387, p_value = 5.48750071224893e-31)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.0226056202660364e-17
# Wilcoxon test between Supervised and SupCon: p-value = 3.129240544967874e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 1.948037884065656e-10
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 141.35353535353542, p_value = 2.020550918274691e-31)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.7874244706454104e-17
# Wilcoxon test between Supervised and SupCon: p-value = 6.913314159091871e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 6.224745153217812e-12
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 154.0911392405063, p_value = 3.4636520615997067e-34)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.6855747645707083e-17
# Wilcoxon test between Supervised and SupCon: p-value = 5.39066428471667e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 3.86182897399591e-10
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 150.59746835443028, p_value = 1.9868965356669595e-33)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.953384716727626e-17
# Wilcoxon test between Supervised and SupCon: p-value = 2.9185998457850814e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 4.368992327246232e-10
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 133.28426395939096, p_value = 1.1420623616381896e-29)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.5482695691825306e-17
# Wilcoxon test between Supervised and SupCon: p-value = 3.105962987764518e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 1.4133254534997168e-08
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 133.97953964194363, p_value = 8.067010510458544e-30)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.625190186620322e-17
# Wilcoxon test between Supervised and SupCon: p-value = 3.7079956206798364e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.9782724518417507e-06
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 133.89340101522842, p_value = 8.422041709783963e-30)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.6553882871789263e-17
# Wilcoxon test between Supervised and SupCon: p-value = 6.9261106363929e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 2.9783065757018215e-07
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 137.5959595959596, p_value = 1.3225649457228052e-30)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.6821862824422362e-17
# Wilcoxon test between Supervised and SupCon: p-value = 4.9803485084378385e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 7.069492118027739e-06
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 135.61439588688944, p_value = 3.562116342195657e-30)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.815284001959849e-17
# Wilcoxon test between Supervised and SupCon: p-value = 4.497027003529395e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.0396561419280323e-05
# [array([ 9.99, 15.57, 20.02, 25.3 , 29.25, 33.04, 35.88, 39.48, 42.98,
#        46.29, 49.04, 51.97, 53.92, 56.6 , 57.98]), array([16.89, 23.75, 32.76, 39.24, 43.85, 51.22, 56.38, 60.33, 63.65,
#        67.37, 69.51, 72.74, 74.44, 76.57, 78.22]), array([13.91, 20.96, 28.02, 34.24, 39.65, 45.42, 50.48, 53.61, 57.7 ,
#        61.45, 64.68, 68.76, 70.53, 73.14, 74.96])]
# Analysing data from 25 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 97.96373056994827, p_value = 5.338831244227917e-22)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SupCon: p-value = 3.415614948739294e-15
# Wilcoxon test between Supervised and SimCLR: p-value = 1.6744930111163823e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 0.007000715842689467
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 40.98437500000003, p_value = 1.2599579368407145e-09)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.8217949752740636e-10
# Wilcoxon test between Supervised and SupCon: p-value = 8.80038819868546e-09
# Wilcoxon test between SimCLR and SupCon: p-value = 0.00019670763128986943
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 87.83896103896112, p_value = 8.433579871395314e-20)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 5.73627058890959e-14
# Wilcoxon test between Supervised and SupCon: p-value = 4.2643590614861873e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 5.177566489222905e-06
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 92.2063492063492, p_value = 9.498295388341609e-21)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 5.89835210109348e-15
# Wilcoxon test between Supervised and SupCon: p-value = 4.221176925070483e-10
# Wilcoxon test between SimCLR and SupCon: p-value = 4.85309779515871e-10
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 103.91214470284245, p_value = 2.727498223625463e-23)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.675976880008642e-15
# Wilcoxon test between Supervised and SupCon: p-value = 8.117807957906648e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 2.111385874101547e-07
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 142.96640826873377, p_value = 9.020672081496971e-32)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 6.116780891503019e-17
# Wilcoxon test between Supervised and SupCon: p-value = 9.194963267296272e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.643951381822536e-10
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 141.27411167512687, p_value = 2.1024052474788553e-31)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.323874564670975e-17
# Wilcoxon test between Supervised and SupCon: p-value = 6.458611091010619e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 2.020421868907176e-09
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 148.6820512820512, p_value = 5.177293491714558e-33)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.2186617541078477e-17
# Wilcoxon test between Supervised and SupCon: p-value = 8.515920568182176e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 4.322379289972105e-13
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 160.04591836734696, p_value = 1.7638855439865013e-35)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.6478613051657964e-17
# Wilcoxon test between Supervised and SupCon: p-value = 3.5084919911759875e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 7.677145043035201e-13
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 137.54822335025395, p_value = 1.3545118277506813e-30)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.1482372066057203e-17
# Wilcoxon test between Supervised and SupCon: p-value = 2.3879952442513353e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 6.620339787112616e-07
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 139.91214470284237, p_value = 4.153974269955739e-31)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 5.815585026879642e-17
# Wilcoxon test between Supervised and SupCon: p-value = 5.2786944614855986e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.1303387438213543e-05
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 157.67095115681238, p_value = 5.783463220712604e-35)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1130377890720449e-17
# Wilcoxon test between Supervised and SupCon: p-value = 8.471695303204997e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 7.314699803636267e-05
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 132.16103896103888, p_value = 2.0026037649242145e-29)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.197661607621425e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.681183890849922e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 2.345364664930639e-05
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 125.51145038167944, p_value = 5.565892854918248e-28)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.9003791725788634e-17
# Wilcoxon test between Supervised and SupCon: p-value = 4.538413026413629e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 0.000993645279396135
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 107.04145077720216, p_value = 5.704850872918105e-24)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.4620379216538083e-16
# Wilcoxon test between Supervised and SupCon: p-value = 4.005492962867185e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 0.012572896933167115
# [array([14.63, 22.07, 29.65, 37.37, 42.11, 47.37, 51.6 , 56.54, 60.16,
#        63.87, 66.99, 70.03, 72.26, 74.55, 76.06]), array([19.59, 27.78, 38.98, 45.22, 50.22, 58.15, 64.26, 68.37, 71.72,
#        74.  , 76.48, 80.25, 81.46, 83.14, 83.93]), array([18.55, 25.1 , 35.15, 41.62, 47.5 , 53.86, 59.67, 62.99, 67.14,
#        71.43, 74.16, 78.96, 79.78, 81.91, 83.05])]
# Analysing data from 40 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 63.20643431635395, p_value = 1.883203175484252e-14)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SupCon: p-value = 4.598574491624976e-13
# Wilcoxon test between Supervised and SimCLR: p-value = 6.269808743682064e-11
# Wilcoxon test between SimCLR and SupCon: p-value = 0.35560883394843534
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 50.43733333333342, p_value = 1.116020637607299e-11)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.31328646736001e-11
# Wilcoxon test between Supervised and SupCon: p-value = 2.3931366461562562e-08
# Wilcoxon test between SimCLR and SupCon: p-value = 1.1682144534270954e-05
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 105.47894736842098, p_value = 1.2460561139854961e-23)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.826954530131447e-15
# Wilcoxon test between Supervised and SupCon: p-value = 5.543863443923717e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 1.0240737384891046e-05
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 91.47643979057605, p_value = 1.368180786841793e-20)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.9734278816466946e-16
# Wilcoxon test between Supervised and SupCon: p-value = 1.2308903503712669e-10
# Wilcoxon test between SimCLR and SupCon: p-value = 3.234613192485233e-09
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 95.06878306878299, p_value = 2.2702623976322335e-21)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.24952878352312e-15
# Wilcoxon test between Supervised and SupCon: p-value = 2.2248007181813592e-10
# Wilcoxon test between SimCLR and SupCon: p-value = 1.79862778016625e-09
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 140.10741687979532, p_value = 3.767567029692891e-31)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0841898318038651e-17
# Wilcoxon test between Supervised and SupCon: p-value = 2.1398187143117397e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 9.445412543104902e-11
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 120.9642857142858, p_value = 5.406785039777075e-27)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0814180483893503e-17
# Wilcoxon test between Supervised and SupCon: p-value = 8.345101596609634e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 7.939946132396212e-10
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 134.64615384615382, p_value = 5.780417238926634e-30)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.312098855198657e-17
# Wilcoxon test between Supervised and SupCon: p-value = 2.2808525915851034e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 7.663476132034105e-13
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 148.37851662404088, p_value = 6.0257970240862345e-33)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.2534620532712685e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 4.192272148292378e-15
# Wilcoxon test between Supervised and SupCon: p-value = 2.8246311590874347e-13
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 124.39583333333341, p_value = 9.722725079635424e-28)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.609858397427885e-16
# Wilcoxon test between Supervised and SupCon: p-value = 4.300537564347609e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 2.44375330997257e-06
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 124.37894736842115, p_value = 9.805161391377158e-28)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.0648075623148787e-16
# Wilcoxon test between Supervised and SupCon: p-value = 1.158488624041184e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 3.7849833730639564e-06
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 153.34715025906738, p_value = 5.024460235043368e-34)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.063261657116674e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.891254574649758e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 5.73274319226446e-06
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 135.25130890052353, p_value = 4.271215040441224e-30)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.466829321177548e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.551228883533796e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 1.0289673676975021e-07
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 106.11609498680747, p_value = 9.06113817417652e-24)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 6.514692547217285e-16
# Wilcoxon test between Supervised and SupCon: p-value = 4.1183669188765767e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 0.19902179331622127
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 91.44444444444441, p_value = 1.3902445093201967e-20)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SupCon: p-value = 1.7751863711957122e-15
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1828610528487894e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 0.07564101966968788
# [array([15.9 , 23.96, 32.58, 40.4 , 46.15, 50.89, 55.85, 60.72, 64.85,
#        69.02, 71.65, 74.83, 76.69, 78.49, 80.24]), array([19.28, 28.94, 40.68, 47.37, 53.03, 60.28, 66.38, 70.45, 73.8 ,
#        75.95, 78.58, 82.67, 83.48, 84.41, 85.39]), array([19.61, 26.39, 37.57, 44.46, 50.07, 56.42, 61.6 , 65.12, 69.01,
#        73.59, 76.87, 81.07, 81.66, 84.04, 84.84])]
# Analysing data from 85 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 38.43258426966284, p_value = 4.5130522665747355e-09)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.4464259418510956e-10
# Wilcoxon test between Supervised and SupCon: p-value = 8.707012851276434e-09
# Wilcoxon test between SimCLR and SupCon: p-value = 0.1860620773189805
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 52.088772845953, p_value = 4.8872740445665215e-12)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SupCon: p-value = 1.5022856504690507e-16
# Wilcoxon test between Supervised and SimCLR: p-value = 4.67640650395904e-07
# Wilcoxon test between SimCLR and SupCon: p-value = 0.7219039409815071
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 103.20942408376969, p_value = 3.8757728844871905e-23)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SupCon: p-value = 5.36853027412934e-16
# Wilcoxon test between Supervised and SimCLR: p-value = 2.3161443829552826e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 1.0769732231223113e-06
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 81.85789473684221, p_value = 1.6779692885630534e-18)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.713343198613196e-17
# Wilcoxon test between Supervised and SupCon: p-value = 7.369567531431141e-09
# Wilcoxon test between SimCLR and SupCon: p-value = 0.00029349907698407495
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 164.734375, p_value = 1.6919400815908883e-36)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0056478085170678e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.171018618574631e-16
# Wilcoxon test between Supervised and SupCon: p-value = 1.740695851600174e-13
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 127.81912144702838, p_value = 1.7556196654409718e-28)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.841568691003724e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 2.2060606754232476e-15
# Wilcoxon test between Supervised and SupCon: p-value = 2.428568026248969e-05
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 81.27225130890054, p_value = 2.248820866335045e-18)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.17076568139784e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 3.83625917991583e-08
# Wilcoxon test between Supervised and SupCon: p-value = 7.673459760941692e-07
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 113.95755968169759, p_value = 1.7965128565741367e-25)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 8.810028493581308e-16
# Wilcoxon test between Supervised and SupCon: p-value = 2.707637646955176e-12
# Wilcoxon test between SimCLR and SupCon: p-value = 2.5389353746847817e-11
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 96.85245901639357, p_value = 9.305843513944002e-22)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and SupCon: p-value = 3.3366253897402344e-15
# Wilcoxon test between Supervised and SimCLR: p-value = 3.335651846551633e-14
# Wilcoxon test between Supervised and SupCon: p-value = 1.3479469755426676e-06
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 98.92800000000013, p_value = 3.296535425360804e-22)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 6.938972574057729e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.1600359818238813e-12
# Wilcoxon test between SimCLR and SupCon: p-value = 1.0656542159558568e-05
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 119.83202099737544, p_value = 9.523734127221311e-27)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SupCon: p-value = 4.197889780632291e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 2.015565201912636e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 0.09036038399539349
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 149.22955145118732, p_value = 3.937446210408686e-33)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.3614310797336736e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.1310592274118225e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 0.001663728212235045
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 120.45125348189417, p_value = 6.98783492876062e-27)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 8.445693811026013e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 3.538130142470198e-10
# Wilcoxon test between Supervised and SupCon: p-value = 4.590029715502456e-08
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 106.37900874635571, p_value = 7.944960741393508e-24)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.273656631890553e-16
# Wilcoxon test between Supervised and SupCon: p-value = 1.5382690278915896e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 0.00013887564727353767
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 116.42541436464089, p_value = 5.23049142053853e-26)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SupCon: p-value = 3.932275462665943e-16
# Wilcoxon test between Supervised and SimCLR: p-value = 3.009218178348505e-11
# Wilcoxon test between SimCLR and SupCon: p-value = 4.6080618777121997e-10
# [array([18.16, 25.34, 36.45, 44.38, 50.47, 55.88, 59.46, 65.83, 69.05,
#        72.67, 76.25, 79.82, 81.7 , 83.09, 83.03]), array([19.91, 29.27, 44.03, 48.53, 56.01, 62.17, 67.99, 72.1 , 74.74,
#        77.66, 79.92, 84.31, 84.55, 86.75, 85.8 ]), array([20.42, 29.38, 40.23, 47.17, 53.  , 57.94, 63.17, 67.77, 70.45,
#        75.66, 80.38, 83.57, 83.16, 86.12, 87.03])]

# %% [markdown]
# ### EEG-Inception Results

# %%
file_paths = [
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/Supervised_results/EEGInception_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SimCLR_results/EEGInception_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SupCon_results/EEGInception_1CLS_50Folfd_evaluation_results.txt')
]
process_results.get_differences(file_paths, 'EEGInception', retraining_chars=[1, 5, 10, 25, 40, 85], dataset='BCI')
# Out:
# ALL SUBJECTS
#
# Analysing data from 1 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 9.0416666666667, p_value = 0.010879953262024768)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SupCon and Supervised: p-value = 0.0034131288870483415: diff -> 2.65 - 3.54 = -0.89
# Wilcoxon test between SupCon and SimCLR: p-value = 0.05095397888935817: diff -> 2.65 - 3.18 = -0.53
# Wilcoxon test between SimCLR and Supervised: p-value = 0.16304072606512898: diff -> 3.18 - 3.54 = -0.36
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 20.365650969529206, p_value = 3.781421435962512e-05)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SupCon and Supervised: p-value = 0.00018626724380297097: diff -> 2.94 - 4.09 = -1.15
# Wilcoxon test between SimCLR and Supervised: p-value = 0.0006853142402131185: diff -> 3.01 - 4.09 = -1.08
# Wilcoxon test between SupCon and SimCLR: p-value = 0.5688861723316183: diff -> 2.94 - 3.01 = -0.07
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 26.215297450424917, p_value = 2.0296468913015204e-06)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.48690843818198e-06: diff -> 3.14 - 4.48 = -1.34
# Wilcoxon test between SupCon and Supervised: p-value = 6.166223250089466e-06: diff -> 3.07 - 4.48 = -1.41
# Wilcoxon test between SupCon and SimCLR: p-value = 0.6202274105911909: diff -> 3.07 - 3.14 = -0.07
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 11.405555555555667, p_value = 0.0033366840058511506)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.0004998245502167094: diff -> 3.05 - 4.39 = -1.34
# Wilcoxon test between SupCon and Supervised: p-value = 0.0013213149963139435: diff -> 3.21 - 4.39 = -1.18
# Wilcoxon test between SupCon and SimCLR: p-value = 0.4258292817788436: diff -> 3.21 - 3.05 = 0.16
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 15.907356948228912, p_value = 0.0003513672890278099)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.536696551074166e-06: diff -> 2.94 - 4.61 = -1.67
# Wilcoxon test between SupCon and Supervised: p-value = 0.00020601646052146103: diff -> 3.23 - 4.61 = -1.38
# Wilcoxon test between SupCon and SimCLR: p-value = 0.23724896909679938: diff -> 3.23 - 2.94 = 0.29
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 17.152815013404954, p_value = 0.0001885009508668466)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.5615685698276747e-06: diff -> 2.86 - 4.73 = -1.87
# Wilcoxon test between SupCon and Supervised: p-value = 0.0010865763449507094: diff -> 3.43 - 4.73 = -1.30
# Wilcoxon test between SupCon and SimCLR: p-value = 0.03096334405204873: diff -> 3.43 - 2.86 = 0.57
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 22.16666666666668, p_value = 1.536630652687558e-05)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.078280579142611e-07: diff -> 3.25 - 5.12 = -1.87
# Wilcoxon test between SupCon and Supervised: p-value = 0.00024537051570218226: diff -> 3.50 - 5.12 = -1.62
# Wilcoxon test between SupCon and SimCLR: p-value = 0.38678410361594134: diff -> 3.50 - 3.25 = 0.25
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 21.85245901639357, p_value = 1.7980377956590237e-05)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 7.529717178931006e-06: diff -> 3.29 - 5.47 = -2.18
# Wilcoxon test between SupCon and Supervised: p-value = 0.0005228823842941188: diff -> 3.69 - 5.47 = -1.78
# Wilcoxon test between SupCon and SimCLR: p-value = 0.10567875514229798: diff -> 3.69 - 3.29 = 0.40
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 26.075067024128746, p_value = 2.1770637078927465e-06)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.984637838058691e-06: diff -> 3.31 - 5.75 = -2.44
# Wilcoxon test between SupCon and Supervised: p-value = 5.339394952607186e-05: diff -> 3.56 - 5.75 = -2.19
# Wilcoxon test between SupCon and SimCLR: p-value = 0.23854782636561123: diff -> 3.56 - 3.31 = 0.25
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 17.625344352617212, p_value = 0.0001488350106955272)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.202815597763935e-05: diff -> 3.58 - 6.15 = -2.57
# Wilcoxon test between SupCon and Supervised: p-value = 5.022960339202872e-05: diff -> 3.83 - 6.15 = -2.32
# Wilcoxon test between SupCon and SimCLR: p-value = 0.41356007521893784: diff -> 3.83 - 3.58 = 0.25
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 27.286863270777413, p_value = 1.1877715715064319e-06)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 5.207440934170796e-08: diff -> 3.65 - 6.76 = -3.11
# Wilcoxon test between SupCon and Supervised: p-value = 4.756030476378206e-06: diff -> 3.90 - 6.76 = -2.86
# Wilcoxon test between SupCon and SimCLR: p-value = 0.5945620922608661: diff -> 3.90 - 3.65 = 0.25
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 31.099447513812134, p_value = 1.76539046765709e-07)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.9509364382561524e-08: diff -> 3.52 - 7.14 = -3.62
# Wilcoxon test between SupCon and Supervised: p-value = 2.734532147454289e-06: diff -> 3.95 - 7.14 = -3.19
# Wilcoxon test between SupCon and SimCLR: p-value = 0.33897102820462477: diff -> 3.95 - 3.52 = 0.43
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 32.249336870026504, p_value = 9.934487694421698e-08)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.356924703361188e-07: diff -> 3.72 - 7.32 = -3.60
# Wilcoxon test between SupCon and Supervised: p-value = 7.689813907994625e-07: diff -> 3.96 - 7.32 = -3.36
# Wilcoxon test between SupCon and SimCLR: p-value = 0.685795700602454: diff -> 3.96 - 3.72 = 0.24
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 35.46666666666675, p_value = 1.9884340325140453e-08)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 7.926399403417031e-08: diff -> 3.94 - 7.89 = -3.95
# Wilcoxon test between SupCon and Supervised: p-value = 1.474312447482376e-07: diff -> 4.04 - 7.89 = -3.85
# Wilcoxon test between SupCon and SimCLR: p-value = 0.9390269915688827: diff -> 4.04 - 3.94 = 0.10
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 21.650537634408593, p_value = 1.98904902526554e-05)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.994392483031175e-06: diff -> 4.07 - 8.13 = -4.06
# Wilcoxon test between SupCon and Supervised: p-value = 3.6108882393728197e-06: diff -> 4.21 - 8.13 = -3.92
# Wilcoxon test between SupCon and SimCLR: p-value = 0.9683204402783187: diff -> 4.21 - 4.07 = 0.14
#
#  ALL SUBJECTS Differences 1: {'SimCLR': [-1.08, -1.3400000000000003, -1.3399999999999999, -1.6700000000000004, -1.8700000000000006, -1.87, -2.1799999999999997, -2.44, -2.5700000000000003, -3.11, -3.6199999999999997, -3.6, -3.9499999999999997, -4.0600000000000005], 'SupCon': [-0.8900000000000001, -1.15, -1.4100000000000006, -1.1799999999999997, -1.3800000000000003, -1.3000000000000003, -1.62, -1.7799999999999998, -2.19, -2.3200000000000003, -2.86, -3.1899999999999995, -3.3600000000000003, -3.8499999999999996, -3.920000000000001]}
#
# Average Difference: (-2.48, -2.16)
#
# Analysing data from 5 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 10.526011560693663, p_value = 0.005179712219439351)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.0023033172806275664: diff -> 3.33 - 4.30 = -0.97
# Wilcoxon test between SupCon and Supervised: p-value = 0.00840077716101913: diff -> 3.47 - 4.30 = -0.83
# Wilcoxon test between SupCon and SimCLR: p-value = 0.6188814024860307: diff -> 3.47 - 3.33 = 0.14
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 34.10555555555548, p_value = 3.9271067788544376e-08)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.2536200219766135e-08: diff -> 3.53 - 5.70 = -2.17
# Wilcoxon test between SupCon and Supervised: p-value = 3.6278038943860825e-05: diff -> 3.97 - 5.70 = -1.73
# Wilcoxon test between SupCon and SimCLR: p-value = 0.2667831152249771: diff -> 3.97 - 3.53 = 0.44
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 66.62337662337663, p_value = 3.41128169128042e-15)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0810970163530061e-13: diff -> 3.24 - 7.06 = -3.82
# Wilcoxon test between SupCon and Supervised: p-value = 1.4529190536100008e-08: diff -> 4.54 - 7.06 = -2.52
# Wilcoxon test between SupCon and SimCLR: p-value = 4.8481890881561697e-05: diff -> 4.54 - 3.24 = 1.30
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 72.86702127659588, p_value = 1.5035828844666132e-16)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.599506142391831e-13: diff -> 3.45 - 7.77 = -4.32
# Wilcoxon test between SupCon and Supervised: p-value = 2.876633414494413e-10: diff -> 4.70 - 7.77 = -3.07
# Wilcoxon test between SupCon and SimCLR: p-value = 5.62786230950408e-05: diff -> 4.70 - 3.45 = 1.25
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 56.691099476439895, p_value = 4.894227604100923e-13)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.921914498126445e-12: diff -> 3.70 - 8.10 = -4.40
# Wilcoxon test between SupCon and Supervised: p-value = 1.9746500490405983e-07: diff -> 5.41 - 8.10 = -2.69
# Wilcoxon test between SupCon and SimCLR: p-value = 2.488528044514024e-05: diff -> 5.41 - 3.70 = 1.71
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 59.69272237196766, p_value = 1.0911640071779735e-13)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 6.538359539606438e-13: diff -> 3.59 - 8.91 = -5.32
# Wilcoxon test between SupCon and SimCLR: p-value = 5.140816156920797e-08: diff -> 5.92 - 3.59 = 2.33
# Wilcoxon test between SupCon and Supervised: p-value = 8.350065074534921e-07: diff -> 5.92 - 8.91 = -2.99
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 68.83377308707126, p_value = 1.1296296677727227e-15)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.9568538445969944e-13: diff -> 3.78 - 10.54 = -6.76
# Wilcoxon test between SupCon and Supervised: p-value = 1.066194887434303e-08: diff -> 6.22 - 10.54 = -4.32
# Wilcoxon test between SupCon and SimCLR: p-value = 7.196454055653897e-08: diff -> 6.22 - 3.78 = 2.44
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 90.40750670241293, p_value = 2.3348520066777706e-20)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.686271313192323e-15: diff -> 3.91 - 12.21 = -8.30
# Wilcoxon test between SupCon and Supervised: p-value = 5.885321310388946e-11: diff -> 6.55 - 12.21 = -5.66
# Wilcoxon test between SupCon and SimCLR: p-value = 2.0039943075731275e-08: diff -> 6.55 - 3.91 = 2.64
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 81.92592592592601, p_value = 1.6218520077456218e-18)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 5.985375264501597e-14: diff -> 4.02 - 12.58 = -8.56
# Wilcoxon test between SupCon and Supervised: p-value = 2.336145739916809e-10: diff -> 6.70 - 12.58 = -5.88
# Wilcoxon test between SupCon and SimCLR: p-value = 5.6244129049925944e-08: diff -> 6.70 - 4.02 = 2.68
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 60.594315245478036, p_value = 6.952029832587434e-14)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.3007492417367522e-14: diff -> 4.35 - 13.42 = -9.07
# Wilcoxon test between SupCon and Supervised: p-value = 3.192393994862174e-10: diff -> 7.12 - 13.42 = -6.30
# Wilcoxon test between SupCon and SimCLR: p-value = 1.863756171398975e-07: diff -> 7.12 - 4.35 = 2.77
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 77.16279069767438, p_value = 1.755144574331873e-17)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.528665172326807e-15: diff -> 4.28 - 13.92 = -9.64
# Wilcoxon test between SupCon and Supervised: p-value = 4.510095556289425e-10: diff -> 7.35 - 13.92 = -6.57
# Wilcoxon test between SupCon and SimCLR: p-value = 4.270957167563032e-08: diff -> 7.35 - 4.28 = 3.07
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 72.65608465608474, p_value = 1.670827745905215e-16)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.327122122325397e-14: diff -> 4.72 - 15.24 = -10.52
# Wilcoxon test between SupCon and Supervised: p-value = 2.4731717884029205e-11: diff -> 7.51 - 15.24 = -7.73
# Wilcoxon test between SupCon and SimCLR: p-value = 2.077904466827319e-06: diff -> 7.51 - 4.72 = 2.79
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 82.57068062827227, p_value = 1.1749097777526931e-18)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.1222801497456505e-14: diff -> 4.80 - 16.60 = -11.80
# Wilcoxon test between SupCon and Supervised: p-value = 3.726835047815208e-11: diff -> 8.00 - 16.60 = -8.60
# Wilcoxon test between SupCon and SimCLR: p-value = 4.889421538131313e-08: diff -> 8.00 - 4.80 = 3.20
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 84.03636363636363, p_value = 5.645930096593956e-19)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.787009888293507e-14: diff -> 5.15 - 17.22 = -12.07
# Wilcoxon test between SupCon and Supervised: p-value = 6.807141487797916e-11: diff -> 8.52 - 17.22 = -8.70
# Wilcoxon test between SupCon and SimCLR: p-value = 7.459195759606844e-09: diff -> 8.52 - 5.15 = 3.37
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 78.31937172774877, p_value = 9.843839322519186e-18)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.2977062819233173e-14: diff -> 5.22 - 18.86 = -13.64
# Wilcoxon test between SupCon and Supervised: p-value = 1.5965855077435372e-12: diff -> 8.74 - 18.86 = -10.12
# Wilcoxon test between SupCon and SimCLR: p-value = 1.0060280323748341e-08: diff -> 8.74 - 5.22 = 3.52
#
#  ALL SUBJECTS Differences 5: {'SimCLR': [-0.9699999999999998, -2.1700000000000004, -3.8199999999999994, -4.319999999999999, -4.3999999999999995, -5.32, -6.76, -8.3, -8.56, -9.07, -9.64, -10.52, -11.8, -12.069999999999999, -13.64], 'SupCon': [-0.8299999999999996, -1.73, -2.5199999999999996, -3.0699999999999994, -2.6899999999999995, -2.99, -4.319999999999999, -5.660000000000001, -5.88, -6.3, -6.57, -7.73, -8.600000000000001, -8.7, -10.12]}
#
# Average Difference: (-7.42, -5.18)
#
# Analysing data from 10 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 6.224719101123554, p_value = 0.044495841190889104)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.02163504903707755: diff -> 4.03 - 4.84 = -0.81
# Wilcoxon test between SupCon and Supervised: p-value = 0.28020757204446356: diff -> 4.41 - 4.84 = -0.43
# Wilcoxon test between SupCon and SimCLR: p-value = 0.21112858443730254: diff -> 4.41 - 4.03 = 0.38
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 44.28342245989302, p_value = 2.4209007943866995e-10)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.7280781333348417e-11: diff -> 3.69 - 6.90 = -3.21
# Wilcoxon test between SupCon and Supervised: p-value = 1.455101300138707e-05: diff -> 5.07 - 6.90 = -1.83
# Wilcoxon test between SupCon and SimCLR: p-value = 0.0001685802435116584: diff -> 5.07 - 3.69 = 1.38
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 88.73544973544976, p_value = 5.386937233506964e-20)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.973260116242215e-15: diff -> 3.92 - 9.15 = -5.23
# Wilcoxon test between SupCon and Supervised: p-value = 1.7568274709821194e-08: diff -> 6.09 - 9.15 = -3.06
# Wilcoxon test between SupCon and SimCLR: p-value = 4.0283753878580507e-08: diff -> 6.09 - 3.92 = 2.17
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 100.6632390745501, p_value = 1.3843801697401735e-22)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1924418234725473e-15: diff -> 4.44 - 10.52 = -6.08
# Wilcoxon test between SupCon and Supervised: p-value = 6.818872087210178e-11: diff -> 6.33 - 10.52 = -4.19
# Wilcoxon test between SupCon and SimCLR: p-value = 1.4526209504299423e-05: diff -> 6.33 - 4.44 = 1.89
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 95.51706036745409, p_value = 1.8144035101355004e-21)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 6.543515751532908e-16: diff -> 4.53 - 12.20 = -7.67
# Wilcoxon test between SupCon and Supervised: p-value = 2.439595321865583e-12: diff -> 7.05 - 12.20 = -5.15
# Wilcoxon test between SupCon and SimCLR: p-value = 6.27524117015653e-08: diff -> 7.05 - 4.53 = 2.52
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 101.93861892583118, p_value = 7.316614170462271e-23)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.784685188454486e-16: diff -> 4.93 - 13.96 = -9.03
# Wilcoxon test between SupCon and Supervised: p-value = 1.8246988541135626e-12: diff -> 7.90 - 13.96 = -6.06
# Wilcoxon test between SupCon and SimCLR: p-value = 1.513750689374731e-08: diff -> 7.90 - 4.93 = 2.97
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 117.54755784061702, p_value = 2.9845037870646386e-26)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.6079105292731427e-16: diff -> 4.86 - 15.76 = -10.90
# Wilcoxon test between SupCon and Supervised: p-value = 1.8168471757659325e-13: diff -> 8.31 - 15.76 = -7.45
# Wilcoxon test between SupCon and SimCLR: p-value = 2.0465360105820585e-09: diff -> 8.31 - 4.86 = 3.45
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 116.03053435114504, p_value = 6.372202952864902e-26)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.0809019165322074e-17: diff -> 5.38 - 17.83 = -12.45
# Wilcoxon test between SupCon and Supervised: p-value = 2.4088551809688515e-14: diff -> 9.29 - 17.83 = -8.54
# Wilcoxon test between SupCon and SimCLR: p-value = 6.416552991115624e-10: diff -> 9.29 - 5.38 = 3.91
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 126.36734693877543, p_value = 3.6281001421370823e-28)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.775879859606142e-17: diff -> 5.62 - 19.49 = -13.87
# Wilcoxon test between SupCon and Supervised: p-value = 1.883692951053612e-15: diff -> 9.30 - 19.49 = -10.19
# Wilcoxon test between SupCon and SimCLR: p-value = 9.60168394079058e-10: diff -> 9.30 - 5.62 = 3.68
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 126.83969465648866, p_value = 2.8649052429017765e-28)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.924559738193209e-17: diff -> 5.85 - 20.84 = -14.99
# Wilcoxon test between SupCon and Supervised: p-value = 5.245815138202948e-15: diff -> 10.33 - 20.84 = -10.51
# Wilcoxon test between SupCon and SimCLR: p-value = 3.829954724601351e-10: diff -> 10.33 - 5.85 = 4.48
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 128.02035623409665, p_value = 1.5875699071020588e-28)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 5.3709387473944394e-17: diff -> 6.14 - 22.72 = -16.58
# Wilcoxon test between SupCon and Supervised: p-value = 2.234942079727039e-14: diff -> 10.71 - 22.72 = -12.01
# Wilcoxon test between SupCon and SimCLR: p-value = 7.694741865802701e-11: diff -> 10.71 - 6.14 = 4.57
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 116.40609137055846, p_value = 5.281270704878138e-26)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 6.235899635487183e-17: diff -> 6.42 - 24.60 = -18.18
# Wilcoxon test between SupCon and Supervised: p-value = 6.287558191409537e-15: diff -> 11.66 - 24.60 = -12.94
# Wilcoxon test between SupCon and SimCLR: p-value = 4.4493101374895556e-10: diff -> 11.66 - 6.42 = 5.24
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 119.77551020408174, p_value = 9.796668792892764e-27)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.930355746901731e-17: diff -> 6.84 - 26.03 = -19.19
# Wilcoxon test between SupCon and Supervised: p-value = 1.1833466156918923e-14: diff -> 12.51 - 26.03 = -13.52
# Wilcoxon test between SupCon and SimCLR: p-value = 1.476031068781204e-10: diff -> 12.51 - 6.84 = 5.67
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 115.30632911392405, p_value = 9.152690327034923e-26)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 5.2964121133434066e-17: diff -> 7.58 - 27.71 = -20.13
# Wilcoxon test between SupCon and Supervised: p-value = 4.07873733537262e-14: diff -> 13.73 - 27.71 = -13.98
# Wilcoxon test between SupCon and SimCLR: p-value = 4.599490238655587e-10: diff -> 13.73 - 7.58 = 6.15
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 119.65656565656569, p_value = 1.0396972755326764e-26)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.2437169738452535e-17: diff -> 7.27 - 30.07 = -22.80
# Wilcoxon test between SupCon and Supervised: p-value = 6.4874666781827495e-15: diff -> 13.59 - 30.07 = -16.48
# Wilcoxon test between SupCon and SimCLR: p-value = 1.4656883948023974e-10: diff -> 13.59 - 7.27 = 6.32
#
#  ALL SUBJECTS Differences 10: {'SimCLR': [-0.8099999999999996, -3.2100000000000004, -5.23, -6.079999999999999, -7.669999999999999, -9.030000000000001, -10.899999999999999, -12.45, -13.869999999999997, -14.99, -16.58, -18.18, -19.19, -20.130000000000003, -22.8], 'SupCon': [-1.83, -3.0600000000000005, -4.1899999999999995, -5.1499999999999995, -6.0600000000000005, -7.449999999999999, -8.54, -10.189999999999998, -10.51, -12.009999999999998, -12.940000000000001, -13.520000000000001, -13.98, -16.48]}
#
# Average Difference: (-12.07, -8.99)
#
# Analysing data from 25 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 7.3850415512464975, p_value = 0.024909132501558146)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SupCon and SimCLR: p-value = 0.0025927595549961745: diff -> 5.79 - 4.68 = 1.11
# Wilcoxon test between SimCLR and Supervised: p-value = 0.009531043800300773: diff -> 4.68 - 5.49 = -0.81
# Wilcoxon test between SupCon and Supervised: p-value = 0.4213156611325224: diff -> 5.79 - 5.49 = 0.30
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 60.7093333333333, p_value = 6.563504187439944e-14)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.006196721955892e-12: diff -> 4.90 - 8.30 = -3.40
# Wilcoxon test between SupCon and Supervised: p-value = 1.2242630639448771e-06: diff -> 6.49 - 8.30 = -1.81
# Wilcoxon test between SupCon and SimCLR: p-value = 0.00016773561463548264: diff -> 6.49 - 4.90 = 1.59
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 127.4233766233766, p_value = 2.1397613243688263e-28)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.462067155268486e-17: diff -> 4.95 - 11.99 = -7.04
# Wilcoxon test between SupCon and SimCLR: p-value = 3.0449561663570804e-13: diff -> 8.93 - 4.95 = 3.98
# Wilcoxon test between SupCon and Supervised: p-value = 6.57000051939352e-11: diff -> 8.93 - 11.99 = -3.06
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 133.62886597938157, p_value = 9.613033174971142e-30)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1746687309530195e-17: diff -> 5.63 - 13.96 = -8.33
# Wilcoxon test between SupCon and SimCLR: p-value = 2.5160840655248958e-11: diff -> 9.78 - 5.63 = 4.15
# Wilcoxon test between SupCon and Supervised: p-value = 2.6310696091143602e-11: diff -> 9.78 - 13.96 = -4.18
#
# N Trials -> 5
#
# Is data Normally Distributed? - True
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 151.87146529562975, p_value = 1.0508248434747605e-33)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1403068176752403e-17: diff -> 6.16 - 16.54 = -10.38
# Wilcoxon test between SupCon and Supervised: p-value = 3.1956138481053766e-15: diff -> 11.16 - 16.54 = -5.38
# Wilcoxon test between SupCon and SimCLR: p-value = 2.7098624398269765e-13: diff -> 11.16 - 6.16 = 5.00
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 156.8071065989847, p_value = 8.907779136932063e-35)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.607010251439338e-17: diff -> 6.81 - 19.93 = -13.12
# Wilcoxon test between SupCon and SimCLR: p-value = 9.90536875554769e-16: diff -> 12.86 - 6.81 = 6.05
# Wilcoxon test between SupCon and Supervised: p-value = 7.896454035294254e-16: diff -> 12.86 - 19.93 = -7.07
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 175.41057934508817, p_value = 8.129740093452724e-39)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1190332210554887e-17: diff -> 6.84 - 22.39 = -15.55
# Wilcoxon test between SupCon and Supervised: p-value = 4.9230412399019555e-17: diff -> 14.11 - 22.39 = -8.28
# Wilcoxon test between SupCon and SimCLR: p-value = 7.9066078201617e-17: diff -> 14.11 - 6.84 = 7.27
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 173.80856423173813, p_value = 1.8111308295605853e-38)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.086402422094684e-17: diff -> 7.85 - 24.22 = -16.37
# Wilcoxon test between SupCon and Supervised: p-value = 6.531051159048823e-17: diff -> 14.96 - 24.22 = -9.26
# Wilcoxon test between SupCon and SimCLR: p-value = 2.0170786518029396e-16: diff -> 14.96 - 7.85 = 7.11
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 182.07106598984763, p_value = 2.909178459024059e-40)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1260135469019991e-17: diff -> 7.81 - 26.82 = -19.01
# Wilcoxon test between SupCon and Supervised: p-value = 1.4334397817697367e-17: diff -> 15.15 - 26.82 = -11.67
# Wilcoxon test between SupCon and SimCLR: p-value = 5.978283840426944e-16: diff -> 15.15 - 7.81 = 7.34
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 186.42424242424238, p_value = 3.2998189411026163e-41)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1220741217015956e-17: diff -> 8.18 - 28.99 = -20.81
# Wilcoxon test between SupCon and Supervised: p-value = 1.3432255646901615e-17: diff -> 16.42 - 28.99 = -12.57
# Wilcoxon test between SupCon and SimCLR: p-value = 2.4640908842551366e-17: diff -> 16.42 - 8.18 = 8.24
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 180.24120603015066, p_value = 7.263056201765108e-40)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1393256783863475e-17: diff -> 9.16 - 31.22 = -22.06
# Wilcoxon test between SupCon and Supervised: p-value = 7.935738347348605e-18: diff -> 18.06 - 31.22 = -13.16
# Wilcoxon test between SupCon and SimCLR: p-value = 2.030486699102669e-16: diff -> 18.06 - 9.16 = 8.90
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 184.9319899244333, p_value = 6.958708178202659e-41)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1357912075247191e-17: diff -> 9.74 - 33.43 = -23.69
# Wilcoxon test between SupCon and Supervised: p-value = 1.8880764531131766e-17: diff -> 19.88 - 33.43 = -13.55
# Wilcoxon test between SupCon and SimCLR: p-value = 4.722623657553061e-17: diff -> 19.88 - 9.74 = 10.14
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 184.3800000000001, p_value = 9.170472510063194e-41)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1347649511484582e-17: diff -> 10.70 - 35.94 = -25.24
# Wilcoxon test between SupCon and Supervised: p-value = 1.2945182799391897e-17: diff -> 20.92 - 35.94 = -15.02
# Wilcoxon test between SupCon and SimCLR: p-value = 2.1560396593435253e-17: diff -> 20.92 - 10.70 = 10.22
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 182.37185929648246, p_value = 2.5029601001726507e-40)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1274145563797569e-17: diff -> 11.70 - 39.25 = -27.55
# Wilcoxon test between SupCon and Supervised: p-value = 6.4318326585682305e-18: diff -> 22.35 - 39.25 = -16.90
# Wilcoxon test between SupCon and SimCLR: p-value = 1.291132789943949e-16: diff -> 22.35 - 11.70 = 10.65
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 187.7744360902256, p_value = 1.679961317148236e-41)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1457140163230534e-17: diff -> 11.49 - 41.75 = -30.26
# Wilcoxon test between SupCon and Supervised: p-value = 6.266824885438391e-18: diff -> 23.26 - 41.75 = -18.49
# Wilcoxon test between SupCon and SimCLR: p-value = 3.746082523745798e-17: diff -> 23.26 - 11.49 = 11.77
#
#  ALL SUBJECTS Differences 25: {'SimCLR': [-0.8100000000000005, -3.4000000000000004, -7.04, -8.330000000000002, -10.379999999999999, -13.120000000000001, -15.55, -16.369999999999997, -19.01, -20.81, -22.06, -23.689999999999998, -25.24, -27.55, -30.259999999999998], 'SupCon': [-1.8100000000000005, -3.0600000000000005, -4.1800000000000015, -5.379999999999999, -7.07, -8.280000000000001, -9.259999999999998, -11.67, -12.569999999999997, -13.16, -13.55, -15.019999999999996, -16.9, -18.49]}
#
# Average Difference: (-16.24, -10.03)
#
# Analysing data from 40 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 32.53591160220987, p_value = 8.608283547266155e-08)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SupCon and SimCLR: p-value = 9.336293656835563e-09: diff -> 6.65 - 4.66 = 1.99
# Wilcoxon test between SimCLR and Supervised: p-value = 5.474143003291982e-05: diff -> 4.66 - 5.96 = -1.30
# Wilcoxon test between SupCon and Supervised: p-value = 0.035159674185406956: diff -> 6.65 - 5.96 = 0.69
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 44.37016574585632, p_value = 2.3181467620814608e-10)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 5.188630804522897e-11: diff -> 5.15 - 8.54 = -3.39
# Wilcoxon test between SupCon and SimCLR: p-value = 5.699758639801772e-08: diff -> 8.25 - 5.15 = 3.10
# Wilcoxon test between SupCon and Supervised: p-value = 0.2759973404530818: diff -> 8.25 - 8.54 = -0.29
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 127.37215189873415, p_value = 2.195273531468e-28)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.932977340930405e-17: diff -> 5.92 - 13.27 = -7.35
# Wilcoxon test between SupCon and SimCLR: p-value = 5.180017151168225e-14: diff -> 11.13 - 5.92 = 5.21
# Wilcoxon test between SupCon and Supervised: p-value = 9.378783650889259e-07: diff -> 11.13 - 13.27 = -2.14
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 137.1670951156812, p_value = 1.6388671352926578e-30)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0328206905889928e-17: diff -> 6.57 - 14.91 = -8.34
# Wilcoxon test between SupCon and SimCLR: p-value = 1.5540723360591787e-15: diff -> 12.71 - 6.57 = 6.14
# Wilcoxon test between SupCon and Supervised: p-value = 1.7266053523754155e-05: diff -> 12.71 - 14.91 = -2.20
#
# N Trials -> 5
#
# Is data Normally Distributed? - True
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 162.2040816326531, p_value = 5.9955800022179224e-36)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0600715096358922e-17: diff -> 7.50 - 18.48 = -10.98
# Wilcoxon test between SupCon and SimCLR: p-value = 1.0032076840944556e-16: diff -> 14.11 - 7.50 = 6.61
# Wilcoxon test between SupCon and Supervised: p-value = 1.3804778408804954e-11: diff -> 14.11 - 18.48 = -4.37
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 183.69849246231152, p_value = 1.2893748501265186e-40)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0996436556040127e-17: diff -> 8.23 - 22.63 = -14.40
# Wilcoxon test between SupCon and SimCLR: p-value = 6.990331701611845e-18: diff -> 16.69 - 8.23 = 8.46
# Wilcoxon test between SupCon and Supervised: p-value = 3.9819697708136773e-16: diff -> 16.69 - 22.63 = -5.94
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 184.26262626262633, p_value = 9.724764579448566e-41)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1104597050567092e-17: diff -> 8.72 - 24.93 = -16.21
# Wilcoxon test between SupCon and SimCLR: p-value = 2.092225007884367e-17: diff -> 17.87 - 8.72 = 9.15
# Wilcoxon test between SupCon and Supervised: p-value = 2.6537029108709658e-17: diff -> 17.87 - 24.93 = -7.06
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 184.0603015075378, p_value = 1.076002694579976e-40)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0811851144057304e-17: diff -> 8.91 - 27.50 = -18.59
# Wilcoxon test between SupCon and SimCLR: p-value = 5.785366861221815e-18: diff -> 18.86 - 8.91 = 9.95
# Wilcoxon test between SupCon and Supervised: p-value = 2.695893768058821e-16: diff -> 18.86 - 27.50 = -8.64
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 193.57894736842107, p_value = 9.222861197475533e-43)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0833918912661127e-17: diff -> 9.35 - 30.33 = -20.98
# Wilcoxon test between SupCon and Supervised: p-value = 5.858971922584559e-18: diff -> 19.39 - 30.33 = -10.94
# Wilcoxon test between SupCon and SimCLR: p-value = 6.8192734160998166e-18: diff -> 19.39 - 9.35 = 10.04
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 194.18000000000006, p_value = 6.828868534581509e-43)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SupCon and Supervised: p-value = 1.1128489565433367e-17: diff -> 20.92 - 33.00 = -12.08
# Wilcoxon test between SimCLR and Supervised: p-value = 5.594217121984118e-18: diff -> 9.81 - 33.00 = -23.19
# Wilcoxon test between SupCon and SimCLR: p-value = 4.686113188165952e-18: diff -> 20.92 - 9.81 = 11.11
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 189.88860759493681, p_value = 5.837310198445588e-42)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1330351365359021e-17: diff -> 11.22 - 35.11 = -23.89
# Wilcoxon test between SupCon and Supervised: p-value = 6.329394201765882e-18: diff -> 22.51 - 35.11 = -12.60
# Wilcoxon test between SupCon and SimCLR: p-value = 3.932535696698119e-17: diff -> 22.51 - 11.22 = 11.29
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 198.06060606060598, p_value = 9.810380516264172e-44)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SupCon and Supervised: p-value = 1.1175788929972723e-17: diff -> 24.58 - 37.73 = -13.15
# Wilcoxon test between SimCLR and Supervised: p-value = 5.699203255053233e-18: diff -> 11.97 - 37.73 = -25.76
# Wilcoxon test between SupCon and SimCLR: p-value = 1.732219936762538e-17: diff -> 24.58 - 11.97 = 12.61
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 194.18000000000006, p_value = 6.828868534581509e-43)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1186536582552876e-17: diff -> 12.96 - 40.07 = -27.11
# Wilcoxon test between SupCon and Supervised: p-value = 5.636117061871365e-18: diff -> 26.34 - 40.07 = -13.73
# Wilcoxon test between SupCon and SimCLR: p-value = 4.923765862084664e-18: diff -> 26.34 - 12.96 = 13.38
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 198.01999999999998, p_value = 1.0011596706425744e-43)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SupCon and Supervised: p-value = 1.1013251067532102e-17: diff -> 29.10 - 43.97 = -14.87
# Wilcoxon test between SimCLR and Supervised: p-value = 5.636117061871365e-18: diff -> 14.20 - 43.97 = -29.77
# Wilcoxon test between SupCon and SimCLR: p-value = 3.94409605754133e-18: diff -> 29.10 - 14.20 = 14.90
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SupCon and Supervised: p-value = 1.1217569960926137e-17: diff -> 30.77 - 45.83 = -15.06
# Wilcoxon test between SupCon and SimCLR: p-value = 5.650149696024605e-18: diff -> 30.77 - 14.28 = 16.49
# Wilcoxon test between SimCLR and Supervised: p-value = 3.829844469015194e-18: diff -> 14.28 - 45.83 = -31.55
#
#  ALL SUBJECTS Differences 40: {'SimCLR': [-1.2999999999999998, -3.389999999999999, -7.35, -8.34, -10.98, -14.399999999999999, -16.21, -18.59, -20.979999999999997, -23.189999999999998, -23.89, -25.759999999999998, -27.11, -29.77, -31.549999999999997], 'SupCon': [0.6900000000000004, -2.139999999999999, -2.1999999999999993, -4.370000000000001, -5.939999999999998, -7.059999999999999, -8.64, -10.939999999999998, -12.079999999999998, -12.599999999999998, -13.149999999999999, -13.73, -14.869999999999997, -15.059999999999999]}
#
# Average Difference: (-17.52, -8.72)
#
# Analysing data from 85 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 23.876675603217265, p_value = 6.535002674641797e-06)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SupCon and Supervised: p-value = 3.044893842218264e-07: diff -> 7.90 - 6.30 = 1.60
# Wilcoxon test between SupCon and SimCLR: p-value = 1.3961639737666852e-06: diff -> 7.90 - 6.31 = 1.59
# Wilcoxon test between SimCLR and Supervised: p-value = 0.9566885457476831: diff -> 6.31 - 6.30 = 0.01
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 31.446927374301655, p_value = 1.4838379843331307e-07)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SupCon and SimCLR: p-value = 4.791598300499296e-08: diff -> 9.08 - 6.23 = 2.85
# Wilcoxon test between SupCon and Supervised: p-value = 2.7018100487853e-07: diff -> 9.08 - 7.94 = 1.14
# Wilcoxon test between SimCLR and Supervised: p-value = 2.671692192225294e-06: diff -> 6.23 - 7.94 = -1.71
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 144.71099744245515, p_value = 3.7705627262630933e-32)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.435755574425174e-18: diff -> 7.44 - 15.30 = -7.86
# Wilcoxon test between SupCon and SimCLR: p-value = 4.5084629394860266e-17: diff -> 14.00 - 7.44 = 6.56
# Wilcoxon test between SupCon and Supervised: p-value = 0.001209322009542858: diff -> 14.00 - 15.30 = -1.30
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 137.84771573604058, p_value = 1.1661350701183531e-30)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.282472635233747e-18: diff -> 7.20 - 15.61 = -8.41
# Wilcoxon test between SupCon and SimCLR: p-value = 2.5441068239134348e-17: diff -> 15.62 - 7.20 = 8.42
# Wilcoxon test between SupCon and Supervised: p-value = 0.9488934390735962: diff -> 15.62 - 15.61 = 0.01
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 158.67519181585678, p_value = 3.500417849228029e-35)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.692523942123804e-18: diff -> 8.91 - 20.40 = -11.49
# Wilcoxon test between SupCon and SimCLR: p-value = 9.184044962851914e-17: diff -> 16.40 - 8.91 = 7.49
# Wilcoxon test between SupCon and Supervised: p-value = 1.2205683839209657e-10: diff -> 16.40 - 20.40 = -4.00
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 180.36775818639808, p_value = 6.817716737395819e-40)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0465104273542908e-17: diff -> 9.19 - 26.14 = -16.95
# Wilcoxon test between SupCon and SimCLR: p-value = 6.338674973428011e-18: diff -> 20.21 - 9.19 = 11.02
# Wilcoxon test between SupCon and Supervised: p-value = 2.4523586277945036e-15: diff -> 20.21 - 26.14 = -5.93
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 180.24120603015066, p_value = 7.263056201765108e-40)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1071980824044484e-17: diff -> 9.90 - 28.00 = -18.10
# Wilcoxon test between SupCon and SimCLR: p-value = 6.728914783504967e-18: diff -> 22.02 - 9.90 = 12.12
# Wilcoxon test between SupCon and Supervised: p-value = 1.5173129639310355e-16: diff -> 22.02 - 28.00 = -5.98
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 178.18781725888334, p_value = 2.0277159206176524e-39)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.454611968107629e-18: diff -> 9.46 - 30.36 = -20.90
# Wilcoxon test between SupCon and SimCLR: p-value = 8.298904453410889e-18: diff -> 23.04 - 9.46 = 13.58
# Wilcoxon test between SupCon and Supervised: p-value = 1.4663064442498264e-14: diff -> 23.04 - 30.36 = -7.32
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 197.50877192982466, p_value = 1.2927516825636133e-43)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SupCon and Supervised: p-value = 1.0996459600602746e-17: diff -> 23.17 - 33.79 = -10.62
# Wilcoxon test between SimCLR and Supervised: p-value = 5.525664596401774e-18: diff -> 10.54 - 33.79 = -23.25
# Wilcoxon test between SupCon and SimCLR: p-value = 5.54217907359093e-18: diff -> 23.17 - 10.54 = 12.63
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SupCon and Supervised: p-value = 1.071732294467035e-17: diff -> 24.93 - 36.06 = -11.13
# Wilcoxon test between SupCon and SimCLR: p-value = 5.567077726301574e-18: diff -> 24.93 - 11.20 = 13.73
# Wilcoxon test between SimCLR and Supervised: p-value = 3.719369416792904e-18: diff -> 11.20 - 36.06 = -24.86
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SupCon and Supervised: p-value = 1.0808789548678864e-17: diff -> 26.57 - 39.37 = -12.80
# Wilcoxon test between SimCLR and Supervised: p-value = 5.574954190123171e-18: diff -> 13.43 - 39.37 = -25.94
# Wilcoxon test between SupCon and SimCLR: p-value = 3.78725426816608e-18: diff -> 26.57 - 13.43 = 13.14
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 199.50375939849633, p_value = 4.767701831604771e-44)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SupCon and Supervised: p-value = 1.0944280242588942e-17: diff -> 28.97 - 41.94 = -12.97
# Wilcoxon test between SimCLR and Supervised: p-value = 5.591687245779589e-18: diff -> 14.42 - 41.94 = -27.52
# Wilcoxon test between SupCon and SimCLR: p-value = 5.529414419313474e-18: diff -> 28.97 - 14.42 = 14.55
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SupCon and Supervised: p-value = 1.0773945403523864e-17: diff -> 31.02 - 43.79 = -12.77
# Wilcoxon test between SimCLR and Supervised: p-value = 5.60339702224086e-18: diff -> 16.09 - 43.79 = -27.70
# Wilcoxon test between SupCon and SimCLR: p-value = 3.786612428399259e-18: diff -> 31.02 - 16.09 = 14.93
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 199.50375939849633, p_value = 4.767701831604771e-44)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SupCon and Supervised: p-value = 1.0939944485500098e-17: diff -> 34.56 - 47.45 = -12.89
# Wilcoxon test between SimCLR and Supervised: p-value = 5.560155165722571e-18: diff -> 16.87 - 47.45 = -30.58
# Wilcoxon test between SupCon and SimCLR: p-value = 5.5109551383366935e-18: diff -> 34.56 - 16.87 = 17.69
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SupCon and Supervised: p-value = 1.0943660748997022e-17: diff -> 37.18 - 49.75 = -12.57
# Wilcoxon test between SupCon and SimCLR: p-value = 5.6892318018728184e-18: diff -> 37.18 - 17.01 = 20.17
# Wilcoxon test between SimCLR and Supervised: p-value = 3.800112742087812e-18: diff -> 17.01 - 49.75 = -32.74
#
#  ALL SUBJECTS Differences 85: {'SimCLR': [-1.71, -7.86, -8.41, -11.489999999999998, -16.950000000000003, -18.1, -20.9, -23.25, -24.860000000000003, -25.939999999999998, -27.519999999999996, -27.7, -30.580000000000002, -32.739999999999995], 'SupCon': [1.6000000000000005, 1.1399999999999997, -1.3000000000000007, -4.0, -5.93, -5.98, -7.32, -10.619999999999997, -11.130000000000003, -12.799999999999997, -12.969999999999999, -12.77, -12.89, -12.57]}
#
# Average Difference: (-19.86, -7.68)

# %%
reload(process_results)
file_paths = [
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/Supervised_results/EEGInception_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SimCLR_results/EEGInception_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SupCon_results/EEGInception_1CLS_50Folfd_evaluation_results.txt')
]
process_results.plot_intra_and_BCI(file_paths, 'EEG-Inception', retraining_chars=[1, 5, 10, 25, 40, 85], 
                                   dataset='BCI', significance_legend_loc = ['upper right', 'upper right', 'upper right', 'upper right', 'upper right', 'upper right'])
# Out:
# Analysing data from 1 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 9.0416666666667, p_value = 0.010879953262024768)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SupCon: p-value = 0.0034131288870483415
# Wilcoxon test between SimCLR and SupCon: p-value = 0.05095397888935817
# Wilcoxon test between Supervised and SimCLR: p-value = 0.16304072606512898
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 20.365650969529206, p_value = 3.781421435962512e-05)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SupCon: p-value = 0.00018626724380297097
# Wilcoxon test between Supervised and SimCLR: p-value = 0.0006853142402131185
# Wilcoxon test between SimCLR and SupCon: p-value = 0.5688861723316183
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 26.215297450424917, p_value = 2.0296468913015204e-06)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.48690843818198e-06
# Wilcoxon test between Supervised and SupCon: p-value = 6.166223250089466e-06
# Wilcoxon test between SimCLR and SupCon: p-value = 0.6202274105911909
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 11.405555555555667, p_value = 0.0033366840058511506)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.0004998245502167094
# Wilcoxon test between Supervised and SupCon: p-value = 0.0013213149963139435
# Wilcoxon test between SimCLR and SupCon: p-value = 0.4258292817788436
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 15.907356948228912, p_value = 0.0003513672890278099)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.536696551074166e-06
# Wilcoxon test between Supervised and SupCon: p-value = 0.00020601646052146103
# Wilcoxon test between SimCLR and SupCon: p-value = 0.23724896909679938
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 17.152815013404954, p_value = 0.0001885009508668466)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.5615685698276747e-06
# Wilcoxon test between Supervised and SupCon: p-value = 0.0010865763449507094
# Wilcoxon test between SimCLR and SupCon: p-value = 0.03096334405204873
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 22.16666666666668, p_value = 1.536630652687558e-05)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.078280579142611e-07
# Wilcoxon test between Supervised and SupCon: p-value = 0.00024537051570218226
# Wilcoxon test between SimCLR and SupCon: p-value = 0.38678410361594134
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 21.85245901639357, p_value = 1.7980377956590237e-05)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 7.529717178931006e-06
# Wilcoxon test between Supervised and SupCon: p-value = 0.0005228823842941188
# Wilcoxon test between SimCLR and SupCon: p-value = 0.10567875514229798
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 26.075067024128746, p_value = 2.1770637078927465e-06)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.984637838058691e-06
# Wilcoxon test between Supervised and SupCon: p-value = 5.339394952607186e-05
# Wilcoxon test between SimCLR and SupCon: p-value = 0.23854782636561123
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 17.625344352617212, p_value = 0.0001488350106955272)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.202815597763935e-05
# Wilcoxon test between Supervised and SupCon: p-value = 5.022960339202872e-05
# Wilcoxon test between SimCLR and SupCon: p-value = 0.41356007521893784
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 27.286863270777413, p_value = 1.1877715715064319e-06)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 5.207440934170796e-08
# Wilcoxon test between Supervised and SupCon: p-value = 4.756030476378206e-06
# Wilcoxon test between SimCLR and SupCon: p-value = 0.5945620922608661
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 31.099447513812134, p_value = 1.76539046765709e-07)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.9509364382561524e-08
# Wilcoxon test between Supervised and SupCon: p-value = 2.734532147454289e-06
# Wilcoxon test between SimCLR and SupCon: p-value = 0.33897102820462477
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 32.249336870026504, p_value = 9.934487694421698e-08)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.356924703361188e-07
# Wilcoxon test between Supervised and SupCon: p-value = 7.689813907994625e-07
# Wilcoxon test between SimCLR and SupCon: p-value = 0.685795700602454
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 35.46666666666675, p_value = 1.9884340325140453e-08)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 7.926399403417031e-08
# Wilcoxon test between Supervised and SupCon: p-value = 1.474312447482376e-07
# Wilcoxon test between SimCLR and SupCon: p-value = 0.9390269915688827
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 21.650537634408593, p_value = 1.98904902526554e-05)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.994392483031175e-06
# Wilcoxon test between Supervised and SupCon: p-value = 3.6108882393728197e-06
# Wilcoxon test between SimCLR and SupCon: p-value = 0.9683204402783187
# [array([3.54, 4.09, 4.48, 4.39, 4.61, 4.73, 5.12, 5.47, 5.75, 6.15, 6.76,
#        7.14, 7.32, 7.89, 8.13]), array([3.18, 3.01, 3.14, 3.05, 2.94, 2.86, 3.25, 3.29, 3.31, 3.58, 3.65,
#        3.52, 3.72, 3.94, 4.07]), array([2.65, 2.94, 3.07, 3.21, 3.23, 3.43, 3.5 , 3.69, 3.56, 3.83, 3.9 ,
#        3.95, 3.96, 4.04, 4.21])]
# Analysing data from 5 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 10.526011560693663, p_value = 0.005179712219439351)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.0023033172806275664
# Wilcoxon test between Supervised and SupCon: p-value = 0.00840077716101913
# Wilcoxon test between SimCLR and SupCon: p-value = 0.6188814024860307
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 34.10555555555548, p_value = 3.9271067788544376e-08)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.2536200219766135e-08
# Wilcoxon test between Supervised and SupCon: p-value = 3.6278038943860825e-05
# Wilcoxon test between SimCLR and SupCon: p-value = 0.2667831152249771
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 66.62337662337663, p_value = 3.41128169128042e-15)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0810970163530061e-13
# Wilcoxon test between Supervised and SupCon: p-value = 1.4529190536100008e-08
# Wilcoxon test between SimCLR and SupCon: p-value = 4.8481890881561697e-05
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 72.86702127659588, p_value = 1.5035828844666132e-16)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.599506142391831e-13
# Wilcoxon test between Supervised and SupCon: p-value = 2.876633414494413e-10
# Wilcoxon test between SimCLR and SupCon: p-value = 5.62786230950408e-05
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 56.691099476439895, p_value = 4.894227604100923e-13)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.921914498126445e-12
# Wilcoxon test between Supervised and SupCon: p-value = 1.9746500490405983e-07
# Wilcoxon test between SimCLR and SupCon: p-value = 2.488528044514024e-05
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 59.69272237196766, p_value = 1.0911640071779735e-13)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 6.538359539606438e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 5.140816156920797e-08
# Wilcoxon test between Supervised and SupCon: p-value = 8.350065074534921e-07
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 68.83377308707126, p_value = 1.1296296677727227e-15)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.9568538445969944e-13
# Wilcoxon test between Supervised and SupCon: p-value = 1.066194887434303e-08
# Wilcoxon test between SimCLR and SupCon: p-value = 7.196454055653897e-08
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 90.40750670241293, p_value = 2.3348520066777706e-20)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.686271313192323e-15
# Wilcoxon test between Supervised and SupCon: p-value = 5.885321310388946e-11
# Wilcoxon test between SimCLR and SupCon: p-value = 2.0039943075731275e-08
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 81.92592592592601, p_value = 1.6218520077456218e-18)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 5.985375264501597e-14
# Wilcoxon test between Supervised and SupCon: p-value = 2.336145739916809e-10
# Wilcoxon test between SimCLR and SupCon: p-value = 5.6244129049925944e-08
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 60.594315245478036, p_value = 6.952029832587434e-14)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.3007492417367522e-14
# Wilcoxon test between Supervised and SupCon: p-value = 3.192393994862174e-10
# Wilcoxon test between SimCLR and SupCon: p-value = 1.863756171398975e-07
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 77.16279069767438, p_value = 1.755144574331873e-17)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.528665172326807e-15
# Wilcoxon test between Supervised and SupCon: p-value = 4.510095556289425e-10
# Wilcoxon test between SimCLR and SupCon: p-value = 4.270957167563032e-08
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 72.65608465608474, p_value = 1.670827745905215e-16)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.327122122325397e-14
# Wilcoxon test between Supervised and SupCon: p-value = 2.4731717884029205e-11
# Wilcoxon test between SimCLR and SupCon: p-value = 2.077904466827319e-06
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 82.57068062827227, p_value = 1.1749097777526931e-18)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.1222801497456505e-14
# Wilcoxon test between Supervised and SupCon: p-value = 3.726835047815208e-11
# Wilcoxon test between SimCLR and SupCon: p-value = 4.889421538131313e-08
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 84.03636363636363, p_value = 5.645930096593956e-19)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.787009888293507e-14
# Wilcoxon test between Supervised and SupCon: p-value = 6.807141487797916e-11
# Wilcoxon test between SimCLR and SupCon: p-value = 7.459195759606844e-09
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 78.31937172774877, p_value = 9.843839322519186e-18)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.2977062819233173e-14
# Wilcoxon test between Supervised and SupCon: p-value = 1.5965855077435372e-12
# Wilcoxon test between SimCLR and SupCon: p-value = 1.0060280323748341e-08
# [array([ 4.3 ,  5.7 ,  7.06,  7.77,  8.1 ,  8.91, 10.54, 12.21, 12.58,
#        13.42, 13.92, 15.24, 16.6 , 17.22, 18.86]), array([3.33, 3.53, 3.24, 3.45, 3.7 , 3.59, 3.78, 3.91, 4.02, 4.35, 4.28,
#        4.72, 4.8 , 5.15, 5.22]), array([3.47, 3.97, 4.54, 4.7 , 5.41, 5.92, 6.22, 6.55, 6.7 , 7.12, 7.35,
#        7.51, 8.  , 8.52, 8.74])]
# Analysing data from 10 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 6.224719101123554, p_value = 0.044495841190889104)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.02163504903707755
# Wilcoxon test between Supervised and SupCon: p-value = 0.28020757204446356
# Wilcoxon test between SimCLR and SupCon: p-value = 0.21112858443730254
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 44.28342245989302, p_value = 2.4209007943866995e-10)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.7280781333348417e-11
# Wilcoxon test between Supervised and SupCon: p-value = 1.455101300138707e-05
# Wilcoxon test between SimCLR and SupCon: p-value = 0.0001685802435116584
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 88.73544973544976, p_value = 5.386937233506964e-20)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.973260116242215e-15
# Wilcoxon test between Supervised and SupCon: p-value = 1.7568274709821194e-08
# Wilcoxon test between SimCLR and SupCon: p-value = 4.0283753878580507e-08
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 100.6632390745501, p_value = 1.3843801697401735e-22)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1924418234725473e-15
# Wilcoxon test between Supervised and SupCon: p-value = 6.818872087210178e-11
# Wilcoxon test between SimCLR and SupCon: p-value = 1.4526209504299423e-05
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 95.51706036745409, p_value = 1.8144035101355004e-21)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 6.543515751532908e-16
# Wilcoxon test between Supervised and SupCon: p-value = 2.439595321865583e-12
# Wilcoxon test between SimCLR and SupCon: p-value = 6.27524117015653e-08
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 101.93861892583118, p_value = 7.316614170462271e-23)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.784685188454486e-16
# Wilcoxon test between Supervised and SupCon: p-value = 1.8246988541135626e-12
# Wilcoxon test between SimCLR and SupCon: p-value = 1.513750689374731e-08
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 117.54755784061702, p_value = 2.9845037870646386e-26)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.6079105292731427e-16
# Wilcoxon test between Supervised and SupCon: p-value = 1.8168471757659325e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 2.0465360105820585e-09
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 116.03053435114504, p_value = 6.372202952864902e-26)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.0809019165322074e-17
# Wilcoxon test between Supervised and SupCon: p-value = 2.4088551809688515e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 6.416552991115624e-10
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 126.36734693877543, p_value = 3.6281001421370823e-28)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.775879859606142e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.883692951053612e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 9.60168394079058e-10
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 126.83969465648866, p_value = 2.8649052429017765e-28)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.924559738193209e-17
# Wilcoxon test between Supervised and SupCon: p-value = 5.245815138202948e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 3.829954724601351e-10
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 128.02035623409665, p_value = 1.5875699071020588e-28)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 5.3709387473944394e-17
# Wilcoxon test between Supervised and SupCon: p-value = 2.234942079727039e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 7.694741865802701e-11
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 116.40609137055846, p_value = 5.281270704878138e-26)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 6.235899635487183e-17
# Wilcoxon test between Supervised and SupCon: p-value = 6.287558191409537e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 4.4493101374895556e-10
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 119.77551020408174, p_value = 9.796668792892764e-27)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.930355746901731e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.1833466156918923e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 1.476031068781204e-10
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 115.30632911392405, p_value = 9.152690327034923e-26)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 5.2964121133434066e-17
# Wilcoxon test between Supervised and SupCon: p-value = 4.07873733537262e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 4.599490238655587e-10
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 119.65656565656569, p_value = 1.0396972755326764e-26)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.2437169738452535e-17
# Wilcoxon test between Supervised and SupCon: p-value = 6.4874666781827495e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 1.4656883948023974e-10
# [array([ 4.84,  6.9 ,  9.15, 10.52, 12.2 , 13.96, 15.76, 17.83, 19.49,
#        20.84, 22.72, 24.6 , 26.03, 27.71, 30.07]), array([4.03, 3.69, 3.92, 4.44, 4.53, 4.93, 4.86, 5.38, 5.62, 5.85, 6.14,
#        6.42, 6.84, 7.58, 7.27]), array([ 4.41,  5.07,  6.09,  6.33,  7.05,  7.9 ,  8.31,  9.29,  9.3 ,
#        10.33, 10.71, 11.66, 12.51, 13.73, 13.59])]
# Analysing data from 25 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 7.3850415512464975, p_value = 0.024909132501558146)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and SupCon: p-value = 0.0025927595549961745
# Wilcoxon test between Supervised and SimCLR: p-value = 0.009531043800300773
# Wilcoxon test between Supervised and SupCon: p-value = 0.4213156611325224
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 60.7093333333333, p_value = 6.563504187439944e-14)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.006196721955892e-12
# Wilcoxon test between Supervised and SupCon: p-value = 1.2242630639448771e-06
# Wilcoxon test between SimCLR and SupCon: p-value = 0.00016773561463548264
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 127.4233766233766, p_value = 2.1397613243688263e-28)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.462067155268486e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 3.0449561663570804e-13
# Wilcoxon test between Supervised and SupCon: p-value = 6.57000051939352e-11
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 133.62886597938157, p_value = 9.613033174971142e-30)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1746687309530195e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 2.5160840655248958e-11
# Wilcoxon test between Supervised and SupCon: p-value = 2.6310696091143602e-11
#
# N Trials -> 5
#
# Is data Normally Distributed? - True
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 151.87146529562975, p_value = 1.0508248434747605e-33)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1403068176752403e-17
# Wilcoxon test between Supervised and SupCon: p-value = 3.1956138481053766e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 2.7098624398269765e-13
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 156.8071065989847, p_value = 8.907779136932063e-35)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.607010251439338e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 9.90536875554769e-16
# Wilcoxon test between Supervised and SupCon: p-value = 7.896454035294254e-16
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 175.41057934508817, p_value = 8.129740093452724e-39)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1190332210554887e-17
# Wilcoxon test between Supervised and SupCon: p-value = 4.9230412399019555e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 7.9066078201617e-17
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 173.80856423173813, p_value = 1.8111308295605853e-38)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.086402422094684e-17
# Wilcoxon test between Supervised and SupCon: p-value = 6.531051159048823e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 2.0170786518029396e-16
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 182.07106598984763, p_value = 2.909178459024059e-40)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1260135469019991e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.4334397817697367e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 5.978283840426944e-16
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 186.42424242424238, p_value = 3.2998189411026163e-41)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1220741217015956e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.3432255646901615e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 2.4640908842551366e-17
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 180.24120603015066, p_value = 7.263056201765108e-40)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1393256783863475e-17
# Wilcoxon test between Supervised and SupCon: p-value = 7.935738347348605e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 2.030486699102669e-16
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 184.9319899244333, p_value = 6.958708178202659e-41)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1357912075247191e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.8880764531131766e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 4.722623657553061e-17
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 184.3800000000001, p_value = 9.170472510063194e-41)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1347649511484582e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.2945182799391897e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 2.1560396593435253e-17
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 182.37185929648246, p_value = 2.5029601001726507e-40)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1274145563797569e-17
# Wilcoxon test between Supervised and SupCon: p-value = 6.4318326585682305e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 1.291132789943949e-16
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 187.7744360902256, p_value = 1.679961317148236e-41)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1457140163230534e-17
# Wilcoxon test between Supervised and SupCon: p-value = 6.266824885438391e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 3.746082523745798e-17
# [array([ 5.49,  8.3 , 11.99, 13.96, 16.54, 19.93, 22.39, 24.22, 26.82,
#        28.99, 31.22, 33.43, 35.94, 39.25, 41.75]), array([ 4.68,  4.9 ,  4.95,  5.63,  6.16,  6.81,  6.84,  7.85,  7.81,
#         8.18,  9.16,  9.74, 10.7 , 11.7 , 11.49]), array([ 5.79,  6.49,  8.93,  9.78, 11.16, 12.86, 14.11, 14.96, 15.15,
#        16.42, 18.06, 19.88, 20.92, 22.35, 23.26])]
# Analysing data from 40 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 32.53591160220987, p_value = 8.608283547266155e-08)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and SupCon: p-value = 9.336293656835563e-09
# Wilcoxon test between Supervised and SimCLR: p-value = 5.474143003291982e-05
# Wilcoxon test between Supervised and SupCon: p-value = 0.035159674185406956
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 44.37016574585632, p_value = 2.3181467620814608e-10)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 5.188630804522897e-11
# Wilcoxon test between SimCLR and SupCon: p-value = 5.699758639801772e-08
# Wilcoxon test between Supervised and SupCon: p-value = 0.2759973404530818
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 127.37215189873415, p_value = 2.195273531468e-28)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.932977340930405e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 5.180017151168225e-14
# Wilcoxon test between Supervised and SupCon: p-value = 9.378783650889259e-07
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 137.1670951156812, p_value = 1.6388671352926578e-30)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0328206905889928e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.5540723360591787e-15
# Wilcoxon test between Supervised and SupCon: p-value = 1.7266053523754155e-05
#
# N Trials -> 5
#
# Is data Normally Distributed? - True
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 162.2040816326531, p_value = 5.9955800022179224e-36)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0600715096358922e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.0032076840944556e-16
# Wilcoxon test between Supervised and SupCon: p-value = 1.3804778408804954e-11
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 183.69849246231152, p_value = 1.2893748501265186e-40)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0996436556040127e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 6.990331701611845e-18
# Wilcoxon test between Supervised and SupCon: p-value = 3.9819697708136773e-16
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 184.26262626262633, p_value = 9.724764579448566e-41)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1104597050567092e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 2.092225007884367e-17
# Wilcoxon test between Supervised and SupCon: p-value = 2.6537029108709658e-17
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 184.0603015075378, p_value = 1.076002694579976e-40)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0811851144057304e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 5.785366861221815e-18
# Wilcoxon test between Supervised and SupCon: p-value = 2.695893768058821e-16
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 193.57894736842107, p_value = 9.222861197475533e-43)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0833918912661127e-17
# Wilcoxon test between Supervised and SupCon: p-value = 5.858971922584559e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 6.8192734160998166e-18
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 194.18000000000006, p_value = 6.828868534581509e-43)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SupCon: p-value = 1.1128489565433367e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.594217121984118e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 4.686113188165952e-18
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 189.88860759493681, p_value = 5.837310198445588e-42)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1330351365359021e-17
# Wilcoxon test between Supervised and SupCon: p-value = 6.329394201765882e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 3.932535696698119e-17
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 198.06060606060598, p_value = 9.810380516264172e-44)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SupCon: p-value = 1.1175788929972723e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.699203255053233e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 1.732219936762538e-17
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 194.18000000000006, p_value = 6.828868534581509e-43)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1186536582552876e-17
# Wilcoxon test between Supervised and SupCon: p-value = 5.636117061871365e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 4.923765862084664e-18
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 198.01999999999998, p_value = 1.0011596706425744e-43)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SupCon: p-value = 1.1013251067532102e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.636117061871365e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 3.94409605754133e-18
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SupCon: p-value = 1.1217569960926137e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 5.650149696024605e-18
# Wilcoxon test between Supervised and SimCLR: p-value = 3.829844469015194e-18
# [array([ 5.96,  8.54, 13.27, 14.91, 18.48, 22.63, 24.93, 27.5 , 30.33,
#        33.  , 35.11, 37.73, 40.07, 43.97, 45.83]), array([ 4.66,  5.15,  5.92,  6.57,  7.5 ,  8.23,  8.72,  8.91,  9.35,
#         9.81, 11.22, 11.97, 12.96, 14.2 , 14.28]), array([ 6.65,  8.25, 11.13, 12.71, 14.11, 16.69, 17.87, 18.86, 19.39,
#        20.92, 22.51, 24.58, 26.34, 29.1 , 30.77])]
# Analysing data from 85 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 23.876675603217265, p_value = 6.535002674641797e-06)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SupCon: p-value = 3.044893842218264e-07
# Wilcoxon test between SimCLR and SupCon: p-value = 1.3961639737666852e-06
# Wilcoxon test between Supervised and SimCLR: p-value = 0.9566885457476831
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 31.446927374301655, p_value = 1.4838379843331307e-07)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and SupCon: p-value = 4.791598300499296e-08
# Wilcoxon test between Supervised and SupCon: p-value = 2.7018100487853e-07
# Wilcoxon test between Supervised and SimCLR: p-value = 2.671692192225294e-06
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 144.71099744245515, p_value = 3.7705627262630933e-32)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.435755574425174e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 4.5084629394860266e-17
# Wilcoxon test between Supervised and SupCon: p-value = 0.001209322009542858
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 137.84771573604058, p_value = 1.1661350701183531e-30)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.282472635233747e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 2.5441068239134348e-17
# Wilcoxon test between Supervised and SupCon: p-value = 0.9488934390735962
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 158.67519181585678, p_value = 3.500417849228029e-35)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.692523942123804e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 9.184044962851914e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.2205683839209657e-10
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 180.36775818639808, p_value = 6.817716737395819e-40)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0465104273542908e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 6.338674973428011e-18
# Wilcoxon test between Supervised and SupCon: p-value = 2.4523586277945036e-15
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 180.24120603015066, p_value = 7.263056201765108e-40)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1071980824044484e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 6.728914783504967e-18
# Wilcoxon test between Supervised and SupCon: p-value = 1.5173129639310355e-16
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 178.18781725888334, p_value = 2.0277159206176524e-39)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.454611968107629e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 8.298904453410889e-18
# Wilcoxon test between Supervised and SupCon: p-value = 1.4663064442498264e-14
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 197.50877192982466, p_value = 1.2927516825636133e-43)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SupCon: p-value = 1.0996459600602746e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.525664596401774e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 5.54217907359093e-18
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SupCon: p-value = 1.071732294467035e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 5.567077726301574e-18
# Wilcoxon test between Supervised and SimCLR: p-value = 3.719369416792904e-18
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SupCon: p-value = 1.0808789548678864e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.574954190123171e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 3.78725426816608e-18
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 199.50375939849633, p_value = 4.767701831604771e-44)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SupCon: p-value = 1.0944280242588942e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.591687245779589e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 5.529414419313474e-18
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SupCon: p-value = 1.0773945403523864e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.60339702224086e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 3.786612428399259e-18
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 199.50375939849633, p_value = 4.767701831604771e-44)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SupCon: p-value = 1.0939944485500098e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.560155165722571e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 5.5109551383366935e-18
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SupCon: p-value = 1.0943660748997022e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 5.6892318018728184e-18
# Wilcoxon test between Supervised and SimCLR: p-value = 3.800112742087812e-18
# [array([ 6.3 ,  7.94, 15.3 , 15.61, 20.4 , 26.14, 28.  , 30.36, 33.79,
#        36.06, 39.37, 41.94, 43.79, 47.45, 49.75]), array([ 6.31,  6.23,  7.44,  7.2 ,  8.91,  9.19,  9.9 ,  9.46, 10.54,
#        11.2 , 13.43, 14.42, 16.09, 16.87, 17.01]), array([ 7.9 ,  9.08, 14.  , 15.62, 16.4 , 20.21, 22.02, 23.04, 23.17,
#        24.93, 26.57, 28.97, 31.02, 34.56, 37.18])]

# %% [markdown]
# ### Conformer Results

# %%
file_paths = [
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/Supervised_results/Conformer_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SimCLR_results/Conformer_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SupCon_results/Conformer_1CLS_50Folfd_evaluation_results.txt')
]
process_results.get_differences(file_paths, 'Conformer', retraining_chars=[1, 5, 10, 25, 40, 85], dataset='BCI')
# Out:
# ALL SUBJECTS
#
# Analysing data from 1 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 16.26183844011145, p_value = 0.00029429755221970215)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 8.657533458729078e-06: diff -> 4.30 - 2.93 = 1.37
# Wilcoxon test between SupCon and SimCLR: p-value = 0.00013937955307280085: diff -> 3.06 - 4.30 = -1.24
# Wilcoxon test between SupCon and Supervised: p-value = 0.5820603720803204: diff -> 3.06 - 2.93 = 0.13
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 6.296495956873227, p_value = 0.04292727052478093)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.00043765178181088264: diff -> 4.97 - 3.34 = 1.63
# Wilcoxon test between SupCon and SimCLR: p-value = 0.01985043251730452: diff -> 3.75 - 4.97 = -1.22
# Wilcoxon test between SupCon and Supervised: p-value = 0.09923674915876574: diff -> 3.75 - 3.34 = 0.41
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 10.675675675675675, p_value = 0.004806251378781063)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.0004360374442597975: diff -> 5.04 - 3.47 = 1.57
# Wilcoxon test between SupCon and SimCLR: p-value = 0.006169974755741353: diff -> 3.66 - 5.04 = -1.38
# Wilcoxon test between SupCon and Supervised: p-value = 0.33320780657108817: diff -> 3.66 - 3.47 = 0.19
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 13.770053475935828, p_value = 0.0010229888023490469)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.0001581823321508992: diff -> 5.72 - 3.81 = 1.91
# Wilcoxon test between SupCon and SimCLR: p-value = 0.0032891388311567897: diff -> 4.15 - 5.72 = -1.57
# Wilcoxon test between SupCon and Supervised: p-value = 0.22696802818574935: diff -> 4.15 - 3.81 = 0.34
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 7.557333333333372, p_value = 0.02285314197618219)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.00015598320435341746: diff -> 6.08 - 3.89 = 2.19
# Wilcoxon test between SupCon and SimCLR: p-value = 0.002527737634042821: diff -> 4.28 - 6.08 = -1.80
# Wilcoxon test between SupCon and Supervised: p-value = 0.2932307117169686: diff -> 4.28 - 3.89 = 0.39
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 6.9574468085106, p_value = 0.030846764756634393)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.008050599010050102: diff -> 6.38 - 4.38 = 2.00
# Wilcoxon test between SupCon and SimCLR: p-value = 0.0947516955045207: diff -> 4.93 - 6.38 = -1.45
# Wilcoxon test between SupCon and Supervised: p-value = 0.15876389344494424: diff -> 4.93 - 4.38 = 0.55
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 3.080213903743432, p_value = 0.21435817419299696)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 5.698113207547258, p_value = 0.05789891673758505)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 9.217847769028843, p_value = 0.009962533377931557)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.0009223356628456699: diff -> 7.76 - 4.81 = 2.95
# Wilcoxon test between SupCon and SimCLR: p-value = 0.027458298577284025: diff -> 5.51 - 7.76 = -2.25
# Wilcoxon test between SupCon and Supervised: p-value = 0.10535447080553435: diff -> 5.51 - 4.81 = 0.70
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 13.637333333333421, p_value = 0.0010931775210258749)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 8.625893027834123e-05: diff -> 8.02 - 4.81 = 3.21
# Wilcoxon test between SupCon and SimCLR: p-value = 0.01911762910634671: diff -> 5.75 - 8.02 = -2.27
# Wilcoxon test between SupCon and Supervised: p-value = 0.04588436089376633: diff -> 5.75 - 4.81 = 0.94
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 11.918699186991999, p_value = 0.0025815905093601625)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 6.12274620282052e-05: diff -> 8.66 - 4.93 = 3.73
# Wilcoxon test between SupCon and SimCLR: p-value = 0.017560998346997314: diff -> 6.05 - 8.66 = -2.61
# Wilcoxon test between SupCon and Supervised: p-value = 0.03602578297476326: diff -> 6.05 - 4.93 = 1.12
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 3.340259740259655, p_value = 0.18822261955533498)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 9.037037037036999, p_value = 0.01090516751092009)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.0004488391471764123: diff -> 8.99 - 5.06 = 3.93
# Wilcoxon test between SupCon and Supervised: p-value = 0.04073654329433375: diff -> 6.39 - 5.06 = 1.33
# Wilcoxon test between SupCon and SimCLR: p-value = 0.052216036599144: diff -> 6.39 - 8.99 = -2.60
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 10.713910761154779, p_value = 0.004715240387763337)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.0006040277977027804: diff -> 9.61 - 5.59 = 4.02
# Wilcoxon test between SupCon and SimCLR: p-value = 0.01758426087467672: diff -> 6.62 - 9.61 = -2.99
# Wilcoxon test between SupCon and Supervised: p-value = 0.08570124167332636: diff -> 6.62 - 5.59 = 1.03
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 11.683646112600517, p_value = 0.0029035444728201134)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.00030831569555939077: diff -> 9.79 - 5.65 = 4.14
# Wilcoxon test between SupCon and Supervised: p-value = 0.010311337085924722: diff -> 7.23 - 5.65 = 1.58
# Wilcoxon test between SupCon and SimCLR: p-value = 0.06894592835994842: diff -> 7.23 - 9.79 = -2.56
#
#  ALL SUBJECTS Differences 1: {'SimCLR': [1.3699999999999997, 1.63, 1.5699999999999998, 1.9099999999999997, 2.19, 2.0, 2.95, 3.21, 3.7300000000000004, 3.9300000000000006, 4.02, 4.139999999999999], 'SupCon': [0.9400000000000004, 1.12, 1.33, 1.58]}
#
# Average Difference: (2.72, 1.24)
#
# Analysing data from 5 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 42.937329700272464, p_value = 4.745449124791355e-10)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0739353460284194e-10: diff -> 8.89 - 4.38 = 4.51
# Wilcoxon test between SupCon and SimCLR: p-value = 6.046179428367298e-09: diff -> 5.44 - 8.89 = -3.45
# Wilcoxon test between SupCon and Supervised: p-value = 0.004130698086988435: diff -> 5.44 - 4.38 = 1.06
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 71.81151832460726, p_value = 2.548748171768451e-16)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 6.004033715457599e-14: diff -> 13.13 - 5.65 = 7.48
# Wilcoxon test between SupCon and SimCLR: p-value = 2.273674869538959e-09: diff -> 7.94 - 13.13 = -5.19
# Wilcoxon test between SupCon and Supervised: p-value = 6.568927671311118e-06: diff -> 7.94 - 5.65 = 2.29
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 68.29381443298982, p_value = 1.4797441162698194e-15)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.689765281815899e-14: diff -> 15.47 - 6.61 = 8.86
# Wilcoxon test between SupCon and SimCLR: p-value = 9.95595892394567e-11: diff -> 8.72 - 15.47 = -6.75
# Wilcoxon test between SupCon and Supervised: p-value = 0.00012741610325998364: diff -> 8.72 - 6.61 = 2.11
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 60.47894736842098, p_value = 7.364842153476313e-14)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.811118199580029e-13: diff -> 17.29 - 8.03 = 9.26
# Wilcoxon test between SupCon and SimCLR: p-value = 6.378813955044395e-10: diff -> 9.58 - 17.29 = -7.71
# Wilcoxon test between SupCon and Supervised: p-value = 0.005120185343718808: diff -> 9.58 - 8.03 = 1.55
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 49.26666666666675, p_value = 2.0039148445918275e-11)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.288265130462298e-13: diff -> 19.47 - 8.25 = 11.22
# Wilcoxon test between SupCon and SimCLR: p-value = 9.06680902527471e-08: diff -> 11.81 - 19.47 = -7.66
# Wilcoxon test between SupCon and Supervised: p-value = 3.29101573681633e-07: diff -> 11.81 - 8.25 = 3.56
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 44.14285714285713, p_value = 2.5971699164422386e-10)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.862023889936919e-12: diff -> 21.95 - 10.31 = 11.64
# Wilcoxon test between SupCon and SimCLR: p-value = 4.7083277767060065e-07: diff -> 13.39 - 21.95 = -8.56
# Wilcoxon test between SupCon and Supervised: p-value = 0.00029653943135673594: diff -> 13.39 - 10.31 = 3.08
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 59.91348600508906, p_value = 9.77128809641633e-14)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 7.714367150429443e-14: diff -> 24.88 - 10.56 = 14.32
# Wilcoxon test between SupCon and SimCLR: p-value = 1.2219561309287424e-07: diff -> 14.92 - 24.88 = -9.96
# Wilcoxon test between SupCon and Supervised: p-value = 4.001059243734923e-06: diff -> 14.92 - 10.56 = 4.36
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 63.89285714285715, p_value = 1.3361104321429818e-14)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 7.98096848301761e-14: diff -> 26.21 - 11.58 = 14.63
# Wilcoxon test between SupCon and SimCLR: p-value = 9.220731650897539e-07: diff -> 16.44 - 26.21 = -9.77
# Wilcoxon test between SupCon and Supervised: p-value = 4.543329332847155e-06: diff -> 16.44 - 11.58 = 4.86
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 66.18227848101267, p_value = 4.2530533250133185e-15)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 8.713508283750473e-14: diff -> 27.28 - 11.91 = 15.37
# Wilcoxon test between SupCon and Supervised: p-value = 5.9587314686041905e-08: diff -> 17.84 - 11.91 = 5.93
# Wilcoxon test between SupCon and SimCLR: p-value = 1.4370048202102116e-06: diff -> 17.84 - 27.28 = -9.44
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 60.48979591836732, p_value = 7.32500137585377e-14)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.4109214944767593e-13: diff -> 28.87 - 12.36 = 16.51
# Wilcoxon test between SupCon and Supervised: p-value = 2.5398919261577636e-08: diff -> 19.16 - 12.36 = 6.80
# Wilcoxon test between SupCon and SimCLR: p-value = 1.8872641696242771e-06: diff -> 19.16 - 28.87 = -9.71
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 66.01538461538463, p_value = 4.62318604349075e-15)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.9915996818189182e-14: diff -> 30.13 - 12.93 = 17.20
# Wilcoxon test between SupCon and Supervised: p-value = 5.153119381546463e-07: diff -> 19.82 - 12.93 = 6.89
# Wilcoxon test between SupCon and SimCLR: p-value = 2.796383088871668e-06: diff -> 19.82 - 30.13 = -10.31
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 56.899497487437195, p_value = 4.409924041690687e-13)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.38726778894958e-14: diff -> 31.74 - 13.80 = 17.94
# Wilcoxon test between SupCon and Supervised: p-value = 7.548141600526426e-08: diff -> 21.81 - 13.80 = 8.01
# Wilcoxon test between SupCon and SimCLR: p-value = 9.821270515956884e-06: diff -> 21.81 - 31.74 = -9.93
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 57.00512820512813, p_value = 4.18305611071362e-13)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.0774346991822764e-13: diff -> 33.58 - 15.23 = 18.35
# Wilcoxon test between SupCon and Supervised: p-value = 2.9644051245872216e-07: diff -> 23.54 - 15.23 = 8.31
# Wilcoxon test between SupCon and SimCLR: p-value = 2.8014501758547752e-05: diff -> 23.54 - 33.58 = -10.04
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 55.477157360406075, p_value = 8.98024826815276e-13)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.4532063585748767e-13: diff -> 35.45 - 16.50 = 18.95
# Wilcoxon test between SupCon and Supervised: p-value = 1.1926144346248736e-06: diff -> 25.03 - 16.50 = 8.53
# Wilcoxon test between SupCon and SimCLR: p-value = 3.645608019495645e-05: diff -> 25.03 - 35.45 = -10.42
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 54.8142493638677, p_value = 1.2509414577097415e-12)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.9437405302093622e-13: diff -> 36.51 - 16.58 = 19.93
# Wilcoxon test between SupCon and Supervised: p-value = 1.7394161512564542e-07: diff -> 26.34 - 16.58 = 9.76
# Wilcoxon test between SupCon and SimCLR: p-value = 7.259549994625608e-05: diff -> 26.34 - 36.51 = -10.17
#
#  ALL SUBJECTS Differences 5: {'SimCLR': [4.510000000000001, 7.48, 8.86, 9.26, 11.219999999999999, 11.639999999999999, 14.319999999999999, 14.63, 15.370000000000001, 16.51, 17.2, 17.939999999999998, 18.349999999999998, 18.950000000000003, 19.93], 'SupCon': [1.0600000000000005, 2.29, 2.1100000000000003, 1.5500000000000007, 3.5600000000000005, 3.08, 4.359999999999999, 4.860000000000001, 5.93, 6.800000000000001, 6.890000000000001, 8.009999999999998, 8.309999999999999, 8.530000000000001, 9.760000000000002]}
#
# Average Difference: (13.74, 5.14)
#
# Analysing data from 10 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 86.37735849056605, p_value = 1.7514386249220457e-19)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.845503184131887e-15: diff -> 11.01 - 5.09 = 5.92
# Wilcoxon test between SupCon and SimCLR: p-value = 1.3983059275739392e-11: diff -> 7.16 - 11.01 = -3.85
# Wilcoxon test between SupCon and Supervised: p-value = 3.2550895847150516e-07: diff -> 7.16 - 5.09 = 2.07
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 111.13385826771655, p_value = 7.372067462846636e-25)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.5109975876156847e-16: diff -> 18.44 - 7.79 = 10.65
# Wilcoxon test between SupCon and SimCLR: p-value = 8.780140786784234e-12: diff -> 11.53 - 18.44 = -6.91
# Wilcoxon test between SupCon and Supervised: p-value = 3.656512245897261e-10: diff -> 11.53 - 7.79 = 3.74
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 110.21938775510215, p_value = 1.16456584730742e-24)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.5922812101753844e-16: diff -> 22.67 - 9.42 = 13.25
# Wilcoxon test between SupCon and SimCLR: p-value = 1.1013529246744215e-14: diff -> 12.75 - 22.67 = -9.92
# Wilcoxon test between SupCon and Supervised: p-value = 5.762146407917349e-08: diff -> 12.75 - 9.42 = 3.33
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 100.32642487046638, p_value = 1.6383008057025937e-22)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.0970335637282744e-16: diff -> 25.45 - 11.42 = 14.03
# Wilcoxon test between SupCon and SimCLR: p-value = 3.11382321382265e-13: diff -> 14.19 - 25.45 = -11.26
# Wilcoxon test between SupCon and Supervised: p-value = 1.8180053048077208e-05: diff -> 14.19 - 11.42 = 2.77
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 99.39845758354751, p_value = 2.605548615769657e-22)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.6627069446213658e-16: diff -> 28.54 - 12.56 = 15.98
# Wilcoxon test between SupCon and SimCLR: p-value = 3.4711616744746046e-11: diff -> 17.26 - 28.54 = -11.28
# Wilcoxon test between SupCon and Supervised: p-value = 1.380228999680689e-09: diff -> 17.26 - 12.56 = 4.70
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 82.3443037974684, p_value = 1.3157143830070452e-18)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.848570403625285e-15: diff -> 31.48 - 15.07 = 16.41
# Wilcoxon test between SupCon and SimCLR: p-value = 2.076445968791812e-09: diff -> 20.32 - 31.48 = -11.16
# Wilcoxon test between SupCon and Supervised: p-value = 2.0047891744625374e-08: diff -> 20.32 - 15.07 = 5.25
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 92.3807106598986, p_value = 8.705296407732728e-21)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.3654338509741114e-15: diff -> 34.25 - 15.96 = 18.29
# Wilcoxon test between SupCon and Supervised: p-value = 2.8262420593848918e-12: diff -> 23.53 - 15.96 = 7.57
# Wilcoxon test between SupCon and SimCLR: p-value = 1.320636380991477e-08: diff -> 23.53 - 34.25 = -10.72
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 94.17766497461939, p_value = 3.544703315700853e-21)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.5435114311224026e-15: diff -> 35.81 - 17.13 = 18.68
# Wilcoxon test between SupCon and Supervised: p-value = 2.1260342066248103e-13: diff -> 26.02 - 17.13 = 8.89
# Wilcoxon test between SupCon and SimCLR: p-value = 1.7631857302086509e-07: diff -> 26.02 - 35.81 = -9.79
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 104.1776649746193, p_value = 2.3884023068675793e-23)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 8.344479014102482e-16: diff -> 36.96 - 17.96 = 19.00
# Wilcoxon test between SupCon and Supervised: p-value = 6.196755246939697e-13: diff -> 27.24 - 17.96 = 9.28
# Wilcoxon test between SupCon and SimCLR: p-value = 4.3119148778020446e-08: diff -> 27.24 - 36.96 = -9.72
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 111.04303797468351, p_value = 7.714551398864017e-25)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 6.457286750280953e-16: diff -> 39.10 - 18.43 = 20.67
# Wilcoxon test between SupCon and Supervised: p-value = 2.786846196952954e-14: diff -> 29.48 - 18.43 = 11.05
# Wilcoxon test between SupCon and SimCLR: p-value = 2.058358050908581e-07: diff -> 29.48 - 39.10 = -9.62
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 102.07537688442217, p_value = 6.833033350952174e-23)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.3752892978286784e-16: diff -> 40.75 - 20.03 = 20.72
# Wilcoxon test between SupCon and Supervised: p-value = 2.811148357092736e-13: diff -> 31.33 - 20.03 = 11.30
# Wilcoxon test between SupCon and SimCLR: p-value = 5.402408030495656e-07: diff -> 31.33 - 40.75 = -9.42
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 91.86768447837149, p_value = 1.1250861614679301e-20)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 9.460317554112637e-16: diff -> 43.41 - 22.11 = 21.30
# Wilcoxon test between SupCon and Supervised: p-value = 7.561389808521399e-14: diff -> 34.87 - 22.11 = 12.76
# Wilcoxon test between SupCon and SimCLR: p-value = 4.091286934872754e-06: diff -> 34.87 - 43.41 = -8.54
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 93.10379746835449, p_value = 6.064112611694387e-21)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 7.888188063634957e-16: diff -> 45.23 - 23.76 = 21.47
# Wilcoxon test between SupCon and Supervised: p-value = 3.435155974244697e-14: diff -> 37.67 - 23.76 = 13.91
# Wilcoxon test between SupCon and SimCLR: p-value = 2.1331315643843358e-05: diff -> 37.67 - 45.23 = -7.56
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 96.14105793450888, p_value = 1.3281114697820378e-21)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 8.11281144983107e-16: diff -> 48.38 - 25.88 = 22.50
# Wilcoxon test between SupCon and Supervised: p-value = 4.5097761758669124e-13: diff -> 40.18 - 25.88 = 14.30
# Wilcoxon test between SupCon and SimCLR: p-value = 1.93012839009187e-05: diff -> 40.18 - 48.38 = -8.20
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 85.50125944584396, p_value = 2.7141722971155674e-19)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 5.5656520263700775e-16: diff -> 49.35 - 26.49 = 22.86
# Wilcoxon test between SupCon and Supervised: p-value = 3.0002188102660057e-14: diff -> 41.93 - 26.49 = 15.44
# Wilcoxon test between SupCon and SimCLR: p-value = 4.25614856809792e-05: diff -> 41.93 - 49.35 = -7.42
#
#  ALL SUBJECTS Differences 10: {'SimCLR': [5.92, 10.650000000000002, 13.250000000000002, 14.03, 15.979999999999999, 16.41, 18.29, 18.680000000000003, 19.0, 20.67, 20.72, 21.299999999999997, 21.469999999999995, 22.500000000000004, 22.860000000000003], 'SupCon': [2.0700000000000003, 3.7399999999999993, 3.33, 2.7699999999999996, 4.700000000000001, 5.25, 7.57, 8.89, 9.279999999999998, 11.05, 11.299999999999997, 12.759999999999998, 13.91, 14.3, 15.440000000000001]}
#
# Average Difference: (17.45, 8.42)
#
# Analysing data from 25 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 139.97894736842107, p_value = 4.017517596589498e-31)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 8.87546090629089e-17: diff -> 13.62 - 6.44 = 7.18
# Wilcoxon test between SupCon and SimCLR: p-value = 6.45721525175352e-14: diff -> 10.12 - 13.62 = -3.50
# Wilcoxon test between SupCon and Supervised: p-value = 1.0723945947738552e-12: diff -> 10.12 - 6.44 = 3.68
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 163.07416879795392, p_value = 3.8805579653885965e-36)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1399050381013225e-17: diff -> 23.82 - 9.73 = 14.09
# Wilcoxon test between SupCon and Supervised: p-value = 8.353523862164295e-16: diff -> 15.57 - 9.73 = 5.84
# Wilcoxon test between SupCon and SimCLR: p-value = 1.5226708561885637e-15: diff -> 15.57 - 23.82 = -8.25
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 178.56265984654738, p_value = 1.6811678546625865e-39)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.148758736662577e-17: diff -> 30.07 - 13.28 = 16.79
# Wilcoxon test between SupCon and SimCLR: p-value = 1.710917297390275e-17: diff -> 18.85 - 30.07 = -11.22
# Wilcoxon test between SupCon and Supervised: p-value = 8.045289084914189e-16: diff -> 18.85 - 13.28 = 5.57
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 164.65306122448993, p_value = 1.7621466186428712e-36)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1789666959816289e-17: diff -> 34.86 - 15.94 = 18.92
# Wilcoxon test between SupCon and SimCLR: p-value = 2.4442039491536017e-17: diff -> 20.81 - 34.86 = -14.05
# Wilcoxon test between SupCon and Supervised: p-value = 3.8010326165933476e-14: diff -> 20.81 - 15.94 = 4.87
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 173.86802030456852, p_value = 1.7580818934615481e-38)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.137332241927526e-17: diff -> 38.10 - 18.39 = 19.71
# Wilcoxon test between SupCon and SimCLR: p-value = 7.980383052815908e-17: diff -> 25.37 - 38.10 = -12.73
# Wilcoxon test between SupCon and Supervised: p-value = 6.310222815815559e-16: diff -> 25.37 - 18.39 = 6.98
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 168.20304568527925, p_value = 2.9865700788948845e-37)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1437745793496694e-17: diff -> 42.58 - 23.16 = 19.42
# Wilcoxon test between SupCon and SimCLR: p-value = 1.1774924817496985e-16: diff -> 30.15 - 42.58 = -12.43
# Wilcoxon test between SupCon and Supervised: p-value = 4.0101897361183747e-16: diff -> 30.15 - 23.16 = 6.99
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 179.46365914786978, p_value = 1.0714244800213232e-39)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1498619061811618e-17: diff -> 45.78 - 24.11 = 21.67
# Wilcoxon test between SupCon and Supervised: p-value = 6.1948379884908324e-18: diff -> 34.63 - 24.11 = 10.52
# Wilcoxon test between SupCon and SimCLR: p-value = 3.4023842187240785e-15: diff -> 34.63 - 45.78 = -11.15
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 182.2424242424243, p_value = 2.6703020638725135e-40)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SupCon and Supervised: p-value = 1.123661025006585e-17: diff -> 38.34 - 25.37 = 12.97
# Wilcoxon test between SimCLR and Supervised: p-value = 5.758405403873735e-18: diff -> 48.60 - 25.37 = 23.23
# Wilcoxon test between SupCon and SimCLR: p-value = 2.7516485875989333e-15: diff -> 38.34 - 48.60 = -10.26
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 190.08020050125313, p_value = 5.3040657818878024e-42)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SupCon and Supervised: p-value = 1.1129118973448229e-17: diff -> 39.52 - 25.89 = 13.63
# Wilcoxon test between SimCLR and Supervised: p-value = 5.71984191453995e-18: diff -> 51.52 - 25.89 = 25.63
# Wilcoxon test between SupCon and SimCLR: p-value = 4.8478439751674406e-17: diff -> 39.52 - 51.52 = -12.00
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 182.0, p_value = 3.014408785065379e-40)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SupCon and Supervised: p-value = 1.1315635627003739e-17: diff -> 42.19 - 27.63 = 14.56
# Wilcoxon test between SimCLR and Supervised: p-value = 5.708223967005542e-18: diff -> 53.69 - 27.63 = 26.06
# Wilcoxon test between SupCon and SimCLR: p-value = 7.060354071905941e-16: diff -> 42.19 - 53.69 = -11.50
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 176.84771573604056, p_value = 3.9628392819678755e-39)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1359837285197777e-17: diff -> 55.06 - 30.68 = 24.38
# Wilcoxon test between SupCon and Supervised: p-value = 1.96569636483098e-17: diff -> 45.25 - 30.68 = 14.57
# Wilcoxon test between SupCon and SimCLR: p-value = 1.1564806302526498e-14: diff -> 45.25 - 55.06 = -9.81
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 179.1717171717173, p_value = 1.2398123542017158e-39)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SupCon and Supervised: p-value = 1.129263866564592e-17: diff -> 49.46 - 32.95 = 16.51
# Wilcoxon test between SimCLR and Supervised: p-value = 5.661975495240824e-18: diff -> 58.49 - 32.95 = 25.54
# Wilcoxon test between SupCon and SimCLR: p-value = 1.8934868060534256e-14: diff -> 49.46 - 58.49 = -9.03
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 172.1060606060606, p_value = 4.2427143051909344e-38)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.126968601488495e-17: diff -> 59.90 - 35.42 = 24.48
# Wilcoxon test between SupCon and Supervised: p-value = 8.563847136726548e-18: diff -> 52.52 - 35.42 = 17.10
# Wilcoxon test between SupCon and SimCLR: p-value = 4.210585805199381e-12: diff -> 52.52 - 59.90 = -7.38
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 175.07035175879392, p_value = 9.637316970977251e-39)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1751801909245009e-17: diff -> 62.84 - 38.65 = 24.19
# Wilcoxon test between SupCon and Supervised: p-value = 1.0071944311909435e-17: diff -> 55.37 - 38.65 = 16.72
# Wilcoxon test between SupCon and SimCLR: p-value = 9.93109375625148e-15: diff -> 55.37 - 62.84 = -7.47
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 170.01012658227847, p_value = 1.2099573966885234e-37)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1816974704557172e-17: diff -> 63.71 - 40.03 = 23.68
# Wilcoxon test between SupCon and Supervised: p-value = 7.284218400978858e-18: diff -> 56.94 - 40.03 = 16.91
# Wilcoxon test between SupCon and SimCLR: p-value = 5.931781188212604e-14: diff -> 56.94 - 63.71 = -6.77
#
#  ALL SUBJECTS Differences 25: {'SimCLR': [7.179999999999999, 14.09, 16.79, 18.92, 19.71, 19.419999999999998, 21.67, 23.23, 25.630000000000003, 26.06, 24.380000000000003, 25.54, 24.479999999999997, 24.190000000000005, 23.68], 'SupCon': [3.679999999999999, 5.84, 5.570000000000002, 4.869999999999999, 6.98, 6.989999999999998, 10.520000000000003, 12.970000000000002, 13.630000000000003, 14.559999999999999, 14.57, 16.509999999999998, 17.1, 16.72, 16.909999999999997]}
#
# Average Difference: (21.00, 11.16)
#
# Analysing data from 40 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 150.91145833333334, p_value = 1.6982170424628365e-33)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.07155011192816e-17: diff -> 14.48 - 6.74 = 7.74
# Wilcoxon test between SupCon and Supervised: p-value = 8.02536380642163e-15: diff -> 11.55 - 6.74 = 4.81
# Wilcoxon test between SupCon and SimCLR: p-value = 2.500601656310397e-10: diff -> 11.55 - 14.48 = -2.93
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 174.67512690355338, p_value = 1.1742974830176454e-38)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.649002056534426e-17: diff -> 25.56 - 10.30 = 15.26
# Wilcoxon test between SupCon and Supervised: p-value = 2.8374894453202e-17: diff -> 16.83 - 10.30 = 6.53
# Wilcoxon test between SupCon and SimCLR: p-value = 6.362624535469504e-17: diff -> 16.83 - 25.56 = -8.73
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 182.22506393861892, p_value = 2.6935815801154348e-40)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SupCon and SimCLR: p-value = 1.1276694628507817e-17: diff -> 19.96 - 33.08 = -13.12
# Wilcoxon test between SimCLR and Supervised: p-value = 5.679918642598889e-18: diff -> 33.08 - 14.89 = 18.19
# Wilcoxon test between SupCon and Supervised: p-value = 1.4440709799944077e-14: diff -> 19.96 - 14.89 = 5.07
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 173.0761421319797, p_value = 2.612120824432085e-38)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1227720972317467e-17: diff -> 37.12 - 17.74 = 19.38
# Wilcoxon test between SupCon and SimCLR: p-value = 5.685055148660282e-18: diff -> 21.69 - 37.12 = -15.43
# Wilcoxon test between SupCon and Supervised: p-value = 3.4117150337739236e-12: diff -> 21.69 - 17.74 = 3.95
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 181.46000000000004, p_value = 3.948768348413574e-40)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1327150749373942e-17: diff -> 41.09 - 20.44 = 20.65
# Wilcoxon test between SupCon and SimCLR: p-value = 6.971715044114242e-18: diff -> 27.47 - 41.09 = -13.62
# Wilcoxon test between SupCon and Supervised: p-value = 7.779316469577363e-16: diff -> 27.47 - 20.44 = 7.03
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 181.00251889168763, p_value = 4.963664477581227e-40)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1311799719562301e-17: diff -> 44.67 - 25.43 = 19.24
# Wilcoxon test between SupCon and SimCLR: p-value = 2.6513883400250283e-17: diff -> 33.27 - 44.67 = -11.40
# Wilcoxon test between SupCon and Supervised: p-value = 3.8025655501907745e-17: diff -> 33.27 - 25.43 = 7.84
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 179.4609571788413, p_value = 1.0728729361025672e-39)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1436453942692425e-17: diff -> 48.47 - 25.95 = 22.52
# Wilcoxon test between SupCon and Supervised: p-value = 2.0971632306122753e-17: diff -> 37.14 - 25.95 = 11.19
# Wilcoxon test between SupCon and SimCLR: p-value = 2.506040648214801e-16: diff -> 37.14 - 48.47 = -11.33
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 184.0603015075378, p_value = 1.076002694579976e-40)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1419027489015622e-17: diff -> 51.29 - 28.34 = 22.95
# Wilcoxon test between SupCon and Supervised: p-value = 8.156067793988204e-18: diff -> 40.67 - 28.34 = 12.33
# Wilcoxon test between SupCon and SimCLR: p-value = 6.233882750653017e-17: diff -> 40.67 - 51.29 = -10.62
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 197.02010050251263, p_value = 1.6505503000453228e-43)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1207427650175903e-17: diff -> 54.52 - 28.88 = 25.64
# Wilcoxon test between SupCon and SimCLR: p-value = 8.234556251123257e-18: diff -> 42.49 - 54.52 = -12.03
# Wilcoxon test between SupCon and Supervised: p-value = 6.018582920812344e-18: diff -> 42.49 - 28.88 = 13.61
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 192.1400000000001, p_value = 1.8937782463901564e-42)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.120679404448172e-17: diff -> 57.11 - 31.31 = 25.80
# Wilcoxon test between SupCon and Supervised: p-value = 6.447577915544503e-18: diff -> 45.43 - 31.31 = 14.12
# Wilcoxon test between SupCon and SimCLR: p-value = 1.3705241794460362e-17: diff -> 45.43 - 57.11 = -11.68
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 187.19597989949747, p_value = 2.2434141127760785e-41)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1246141879719175e-17: diff -> 57.62 - 33.69 = 23.93
# Wilcoxon test between SupCon and Supervised: p-value = 7.43555147872828e-18: diff -> 48.31 - 33.69 = 14.62
# Wilcoxon test between SupCon and SimCLR: p-value = 1.5573014152475986e-17: diff -> 48.31 - 57.62 = -9.31
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 187.67512690355343, p_value = 1.765484860183598e-41)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1115908489387507e-17: diff -> 61.43 - 36.65 = 24.78
# Wilcoxon test between SupCon and Supervised: p-value = 1.2165816490501327e-17: diff -> 52.70 - 36.65 = 16.05
# Wilcoxon test between SupCon and SimCLR: p-value = 1.9405186558804354e-16: diff -> 52.70 - 61.43 = -8.73
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 170.64810126582287, p_value = 8.79499580190809e-38)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1173261493545757e-17: diff -> 62.71 - 39.11 = 23.60
# Wilcoxon test between SupCon and Supervised: p-value = 1.9786889887429212e-17: diff -> 55.67 - 39.11 = 16.56
# Wilcoxon test between SupCon and SimCLR: p-value = 1.084458427479643e-14: diff -> 55.67 - 62.71 = -7.04
#
# N Trials -> 14
#
# Is data Normally Distributed? - True
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 178.50505050505055, p_value = 1.7302975262991987e-39)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1322031546461092e-17: diff -> 65.72 - 43.48 = 22.24
# Wilcoxon test between SupCon and Supervised: p-value = 1.2665863155675058e-17: diff -> 58.39 - 43.48 = 14.91
# Wilcoxon test between SupCon and SimCLR: p-value = 7.688492429455329e-17: diff -> 58.39 - 65.72 = -7.33
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 179.91392405063286, p_value = 8.554365132209062e-40)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1390682747901122e-17: diff -> 67.16 - 45.06 = 22.10
# Wilcoxon test between SupCon and Supervised: p-value = 2.681030903072224e-17: diff -> 59.63 - 45.06 = 14.57
# Wilcoxon test between SupCon and SimCLR: p-value = 2.0095159441722344e-17: diff -> 59.63 - 67.16 = -7.53
#
#  ALL SUBJECTS Differences 40: {'SimCLR': [7.74, 15.259999999999998, 18.189999999999998, 19.38, 20.650000000000002, 19.240000000000002, 22.52, 22.95, 25.640000000000004, 25.8, 23.93, 24.78, 23.6, 22.240000000000002, 22.099999999999994], 'SupCon': [4.8100000000000005, 6.529999999999998, 5.07, 3.950000000000003, 7.029999999999998, 7.840000000000003, 11.190000000000001, 12.330000000000002, 13.610000000000003, 14.120000000000001, 14.620000000000005, 16.050000000000004, 16.560000000000002, 14.910000000000004, 14.57]}
#
# Average Difference: (20.93, 10.88)
#
# Analysing data from 85 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 159.25000000000006, p_value = 2.6260432739767623e-35)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0314728079064126e-17: diff -> 16.18 - 6.71 = 9.47
# Wilcoxon test between SupCon and Supervised: p-value = 7.230961169400791e-17: diff -> 12.62 - 6.71 = 5.91
# Wilcoxon test between SupCon and SimCLR: p-value = 1.510847727851178e-13: diff -> 12.62 - 16.18 = -3.56
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 197.5037974683545, p_value = 1.295971056284295e-43)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1108366317184433e-17: diff -> 27.39 - 10.86 = 16.53
# Wilcoxon test between SupCon and SimCLR: p-value = 1.1697933006184954e-17: diff -> 17.72 - 27.39 = -9.67
# Wilcoxon test between SupCon and Supervised: p-value = 1.1094857343312447e-17: diff -> 17.72 - 10.86 = 6.86
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 187.15151515151513, p_value = 2.2938491017230793e-41)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SupCon and SimCLR: p-value = 1.1146756105400984e-17: diff -> 21.24 - 34.96 = -13.72
# Wilcoxon test between SimCLR and Supervised: p-value = 5.5878944649863615e-18: diff -> 34.96 - 16.36 = 18.60
# Wilcoxon test between SupCon and Supervised: p-value = 5.683619717738957e-16: diff -> 21.24 - 16.36 = 4.88
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 163.81074168797954, p_value = 2.6850316183032747e-36)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1003283972643606e-17: diff -> 39.09 - 20.05 = 19.04
# Wilcoxon test between SupCon and SimCLR: p-value = 5.672222131725827e-18: diff -> 22.48 - 39.09 = -16.61
# Wilcoxon test between SupCon and Supervised: p-value = 2.321207255266998e-07: diff -> 22.48 - 20.05 = 2.43
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 191.4572864321608, p_value = 2.664271573986494e-42)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1008266450679597e-17: diff -> 43.17 - 22.71 = 20.46
# Wilcoxon test between SupCon and SimCLR: p-value = 5.565503699990726e-18: diff -> 28.86 - 43.17 = -14.31
# Wilcoxon test between SupCon and Supervised: p-value = 1.3419089736822728e-17: diff -> 28.86 - 22.71 = 6.15
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 189.26448362720404, p_value = 7.975163038395511e-42)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.076113495158822e-17: diff -> 45.93 - 28.35 = 17.58
# Wilcoxon test between SupCon and SimCLR: p-value = 5.659416579233613e-18: diff -> 35.85 - 45.93 = -10.08
# Wilcoxon test between SupCon and Supervised: p-value = 4.727314844575954e-17: diff -> 35.85 - 28.35 = 7.50
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 185.21717171717174, p_value = 6.03395663641137e-41)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1359195514177846e-17: diff -> 50.90 - 28.71 = 22.19
# Wilcoxon test between SupCon and Supervised: p-value = 7.947350053032915e-18: diff -> 39.80 - 28.71 = 11.09
# Wilcoxon test between SupCon and SimCLR: p-value = 2.168022814638109e-16: diff -> 39.80 - 50.90 = -11.10
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 196.07999999999993, p_value = 2.6410036061004486e-43)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SupCon and Supervised: p-value = 1.0928802871967835e-17: diff -> 43.73 - 31.52 = 12.21
# Wilcoxon test between SimCLR and Supervised: p-value = 5.552926669016348e-18: diff -> 54.92 - 31.52 = 23.40
# Wilcoxon test between SupCon and SimCLR: p-value = 4.9545318146620105e-18: diff -> 43.73 - 54.92 = -11.19
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0819815140112091e-17: diff -> 57.67 - 32.10 = 25.57
# Wilcoxon test between SupCon and SimCLR: p-value = 5.426785274410355e-18: diff -> 45.46 - 57.67 = -12.21
# Wilcoxon test between SupCon and Supervised: p-value = 3.763362061471374e-18: diff -> 45.46 - 32.10 = 13.36
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 199.50375939849633, p_value = 4.767701831604771e-44)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0735557356638861e-17: diff -> 59.29 - 32.97 = 26.32
# Wilcoxon test between SupCon and Supervised: p-value = 5.485164507315061e-18: diff -> 48.02 - 32.97 = 15.05
# Wilcoxon test between SupCon and SimCLR: p-value = 5.366607943943742e-18: diff -> 48.02 - 59.29 = -11.27
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SupCon and SimCLR: p-value = 1.0610336155369925e-17: diff -> 51.73 - 59.74 = -8.01
# Wilcoxon test between SimCLR and Supervised: p-value = 5.508807181228658e-18: diff -> 59.74 - 36.80 = 22.94
# Wilcoxon test between SupCon and Supervised: p-value = 3.759748079857097e-18: diff -> 51.73 - 36.80 = 14.93
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SupCon and SimCLR: p-value = 1.076479360642519e-17: diff -> 54.92 - 63.81 = -8.89
# Wilcoxon test between SimCLR and Supervised: p-value = 5.622117470408576e-18: diff -> 63.81 - 39.58 = 24.23
# Wilcoxon test between SupCon and Supervised: p-value = 3.8160285270189416e-18: diff -> 54.92 - 39.58 = 15.34
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 164.60000000000014, p_value = 1.8095231323686558e-36)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.111213679666859e-17: diff -> 63.86 - 42.53 = 21.33
# Wilcoxon test between SupCon and Supervised: p-value = 1.2037986118803578e-17: diff -> 57.51 - 42.53 = 14.98
# Wilcoxon test between SupCon and SimCLR: p-value = 1.1284757715548038e-13: diff -> 57.51 - 63.86 = -6.35
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 199.50375939849633, p_value = 4.767701831604771e-44)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SupCon and SimCLR: p-value = 1.0413567384503606e-17: diff -> 61.30 - 69.05 = -7.75
# Wilcoxon test between SimCLR and Supervised: p-value = 5.685697521445168e-18: diff -> 69.05 - 47.30 = 21.75
# Wilcoxon test between SupCon and Supervised: p-value = 5.4903373989512284e-18: diff -> 61.30 - 47.30 = 14.00
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 197.53884711779455, p_value = 1.2734572422030736e-43)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SupCon and SimCLR: p-value = 1.0338767199731035e-17: diff -> 61.99 - 69.09 = -7.10
# Wilcoxon test between SimCLR and Supervised: p-value = 5.684091718480962e-18: diff -> 69.09 - 48.21 = 20.88
# Wilcoxon test between SupCon and Supervised: p-value = 6.811900045803711e-18: diff -> 61.99 - 48.21 = 13.78
#
#  ALL SUBJECTS Differences 85: {'SimCLR': [9.469999999999999, 16.53, 18.6, 19.040000000000003, 20.46, 17.58, 22.189999999999998, 23.400000000000002, 25.57, 26.32, 22.940000000000005, 24.230000000000004, 21.33, 21.75, 20.880000000000003], 'SupCon': [5.909999999999999, 6.859999999999999, 4.879999999999999, 2.4299999999999997, 6.149999999999999, 7.5, 11.089999999999996, 12.209999999999997, 13.36, 15.050000000000004, 14.93, 15.340000000000003, 14.979999999999997, 14.0, 13.780000000000001]}
#
# Average Difference: (20.69, 10.56)

# %%
file_paths = [
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/Supervised_results/Conformer_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SimCLR_results/Conformer_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SupCon_results/Conformer_1CLS_50Folfd_evaluation_results.txt')
]
process_results.plot_intra_and_BCI(file_paths, 'Conformer', retraining_chars=[1, 5, 10, 25, 40, 85], 
                                   dataset='BCI', significance_legend_loc = ['upper right', 'upper right', 'upper right', 'upper right', 'upper right', 'upper right'])
# Out:
# Analysing data from 1 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 16.26183844011145, p_value = 0.00029429755221970215)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 8.657533458729078e-06
# Wilcoxon test between SimCLR and SupCon: p-value = 0.00013937955307280085
# Wilcoxon test between Supervised and SupCon: p-value = 0.5820603720803204
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 6.296495956873227, p_value = 0.04292727052478093)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.00043765178181088264
# Wilcoxon test between SimCLR and SupCon: p-value = 0.01985043251730452
# Wilcoxon test between Supervised and SupCon: p-value = 0.09923674915876574
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 10.675675675675675, p_value = 0.004806251378781063)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.0004360374442597975
# Wilcoxon test between SimCLR and SupCon: p-value = 0.006169974755741353
# Wilcoxon test between Supervised and SupCon: p-value = 0.33320780657108817
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 13.770053475935828, p_value = 0.0010229888023490469)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.0001581823321508992
# Wilcoxon test between SimCLR and SupCon: p-value = 0.0032891388311567897
# Wilcoxon test between Supervised and SupCon: p-value = 0.22696802818574935
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 7.557333333333372, p_value = 0.02285314197618219)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.00015598320435341746
# Wilcoxon test between SimCLR and SupCon: p-value = 0.002527737634042821
# Wilcoxon test between Supervised and SupCon: p-value = 0.2932307117169686
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 6.9574468085106, p_value = 0.030846764756634393)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.008050599010050102
# Wilcoxon test between SimCLR and SupCon: p-value = 0.0947516955045207
# Wilcoxon test between Supervised and SupCon: p-value = 0.15876389344494424
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 3.080213903743432, p_value = 0.21435817419299696)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 5.698113207547258, p_value = 0.05789891673758505)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 9.217847769028843, p_value = 0.009962533377931557)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.0009223356628456699
# Wilcoxon test between SimCLR and SupCon: p-value = 0.027458298577284025
# Wilcoxon test between Supervised and SupCon: p-value = 0.10535447080553435
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 13.637333333333421, p_value = 0.0010931775210258749)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 8.625893027834123e-05
# Wilcoxon test between SimCLR and SupCon: p-value = 0.01911762910634671
# Wilcoxon test between Supervised and SupCon: p-value = 0.04588436089376633
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 11.918699186991999, p_value = 0.0025815905093601625)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 6.12274620282052e-05
# Wilcoxon test between SimCLR and SupCon: p-value = 0.017560998346997314
# Wilcoxon test between Supervised and SupCon: p-value = 0.03602578297476326
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 3.340259740259655, p_value = 0.18822261955533498)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 9.037037037036999, p_value = 0.01090516751092009)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.0004488391471764123
# Wilcoxon test between Supervised and SupCon: p-value = 0.04073654329433375
# Wilcoxon test between SimCLR and SupCon: p-value = 0.052216036599144
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 10.713910761154779, p_value = 0.004715240387763337)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.0006040277977027804
# Wilcoxon test between SimCLR and SupCon: p-value = 0.01758426087467672
# Wilcoxon test between Supervised and SupCon: p-value = 0.08570124167332636
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 11.683646112600517, p_value = 0.0029035444728201134)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.00030831569555939077
# Wilcoxon test between Supervised and SupCon: p-value = 0.010311337085924722
# Wilcoxon test between SimCLR and SupCon: p-value = 0.06894592835994842
# [array([2.93, 3.34, 3.47, 3.81, 3.89, 4.38, 4.68, 4.93, 4.81, 4.81, 4.93,
#        5.35, 5.06, 5.59, 5.65]), array([4.3 , 4.97, 5.04, 5.72, 6.08, 6.38, 6.76, 7.47, 7.76, 8.02, 8.66,
#        8.75, 8.99, 9.61, 9.79]), array([3.06, 3.75, 3.66, 4.15, 4.28, 4.93, 5.38, 5.86, 5.51, 5.75, 6.05,
#        6.11, 6.39, 6.62, 7.23])]
# Analysing data from 5 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 42.937329700272464, p_value = 4.745449124791355e-10)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0739353460284194e-10
# Wilcoxon test between SimCLR and SupCon: p-value = 6.046179428367298e-09
# Wilcoxon test between Supervised and SupCon: p-value = 0.004130698086988435
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 71.81151832460726, p_value = 2.548748171768451e-16)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 6.004033715457599e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 2.273674869538959e-09
# Wilcoxon test between Supervised and SupCon: p-value = 6.568927671311118e-06
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 68.29381443298982, p_value = 1.4797441162698194e-15)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.689765281815899e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 9.95595892394567e-11
# Wilcoxon test between Supervised and SupCon: p-value = 0.00012741610325998364
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 60.47894736842098, p_value = 7.364842153476313e-14)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.811118199580029e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 6.378813955044395e-10
# Wilcoxon test between Supervised and SupCon: p-value = 0.005120185343718808
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 49.26666666666675, p_value = 2.0039148445918275e-11)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.288265130462298e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 9.06680902527471e-08
# Wilcoxon test between Supervised and SupCon: p-value = 3.29101573681633e-07
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 44.14285714285713, p_value = 2.5971699164422386e-10)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.862023889936919e-12
# Wilcoxon test between SimCLR and SupCon: p-value = 4.7083277767060065e-07
# Wilcoxon test between Supervised and SupCon: p-value = 0.00029653943135673594
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 59.91348600508906, p_value = 9.77128809641633e-14)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 7.714367150429443e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 1.2219561309287424e-07
# Wilcoxon test between Supervised and SupCon: p-value = 4.001059243734923e-06
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 63.89285714285715, p_value = 1.3361104321429818e-14)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 7.98096848301761e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 9.220731650897539e-07
# Wilcoxon test between Supervised and SupCon: p-value = 4.543329332847155e-06
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 66.18227848101267, p_value = 4.2530533250133185e-15)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 8.713508283750473e-14
# Wilcoxon test between Supervised and SupCon: p-value = 5.9587314686041905e-08
# Wilcoxon test between SimCLR and SupCon: p-value = 1.4370048202102116e-06
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 60.48979591836732, p_value = 7.32500137585377e-14)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.4109214944767593e-13
# Wilcoxon test between Supervised and SupCon: p-value = 2.5398919261577636e-08
# Wilcoxon test between SimCLR and SupCon: p-value = 1.8872641696242771e-06
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 66.01538461538463, p_value = 4.62318604349075e-15)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.9915996818189182e-14
# Wilcoxon test between Supervised and SupCon: p-value = 5.153119381546463e-07
# Wilcoxon test between SimCLR and SupCon: p-value = 2.796383088871668e-06
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 56.899497487437195, p_value = 4.409924041690687e-13)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.38726778894958e-14
# Wilcoxon test between Supervised and SupCon: p-value = 7.548141600526426e-08
# Wilcoxon test between SimCLR and SupCon: p-value = 9.821270515956884e-06
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 57.00512820512813, p_value = 4.18305611071362e-13)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.0774346991822764e-13
# Wilcoxon test between Supervised and SupCon: p-value = 2.9644051245872216e-07
# Wilcoxon test between SimCLR and SupCon: p-value = 2.8014501758547752e-05
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 55.477157360406075, p_value = 8.98024826815276e-13)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.4532063585748767e-13
# Wilcoxon test between Supervised and SupCon: p-value = 1.1926144346248736e-06
# Wilcoxon test between SimCLR and SupCon: p-value = 3.645608019495645e-05
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 54.8142493638677, p_value = 1.2509414577097415e-12)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.9437405302093622e-13
# Wilcoxon test between Supervised and SupCon: p-value = 1.7394161512564542e-07
# Wilcoxon test between SimCLR and SupCon: p-value = 7.259549994625608e-05
# [array([ 4.38,  5.65,  6.61,  8.03,  8.25, 10.31, 10.56, 11.58, 11.91,
#        12.36, 12.93, 13.8 , 15.23, 16.5 , 16.58]), array([ 8.89, 13.13, 15.47, 17.29, 19.47, 21.95, 24.88, 26.21, 27.28,
#        28.87, 30.13, 31.74, 33.58, 35.45, 36.51]), array([ 5.44,  7.94,  8.72,  9.58, 11.81, 13.39, 14.92, 16.44, 17.84,
#        19.16, 19.82, 21.81, 23.54, 25.03, 26.34])]
# Analysing data from 10 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 86.37735849056605, p_value = 1.7514386249220457e-19)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.845503184131887e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 1.3983059275739392e-11
# Wilcoxon test between Supervised and SupCon: p-value = 3.2550895847150516e-07
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 111.13385826771655, p_value = 7.372067462846636e-25)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.5109975876156847e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 8.780140786784234e-12
# Wilcoxon test between Supervised and SupCon: p-value = 3.656512245897261e-10
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 110.21938775510215, p_value = 1.16456584730742e-24)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.5922812101753844e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 1.1013529246744215e-14
# Wilcoxon test between Supervised and SupCon: p-value = 5.762146407917349e-08
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 100.32642487046638, p_value = 1.6383008057025937e-22)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.0970335637282744e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 3.11382321382265e-13
# Wilcoxon test between Supervised and SupCon: p-value = 1.8180053048077208e-05
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 99.39845758354751, p_value = 2.605548615769657e-22)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.6627069446213658e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 3.4711616744746046e-11
# Wilcoxon test between Supervised and SupCon: p-value = 1.380228999680689e-09
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 82.3443037974684, p_value = 1.3157143830070452e-18)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.848570403625285e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 2.076445968791812e-09
# Wilcoxon test between Supervised and SupCon: p-value = 2.0047891744625374e-08
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 92.3807106598986, p_value = 8.705296407732728e-21)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.3654338509741114e-15
# Wilcoxon test between Supervised and SupCon: p-value = 2.8262420593848918e-12
# Wilcoxon test between SimCLR and SupCon: p-value = 1.320636380991477e-08
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 94.17766497461939, p_value = 3.544703315700853e-21)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.5435114311224026e-15
# Wilcoxon test between Supervised and SupCon: p-value = 2.1260342066248103e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 1.7631857302086509e-07
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 104.1776649746193, p_value = 2.3884023068675793e-23)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 8.344479014102482e-16
# Wilcoxon test between Supervised and SupCon: p-value = 6.196755246939697e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 4.3119148778020446e-08
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 111.04303797468351, p_value = 7.714551398864017e-25)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 6.457286750280953e-16
# Wilcoxon test between Supervised and SupCon: p-value = 2.786846196952954e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 2.058358050908581e-07
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 102.07537688442217, p_value = 6.833033350952174e-23)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.3752892978286784e-16
# Wilcoxon test between Supervised and SupCon: p-value = 2.811148357092736e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 5.402408030495656e-07
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 91.86768447837149, p_value = 1.1250861614679301e-20)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 9.460317554112637e-16
# Wilcoxon test between Supervised and SupCon: p-value = 7.561389808521399e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 4.091286934872754e-06
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 93.10379746835449, p_value = 6.064112611694387e-21)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 7.888188063634957e-16
# Wilcoxon test between Supervised and SupCon: p-value = 3.435155974244697e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 2.1331315643843358e-05
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 96.14105793450888, p_value = 1.3281114697820378e-21)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 8.11281144983107e-16
# Wilcoxon test between Supervised and SupCon: p-value = 4.5097761758669124e-13
# Wilcoxon test between SimCLR and SupCon: p-value = 1.93012839009187e-05
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 85.50125944584396, p_value = 2.7141722971155674e-19)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 5.5656520263700775e-16
# Wilcoxon test between Supervised and SupCon: p-value = 3.0002188102660057e-14
# Wilcoxon test between SimCLR and SupCon: p-value = 4.25614856809792e-05
# [array([ 5.09,  7.79,  9.42, 11.42, 12.56, 15.07, 15.96, 17.13, 17.96,
#        18.43, 20.03, 22.11, 23.76, 25.88, 26.49]), array([11.01, 18.44, 22.67, 25.45, 28.54, 31.48, 34.25, 35.81, 36.96,
#        39.1 , 40.75, 43.41, 45.23, 48.38, 49.35]), array([ 7.16, 11.53, 12.75, 14.19, 17.26, 20.32, 23.53, 26.02, 27.24,
#        29.48, 31.33, 34.87, 37.67, 40.18, 41.93])]
# Analysing data from 25 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 139.97894736842107, p_value = 4.017517596589498e-31)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 8.87546090629089e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 6.45721525175352e-14
# Wilcoxon test between Supervised and SupCon: p-value = 1.0723945947738552e-12
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 163.07416879795392, p_value = 3.8805579653885965e-36)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1399050381013225e-17
# Wilcoxon test between Supervised and SupCon: p-value = 8.353523862164295e-16
# Wilcoxon test between SimCLR and SupCon: p-value = 1.5226708561885637e-15
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 178.56265984654738, p_value = 1.6811678546625865e-39)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.148758736662577e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.710917297390275e-17
# Wilcoxon test between Supervised and SupCon: p-value = 8.045289084914189e-16
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 164.65306122448993, p_value = 1.7621466186428712e-36)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1789666959816289e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 2.4442039491536017e-17
# Wilcoxon test between Supervised and SupCon: p-value = 3.8010326165933476e-14
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 173.86802030456852, p_value = 1.7580818934615481e-38)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.137332241927526e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 7.980383052815908e-17
# Wilcoxon test between Supervised and SupCon: p-value = 6.310222815815559e-16
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 168.20304568527925, p_value = 2.9865700788948845e-37)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1437745793496694e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.1774924817496985e-16
# Wilcoxon test between Supervised and SupCon: p-value = 4.0101897361183747e-16
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 179.46365914786978, p_value = 1.0714244800213232e-39)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1498619061811618e-17
# Wilcoxon test between Supervised and SupCon: p-value = 6.1948379884908324e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 3.4023842187240785e-15
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 182.2424242424243, p_value = 2.6703020638725135e-40)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SupCon: p-value = 1.123661025006585e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.758405403873735e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 2.7516485875989333e-15
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 190.08020050125313, p_value = 5.3040657818878024e-42)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SupCon: p-value = 1.1129118973448229e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.71984191453995e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 4.8478439751674406e-17
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 182.0, p_value = 3.014408785065379e-40)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SupCon: p-value = 1.1315635627003739e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.708223967005542e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 7.060354071905941e-16
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 176.84771573604056, p_value = 3.9628392819678755e-39)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1359837285197777e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.96569636483098e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.1564806302526498e-14
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 179.1717171717173, p_value = 1.2398123542017158e-39)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SupCon: p-value = 1.129263866564592e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.661975495240824e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 1.8934868060534256e-14
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 172.1060606060606, p_value = 4.2427143051909344e-38)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.126968601488495e-17
# Wilcoxon test between Supervised and SupCon: p-value = 8.563847136726548e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 4.210585805199381e-12
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 175.07035175879392, p_value = 9.637316970977251e-39)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1751801909245009e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.0071944311909435e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 9.93109375625148e-15
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 170.01012658227847, p_value = 1.2099573966885234e-37)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1816974704557172e-17
# Wilcoxon test between Supervised and SupCon: p-value = 7.284218400978858e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 5.931781188212604e-14
# [array([ 6.44,  9.73, 13.28, 15.94, 18.39, 23.16, 24.11, 25.37, 25.89,
#        27.63, 30.68, 32.95, 35.42, 38.65, 40.03]), array([13.62, 23.82, 30.07, 34.86, 38.1 , 42.58, 45.78, 48.6 , 51.52,
#        53.69, 55.06, 58.49, 59.9 , 62.84, 63.71]), array([10.12, 15.57, 18.85, 20.81, 25.37, 30.15, 34.63, 38.34, 39.52,
#        42.19, 45.25, 49.46, 52.52, 55.37, 56.94])]
# Analysing data from 40 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 150.91145833333334, p_value = 1.6982170424628365e-33)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.07155011192816e-17
# Wilcoxon test between Supervised and SupCon: p-value = 8.02536380642163e-15
# Wilcoxon test between SimCLR and SupCon: p-value = 2.500601656310397e-10
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 174.67512690355338, p_value = 1.1742974830176454e-38)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.649002056534426e-17
# Wilcoxon test between Supervised and SupCon: p-value = 2.8374894453202e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 6.362624535469504e-17
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 182.22506393861892, p_value = 2.6935815801154348e-40)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and SupCon: p-value = 1.1276694628507817e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.679918642598889e-18
# Wilcoxon test between Supervised and SupCon: p-value = 1.4440709799944077e-14
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 173.0761421319797, p_value = 2.612120824432085e-38)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1227720972317467e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 5.685055148660282e-18
# Wilcoxon test between Supervised and SupCon: p-value = 3.4117150337739236e-12
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 181.46000000000004, p_value = 3.948768348413574e-40)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1327150749373942e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 6.971715044114242e-18
# Wilcoxon test between Supervised and SupCon: p-value = 7.779316469577363e-16
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 181.00251889168763, p_value = 4.963664477581227e-40)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1311799719562301e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 2.6513883400250283e-17
# Wilcoxon test between Supervised and SupCon: p-value = 3.8025655501907745e-17
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 179.4609571788413, p_value = 1.0728729361025672e-39)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1436453942692425e-17
# Wilcoxon test between Supervised and SupCon: p-value = 2.0971632306122753e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 2.506040648214801e-16
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 184.0603015075378, p_value = 1.076002694579976e-40)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1419027489015622e-17
# Wilcoxon test between Supervised and SupCon: p-value = 8.156067793988204e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 6.233882750653017e-17
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 197.02010050251263, p_value = 1.6505503000453228e-43)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1207427650175903e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 8.234556251123257e-18
# Wilcoxon test between Supervised and SupCon: p-value = 6.018582920812344e-18
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 192.1400000000001, p_value = 1.8937782463901564e-42)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.120679404448172e-17
# Wilcoxon test between Supervised and SupCon: p-value = 6.447577915544503e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 1.3705241794460362e-17
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 187.19597989949747, p_value = 2.2434141127760785e-41)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1246141879719175e-17
# Wilcoxon test between Supervised and SupCon: p-value = 7.43555147872828e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 1.5573014152475986e-17
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 187.67512690355343, p_value = 1.765484860183598e-41)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1115908489387507e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.2165816490501327e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.9405186558804354e-16
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 170.64810126582287, p_value = 8.79499580190809e-38)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1173261493545757e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.9786889887429212e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.084458427479643e-14
#
# N Trials -> 14
#
# Is data Normally Distributed? - True
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 178.50505050505055, p_value = 1.7302975262991987e-39)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1322031546461092e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.2665863155675058e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 7.688492429455329e-17
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 179.91392405063286, p_value = 8.554365132209062e-40)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1390682747901122e-17
# Wilcoxon test between Supervised and SupCon: p-value = 2.681030903072224e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 2.0095159441722344e-17
# [array([ 6.74, 10.3 , 14.89, 17.74, 20.44, 25.43, 25.95, 28.34, 28.88,
#        31.31, 33.69, 36.65, 39.11, 43.48, 45.06]), array([14.48, 25.56, 33.08, 37.12, 41.09, 44.67, 48.47, 51.29, 54.52,
#        57.11, 57.62, 61.43, 62.71, 65.72, 67.16]), array([11.55, 16.83, 19.96, 21.69, 27.47, 33.27, 37.14, 40.67, 42.49,
#        45.43, 48.31, 52.7 , 55.67, 58.39, 59.63])]
# Analysing data from 85 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 159.25000000000006, p_value = 2.6260432739767623e-35)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0314728079064126e-17
# Wilcoxon test between Supervised and SupCon: p-value = 7.230961169400791e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.510847727851178e-13
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 197.5037974683545, p_value = 1.295971056284295e-43)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1108366317184433e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.1697933006184954e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.1094857343312447e-17
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 187.15151515151513, p_value = 2.2938491017230793e-41)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and SupCon: p-value = 1.1146756105400984e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.5878944649863615e-18
# Wilcoxon test between Supervised and SupCon: p-value = 5.683619717738957e-16
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 163.81074168797954, p_value = 2.6850316183032747e-36)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1003283972643606e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 5.672222131725827e-18
# Wilcoxon test between Supervised and SupCon: p-value = 2.321207255266998e-07
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 191.4572864321608, p_value = 2.664271573986494e-42)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1008266450679597e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 5.565503699990726e-18
# Wilcoxon test between Supervised and SupCon: p-value = 1.3419089736822728e-17
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 189.26448362720404, p_value = 7.975163038395511e-42)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.076113495158822e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 5.659416579233613e-18
# Wilcoxon test between Supervised and SupCon: p-value = 4.727314844575954e-17
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 185.21717171717174, p_value = 6.03395663641137e-41)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1359195514177846e-17
# Wilcoxon test between Supervised and SupCon: p-value = 7.947350053032915e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 2.168022814638109e-16
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 196.07999999999993, p_value = 2.6410036061004486e-43)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SupCon: p-value = 1.0928802871967835e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.552926669016348e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 4.9545318146620105e-18
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0819815140112091e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 5.426785274410355e-18
# Wilcoxon test between Supervised and SupCon: p-value = 3.763362061471374e-18
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 199.50375939849633, p_value = 4.767701831604771e-44)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0735557356638861e-17
# Wilcoxon test between Supervised and SupCon: p-value = 5.485164507315061e-18
# Wilcoxon test between SimCLR and SupCon: p-value = 5.366607943943742e-18
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 11:
# Wilcoxon test between SimCLR and SupCon: p-value = 1.0610336155369925e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.508807181228658e-18
# Wilcoxon test between Supervised and SupCon: p-value = 3.759748079857097e-18
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 200.0, p_value = 3.7200759760208177e-44)
# Post-hoc Wilcoxon tests for trial 12:
# Wilcoxon test between SimCLR and SupCon: p-value = 1.076479360642519e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.622117470408576e-18
# Wilcoxon test between Supervised and SupCon: p-value = 3.8160285270189416e-18
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 164.60000000000014, p_value = 1.8095231323686558e-36)
# Post-hoc Wilcoxon tests for trial 13:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.111213679666859e-17
# Wilcoxon test between Supervised and SupCon: p-value = 1.2037986118803578e-17
# Wilcoxon test between SimCLR and SupCon: p-value = 1.1284757715548038e-13
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 199.50375939849633, p_value = 4.767701831604771e-44)
# Post-hoc Wilcoxon tests for trial 14:
# Wilcoxon test between SimCLR and SupCon: p-value = 1.0413567384503606e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.685697521445168e-18
# Wilcoxon test between Supervised and SupCon: p-value = 5.4903373989512284e-18
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 197.53884711779455, p_value = 1.2734572422030736e-43)
# Post-hoc Wilcoxon tests for trial 15:
# Wilcoxon test between SimCLR and SupCon: p-value = 1.0338767199731035e-17
# Wilcoxon test between Supervised and SimCLR: p-value = 5.684091718480962e-18
# Wilcoxon test between Supervised and SupCon: p-value = 6.811900045803711e-18
# [array([ 6.71, 10.86, 16.36, 20.05, 22.71, 28.35, 28.71, 31.52, 32.1 ,
#        32.97, 36.8 , 39.58, 42.53, 47.3 , 48.21]), array([16.18, 27.39, 34.96, 39.09, 43.17, 45.93, 50.9 , 54.92, 57.67,
#        59.29, 59.74, 63.81, 63.86, 69.05, 69.09]), array([12.62, 17.72, 21.24, 22.48, 28.86, 35.85, 39.8 , 43.73, 45.46,
#        48.02, 51.73, 54.92, 57.51, 61.3 , 61.99])]

# %% [markdown]
# ## ALS Dataset Evaluation

# %%
files =   [
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/Supervised_results/EEGNet_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SimCLR_results/EEGNet_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SupCon_results/EEGNet_1CLS_50Folfd_evaluation_results.txt')
    ]
process_results.get_differences_als(files, 'EEGNet')
# Out:
# EEGNet
#
# Supervised
# 8.28 ± 5.40 & 29.12 ± 19.18 & 41.52 ± 22.35
#
# SimCLR
# 17.04 ± 9.64 & 49.26 ± 18.48 & 66.23 ± 16.40
#
# SupCon
# 16.80 ± 7.93 & 44.83 ± 21.49 & 59.95 ± 20.80
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 354.9178470254959, p_value = 8.522534224363585e-78)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SupCon and Supervised: p-value = 5.095105170298128e-53: diff -> 16.80 - 8.28 = 8.52
# Wilcoxon test between SimCLR and Supervised: p-value = 2.1792289042013823e-49: diff -> 17.04 - 8.28 = 8.76
# Wilcoxon test between SupCon and SimCLR: p-value = 0.23082677119790762: diff -> 16.80 - 17.04 = -0.24
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 253.62301587301582, p_value = 8.44232100300851e-56)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SupCon and Supervised: p-value = 3.9883833009807087e-38: diff -> 25.86 - 16.23 = 9.63
# Wilcoxon test between SimCLR and Supervised: p-value = 5.314536962081886e-34: diff -> 26.12 - 16.23 = 9.89
# Wilcoxon test between SupCon and SimCLR: p-value = 0.538731953399577: diff -> 25.86 - 26.12 = -0.26
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 209.31571994716037, p_value = 3.529140313898226e-46)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.411644131610091e-45: diff -> 37.10 - 18.77 = 18.33
# Wilcoxon test between SupCon and Supervised: p-value = 3.897750515227371e-35: diff -> 33.06 - 18.77 = 14.29
# Wilcoxon test between SupCon and SimCLR: p-value = 6.053527605547961e-26: diff -> 33.06 - 37.10 = -4.04
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 239.56413612565498, p_value = 9.534739000153586e-53)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.1065570753100676e-49: diff -> 45.57 - 22.93 = 22.64
# Wilcoxon test between SupCon and Supervised: p-value = 3.7977112746411e-38: diff -> 40.53 - 22.93 = 17.60
# Wilcoxon test between SupCon and SimCLR: p-value = 1.73271128505984e-33: diff -> 40.53 - 45.57 = -5.04
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 204.4290343486712, p_value = 4.0625546927518625e-45)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and Supervised: p-value = 4.792458338018366e-43: diff -> 49.26 - 29.12 = 20.14
# Wilcoxon test between SupCon and Supervised: p-value = 3.255030741789101e-25: diff -> 44.83 - 29.12 = 15.71
# Wilcoxon test between SupCon and SimCLR: p-value = 2.2326255598064613e-19: diff -> 44.83 - 49.26 = -4.43
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 171.69180754226238, p_value = 5.219124996449086e-38)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and Supervised: p-value = 2.029049232578958e-41: diff -> 53.52 - 31.68 = 21.84
# Wilcoxon test between SupCon and Supervised: p-value = 6.972287634352894e-27: diff -> 50.58 - 31.68 = 18.90
# Wilcoxon test between SupCon and SimCLR: p-value = 6.862865875646829e-12: diff -> 50.58 - 53.52 = -2.94
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 291.66840052015607, p_value = 4.623933230711947e-64)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and Supervised: p-value = 6.314046989931105e-54: diff -> 59.54 - 33.22 = 26.33
# Wilcoxon test between SupCon and Supervised: p-value = 2.0761949653048302e-36: diff -> 54.13 - 33.22 = 20.91
# Wilcoxon test between SupCon and SimCLR: p-value = 4.033495449994448e-31: diff -> 54.13 - 59.54 = -5.42
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 215.43880208333331, p_value = 1.6521844626309738e-47)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and Supervised: p-value = 8.745968662687251e-51: diff -> 61.94 - 35.59 = 26.35
# Wilcoxon test between SupCon and Supervised: p-value = 6.572544543804601e-32: diff -> 57.20 - 35.59 = 21.61
# Wilcoxon test between SupCon and SimCLR: p-value = 9.209700059788995e-21: diff -> 57.20 - 61.94 = -4.74
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 268.001278772379, p_value = 6.3717942413195475e-59)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.5085220126861004e-53: diff -> 65.25 - 38.57 = 26.68
# Wilcoxon test between SupCon and Supervised: p-value = 3.634297371336802e-28: diff -> 58.81 - 38.57 = 20.24
# Wilcoxon test between SupCon and SimCLR: p-value = 3.62615340653926e-23: diff -> 58.81 - 65.25 = -6.44
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 209.08756345177673, p_value = 3.955601010355424e-46)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.8789797949504043e-46: diff -> 66.23 - 41.52 = 24.71
# Wilcoxon test between SupCon and SimCLR: p-value = 4.1141985543462124e-32: diff -> 59.95 - 66.23 = -6.28
# Wilcoxon test between SupCon and Supervised: p-value = 5.093522959924071e-24: diff -> 59.95 - 41.52 = 18.43
#
# Differences: {'SimCLR': [8.757499999999991, 9.893499999999932, 18.330250000000017, 22.64250000000008, 20.138500000000075, 21.840499999999878, 26.326750000000004, 26.35324999999994, 26.683999999999997, 24.705250000000028], 'SupCon': [8.519500000000013, 9.629999999999953, 14.294249999999995, 17.6020000000001, 15.70800000000003, 18.895750000000156, 20.907750000000036, 21.61049999999998, 20.23975000000008, 18.426000000000045]}
#
# Average Difference: (20.57, 16.58)

# %%
files =   [
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/Supervised_results/EEGInception_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SimCLR_results/EEGInception_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SupCon_results/EEGInception_1CLS_50Folfd_evaluation_results.txt')
    ]
process_results.get_differences_als(files, 'EEGInception')
# Out:
# EEGInception
#
# Supervised
# 10.51 ± 6.60 & 15.75 ± 9.88 & 25.71 ± 17.23
#
# SimCLR
# 4.15 ± 4.29 & 14.17 ± 12.13 & 16.01 ± 16.01
#
# SupCon
# 5.22 ± 4.60 & 15.73 ± 11.56 & 23.77 ± 15.40
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 182.40504451038626, p_value = 2.4617721199642416e-40)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.2608706101888595e-30: diff -> 4.15 - 10.51 = -6.36
# Wilcoxon test between SupCon and Supervised: p-value = 1.7090522348154152e-24: diff -> 5.22 - 10.51 = -5.29
# Wilcoxon test between SupCon and SimCLR: p-value = 1.3299070483250181e-05: diff -> 5.22 - 4.15 = 1.07
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 125.92090395480284, p_value = 4.5354786621509315e-28)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 1.9586780512684174e-22: diff -> 6.84 - 13.33 = -6.49
# Wilcoxon test between SupCon and Supervised: p-value = 9.408930965752032e-19: diff -> 7.82 - 13.33 = -5.51
# Wilcoxon test between SupCon and SimCLR: p-value = 0.003682726621743659: diff -> 7.82 - 6.84 = 0.98
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 48.96708119970773, p_value = 2.3277343745513708e-11)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SupCon and SimCLR: p-value = 1.6568107713490163e-11: diff -> 11.48 - 9.13 = 2.35
# Wilcoxon test between SimCLR and Supervised: p-value = 3.1426162567686066e-05: diff -> 9.13 - 11.45 = -2.32
# Wilcoxon test between SupCon and Supervised: p-value = 0.7232549790861217: diff -> 11.48 - 11.45 = 0.03
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 14.633073101490956, p_value = 0.0006644595524950737)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 0.14388963604795968: diff -> 12.21 - 14.25 = -2.04
# Wilcoxon test between SupCon and SimCLR: p-value = 0.107047490187802: diff -> 12.48 - 12.21 = 0.27
# Wilcoxon test between SupCon and Supervised: p-value = 0.8477247066340686: diff -> 12.48 - 14.25 = -1.77
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 15.198657718121234, p_value = 0.0005007874196201943)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SupCon and SimCLR: p-value = 0.00023228811578775805: diff -> 15.73 - 14.17 = 1.56
# Wilcoxon test between SupCon and Supervised: p-value = 0.17006125171596498: diff -> 15.73 - 15.75 = -0.02
# Wilcoxon test between SimCLR and Supervised: p-value = 0.3345537859191259: diff -> 14.17 - 15.75 = -1.58
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Friedman Test results: (F-stat = 6.891873740765302, p_value = 0.031874885413434514)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SupCon and SimCLR: p-value = 7.471962428764588e-06: diff -> 18.06 - 15.48 = 2.58
# Wilcoxon test between SimCLR and Supervised: p-value = 0.0024694527175651787: diff -> 15.48 - 20.61 = -5.13
# Wilcoxon test between SupCon and Supervised: p-value = 0.724873489450137: diff -> 18.06 - 20.61 = -2.55
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 41.74240422721241, p_value = 8.624860736844457e-10)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SupCon and SimCLR: p-value = 2.573544336695849e-18: diff -> 21.78 - 16.37 = 5.41
# Wilcoxon test between SimCLR and Supervised: p-value = 3.1291193500558274e-06: diff -> 16.37 - 22.37 = -6.00
# Wilcoxon test between SupCon and Supervised: p-value = 0.45804598037479516: diff -> 21.78 - 22.37 = -0.59
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 42.34602538410142, p_value = 6.377895843657878e-10)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SupCon and SimCLR: p-value = 9.405770132906733e-24: diff -> 21.89 - 15.89 = 6.00
# Wilcoxon test between SimCLR and Supervised: p-value = 9.232368305865872e-13: diff -> 15.89 - 24.68 = -8.79
# Wilcoxon test between SupCon and Supervised: p-value = 0.11047316152411941: diff -> 21.89 - 24.68 = -2.79
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 40.17300131061653, p_value = 1.890356019878444e-09)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SupCon and SimCLR: p-value = 2.4063606848841817e-23: diff -> 24.18 - 16.59 = 7.59
# Wilcoxon test between SimCLR and Supervised: p-value = 7.45945279160247e-11: diff -> 16.59 - 25.34 = -8.75
# Wilcoxon test between SupCon and Supervised: p-value = 0.5015304101632869: diff -> 24.18 - 25.34 = -1.16
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 57.40143135979147, p_value = 3.4311330058095057e-13)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SupCon and SimCLR: p-value = 2.3771471112623268e-26: diff -> 23.77 - 16.01 = 7.76
# Wilcoxon test between SimCLR and Supervised: p-value = 6.793280524338001e-13: diff -> 16.01 - 25.71 = -9.70
# Wilcoxon test between SupCon and Supervised: p-value = 0.21135820794566373: diff -> 23.77 - 25.71 = -1.94
#
# Differences: {'SimCLR': [-6.359499999999977, -6.490249999999968, -2.3152499999999723, -5.134500000000003, -6.00025000000004, -8.792250000000017, -8.746750000000127, -9.700500000000083], 'SupCon': [-5.288249999999971, -5.507999999999965]}
#
# Average Difference: (-6.69, -5.40)

# %%
files =   [
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/Supervised_results/Conformer_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SimCLR_results/Conformer_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SupCon_results/Conformer_1CLS_50Folfd_evaluation_results.txt')
    ]
process_results.get_differences_als(files, 'Conformer')
# Out:
# Conformer
#
# Supervised
# 4.61 ± 4.03 & 11.96 ± 9.37 & 16.15 ± 12.38
#
# SimCLR
# 6.04 ± 4.89 & 21.90 ± 12.21 & 34.35 ± 18.45
#
# SupCon
# 5.36 ± 4.60 & 13.68 ± 9.51 & 17.24 ± 11.20
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 27.903816793893753, p_value = 8.724954507296358e-07)
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between SimCLR and Supervised: p-value = 5.85245379676886e-06: diff -> 6.04 - 4.61 = 1.43
# Wilcoxon test between SupCon and SimCLR: p-value = 0.014054847657371144: diff -> 5.36 - 6.04 = -0.68
# Wilcoxon test between SupCon and Supervised: p-value = 0.010746446460620668: diff -> 5.36 - 4.61 = 0.75
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 165.40261627906995, p_value = 1.2113739463199407e-36)
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.3293207985315463e-37: diff -> 12.23 - 6.29 = 5.94
# Wilcoxon test between SupCon and SimCLR: p-value = 1.3112838504844145e-31: diff -> 7.72 - 12.23 = -4.51
# Wilcoxon test between SupCon and Supervised: p-value = 0.00010404670260476994: diff -> 7.72 - 6.29 = 1.43
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 133.9986216402486, p_value = 7.990409177728859e-30)
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SupCon and SimCLR: p-value = 2.102206496692066e-37: diff -> 9.97 - 16.27 = -6.30
# Wilcoxon test between SimCLR and Supervised: p-value = 5.83133583891429e-28: diff -> 16.27 - 9.46 = 6.81
# Wilcoxon test between SupCon and Supervised: p-value = 0.24120984104592125: diff -> 9.97 - 9.46 = 0.51
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 275.1020124913255, p_value = 1.829603604779453e-60)
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between SimCLR and Supervised: p-value = 3.61613227787343e-49: diff -> 19.54 - 9.91 = 9.63
# Wilcoxon test between SupCon and SimCLR: p-value = 1.8776147708088414e-41: diff -> 10.55 - 19.54 = -9.00
# Wilcoxon test between SupCon and Supervised: p-value = 0.1295023548734976: diff -> 10.55 - 9.91 = 0.63
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 163.4262182566915, p_value = 3.25422521922619e-36)
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SupCon and SimCLR: p-value = 9.16068034385095e-36: diff -> 13.68 - 21.90 = -8.23
# Wilcoxon test between SimCLR and Supervised: p-value = 1.6740678764951238e-32: diff -> 21.90 - 11.96 = 9.94
# Wilcoxon test between SupCon and Supervised: p-value = 0.6968038800586281: diff -> 13.68 - 11.96 = 1.72
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 263.7976501305486, p_value = 5.212764495504242e-58)
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SupCon and SimCLR: p-value = 9.286908707060733e-46: diff -> 15.12 - 27.03 = -11.91
# Wilcoxon test between SimCLR and Supervised: p-value = 1.9512530176364625e-36: diff -> 27.03 - 14.40 = 12.63
# Wilcoxon test between SupCon and Supervised: p-value = 0.46780939653216613: diff -> 15.12 - 14.40 = 0.72
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 234.29778933680103, p_value = 1.327032271633407e-51)
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SupCon and SimCLR: p-value = 1.5166684909743587e-49: diff -> 15.55 - 30.24 = -14.69
# Wilcoxon test between SimCLR and Supervised: p-value = 1.5017221117861618e-38: diff -> 30.24 - 14.27 = 15.96
# Wilcoxon test between SupCon and Supervised: p-value = 0.43168905495068843: diff -> 15.55 - 14.27 = 1.28
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 205.0220779220777, p_value = 3.0201008464491356e-45)
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SupCon and SimCLR: p-value = 2.578295581421659e-46: diff -> 15.44 - 31.12 = -15.68
# Wilcoxon test between SimCLR and Supervised: p-value = 1.6683193637839865e-33: diff -> 31.12 - 15.72 = 15.40
# Wilcoxon test between SupCon and Supervised: p-value = 0.16971854248952623: diff -> 15.44 - 15.72 = -0.27
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 215.48734587929937, p_value = 1.6125655678125803e-47)
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SupCon and SimCLR: p-value = 2.118783512138459e-48: diff -> 16.98 - 33.04 = -16.06
# Wilcoxon test between SimCLR and Supervised: p-value = 1.0878551331829465e-37: diff -> 33.04 - 15.97 = 17.07
# Wilcoxon test between SupCon and Supervised: p-value = 0.8817821233547263: diff -> 16.98 - 15.97 = 1.01
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Friedman Test results: (F-stat = 312.3551769331591, p_value = 1.4891386372877756e-68)
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SupCon and SimCLR: p-value = 6.133936318042028e-52: diff -> 17.24 - 34.35 = -17.11
# Wilcoxon test between SimCLR and Supervised: p-value = 5.883282174249329e-44: diff -> 34.35 - 16.15 = 18.20
# Wilcoxon test between SupCon and Supervised: p-value = 0.23472480249417949: diff -> 17.24 - 16.15 = 1.09
#
# Differences: {'SimCLR': [1.433499999999973, 5.940749999999996, 6.806000000000001, 9.631000000000004, 9.944249999999995, 12.633000000000035, 15.964500000000044, 15.402500000000037, 17.069749999999928, 18.195999999999994], 'SupCon': [0.7517499999999817, 1.429500000000007]}
#
# Average Difference: (11.30, 1.09)

# %%
reload(process_results)
files = [
    [
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/Supervised_results/EEGNet_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SimCLR_results/EEGNet_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SupCon_results/EEGNet_1CLS_50Folfd_evaluation_results.txt')
    ],
    [
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/Supervised_results/EEGInception_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SimCLR_results/EEGInception_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SupCon_results/EEGInception_1CLS_50Folfd_evaluation_results.txt')
    ],
    [
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/Supervised_results/Conformer_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SimCLR_results/Conformer_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/ALS Results/SupCon_results/Conformer_1CLS_50Folfd_evaluation_results.txt')
    ]
]

model_names = ['EEGNet', 'EEGInception', 'Conformer']

process_results.plot_als_results(files, model_names)
# Out:
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SupCon: p-value = 5.095105170298128e-53
# Wilcoxon test between Supervised and SimCLR: p-value = 2.1792289042013823e-49
# Wilcoxon test between SimCLR and SupCon: p-value = 0.23082677119790762
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SupCon: p-value = 3.9883833009807087e-38
# Wilcoxon test between Supervised and SimCLR: p-value = 5.314536962081886e-34
# Wilcoxon test between SimCLR and SupCon: p-value = 0.538731953399577
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.411644131610091e-45
# Wilcoxon test between Supervised and SupCon: p-value = 3.897750515227371e-35
# Wilcoxon test between SimCLR and SupCon: p-value = 6.053527605547961e-26
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.1065570753100676e-49
# Wilcoxon test between Supervised and SupCon: p-value = 3.7977112746411e-38
# Wilcoxon test between SimCLR and SupCon: p-value = 1.73271128505984e-33
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between Supervised and SimCLR: p-value = 4.792458338018366e-43
# Wilcoxon test between Supervised and SupCon: p-value = 3.255030741789101e-25
# Wilcoxon test between SimCLR and SupCon: p-value = 2.2326255598064613e-19
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between Supervised and SimCLR: p-value = 2.029049232578958e-41
# Wilcoxon test between Supervised and SupCon: p-value = 6.972287634352894e-27
# Wilcoxon test between SimCLR and SupCon: p-value = 6.862865875646829e-12
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between Supervised and SimCLR: p-value = 6.314046989931105e-54
# Wilcoxon test between Supervised and SupCon: p-value = 2.0761949653048302e-36
# Wilcoxon test between SimCLR and SupCon: p-value = 4.033495449994448e-31
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between Supervised and SimCLR: p-value = 8.745968662687251e-51
# Wilcoxon test between Supervised and SupCon: p-value = 6.572544543804601e-32
# Wilcoxon test between SimCLR and SupCon: p-value = 9.209700059788995e-21
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.5085220126861004e-53
# Wilcoxon test between Supervised and SupCon: p-value = 3.634297371336802e-28
# Wilcoxon test between SimCLR and SupCon: p-value = 3.62615340653926e-23
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.8789797949504043e-46
# Wilcoxon test between SimCLR and SupCon: p-value = 4.1141985543462124e-32
# Wilcoxon test between Supervised and SupCon: p-value = 5.093522959924071e-24
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.2608706101888595e-30
# Wilcoxon test between Supervised and SupCon: p-value = 1.7090522348154152e-24
# Wilcoxon test between SimCLR and SupCon: p-value = 1.3299070483250181e-05
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 1.9586780512684174e-22
# Wilcoxon test between Supervised and SupCon: p-value = 9.408930965752032e-19
# Wilcoxon test between SimCLR and SupCon: p-value = 0.003682726621743659
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and SupCon: p-value = 1.6568107713490163e-11
# Wilcoxon test between Supervised and SimCLR: p-value = 3.1426162567686066e-05
# Wilcoxon test between Supervised and SupCon: p-value = 0.7232549790861217
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 0.14388963604795968
# Wilcoxon test between SimCLR and SupCon: p-value = 0.107047490187802
# Wilcoxon test between Supervised and SupCon: p-value = 0.8477247066340686
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and SupCon: p-value = 0.00023228811578775805
# Wilcoxon test between Supervised and SupCon: p-value = 0.17006125171596498
# Wilcoxon test between Supervised and SimCLR: p-value = 0.3345537859191259
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and SupCon: p-value = 7.471962428764588e-06
# Wilcoxon test between Supervised and SimCLR: p-value = 0.0024694527175651787
# Wilcoxon test between Supervised and SupCon: p-value = 0.724873489450137
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and SupCon: p-value = 2.573544336695849e-18
# Wilcoxon test between Supervised and SimCLR: p-value = 3.1291193500558274e-06
# Wilcoxon test between Supervised and SupCon: p-value = 0.45804598037479516
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and SupCon: p-value = 9.405770132906733e-24
# Wilcoxon test between Supervised and SimCLR: p-value = 9.232368305865872e-13
# Wilcoxon test between Supervised and SupCon: p-value = 0.11047316152411941
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and SupCon: p-value = 2.4063606848841817e-23
# Wilcoxon test between Supervised and SimCLR: p-value = 7.45945279160247e-11
# Wilcoxon test between Supervised and SupCon: p-value = 0.5015304101632869
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and SupCon: p-value = 2.3771471112623268e-26
# Wilcoxon test between Supervised and SimCLR: p-value = 6.793280524338001e-13
# Wilcoxon test between Supervised and SupCon: p-value = 0.21135820794566373
# Post-hoc Wilcoxon tests for trial 1:
# Wilcoxon test between Supervised and SimCLR: p-value = 5.85245379676886e-06
# Wilcoxon test between SimCLR and SupCon: p-value = 0.014054847657371144
# Wilcoxon test between Supervised and SupCon: p-value = 0.010746446460620668
# Post-hoc Wilcoxon tests for trial 2:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.3293207985315463e-37
# Wilcoxon test between SimCLR and SupCon: p-value = 1.3112838504844145e-31
# Wilcoxon test between Supervised and SupCon: p-value = 0.00010404670260476994
# Post-hoc Wilcoxon tests for trial 3:
# Wilcoxon test between SimCLR and SupCon: p-value = 2.102206496692066e-37
# Wilcoxon test between Supervised and SimCLR: p-value = 5.83133583891429e-28
# Wilcoxon test between Supervised and SupCon: p-value = 0.24120984104592125
# Post-hoc Wilcoxon tests for trial 4:
# Wilcoxon test between Supervised and SimCLR: p-value = 3.61613227787343e-49
# Wilcoxon test between SimCLR and SupCon: p-value = 1.8776147708088414e-41
# Wilcoxon test between Supervised and SupCon: p-value = 0.1295023548734976
# Post-hoc Wilcoxon tests for trial 5:
# Wilcoxon test between SimCLR and SupCon: p-value = 9.16068034385095e-36
# Wilcoxon test between Supervised and SimCLR: p-value = 1.6740678764951238e-32
# Wilcoxon test between Supervised and SupCon: p-value = 0.6968038800586281
# Post-hoc Wilcoxon tests for trial 6:
# Wilcoxon test between SimCLR and SupCon: p-value = 9.286908707060733e-46
# Wilcoxon test between Supervised and SimCLR: p-value = 1.9512530176364625e-36
# Wilcoxon test between Supervised and SupCon: p-value = 0.46780939653216613
# Post-hoc Wilcoxon tests for trial 7:
# Wilcoxon test between SimCLR and SupCon: p-value = 1.5166684909743587e-49
# Wilcoxon test between Supervised and SimCLR: p-value = 1.5017221117861618e-38
# Wilcoxon test between Supervised and SupCon: p-value = 0.43168905495068843
# Post-hoc Wilcoxon tests for trial 8:
# Wilcoxon test between SimCLR and SupCon: p-value = 2.578295581421659e-46
# Wilcoxon test between Supervised and SimCLR: p-value = 1.6683193637839865e-33
# Wilcoxon test between Supervised and SupCon: p-value = 0.16971854248952623
# Post-hoc Wilcoxon tests for trial 9:
# Wilcoxon test between SimCLR and SupCon: p-value = 2.118783512138459e-48
# Wilcoxon test between Supervised and SimCLR: p-value = 1.0878551331829465e-37
# Wilcoxon test between Supervised and SupCon: p-value = 0.8817821233547263
# Post-hoc Wilcoxon tests for trial 10:
# Wilcoxon test between SimCLR and SupCon: p-value = 6.133936318042028e-52
# Wilcoxon test between Supervised and SimCLR: p-value = 5.883282174249329e-44
# Wilcoxon test between Supervised and SupCon: p-value = 0.23472480249417949

# %% [markdown]
# ## Intra Vs Cross

# %%
reload(process_results)
file_paths = [
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SimCLR_results/EEGNet_1CLS_50Folfd_evaluation_results.txt'),
    os.path.join(scripts_folder, 'CrossEvaluation/BCI Results/SimCLR_results/EEGNet_1CLS_INTRA_50Folfd_evaluation_results.txt'),
]
process_results.plot_intra_cross(file_paths, 'EEGNet', retraining_chars=[1, 5, 10, 25, 40, 85], dataset='BCI')
# Out:
# Analysing data from 1 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5082.0, p_value = 0.8414293317041498)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5428.0, p_value = 0.2949675965840721)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5318.5, p_value = 0.4364767844509946)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5433.5, p_value = 0.28946937929839334)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5392.0, p_value = 0.3383489117675701)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5541.0, p_value = 0.1862216240246869)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5490.5, p_value = 0.23087540766758896)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5446.5, p_value = 0.27554970599156836)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5531.0, p_value = 0.19469329222237097)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5391.5, p_value = 0.33915229125976065)
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5435.0, p_value = 0.28819958483755337)
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5503.5, p_value = 0.21888558209302456)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5497.0, p_value = 0.22488743503790554)
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5503.0, p_value = 0.21937985315077635)
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5412.5, p_value = 0.31392083639856694)
# 0 upper right
# Analysing data from 5 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5154.0, p_value = 0.7072127822266034)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5001.0, p_value = 0.9990239996410054)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5089.0, p_value = 0.8286772906295806)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5229.0, p_value = 0.5764045641880589)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5277.0, p_value = 0.4990558116921432)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5130.0, p_value = 0.751581967707437)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5321.5, p_value = 0.4326824049924636)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5557.5, p_value = 0.17338760587347157)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5563.5, p_value = 0.16879220889899138)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5511.0, p_value = 0.21210421225101295)
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5459.5, p_value = 0.2619151199898194)
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5439.0, p_value = 0.28379347783337017)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5370.5, p_value = 0.3657826736395523)
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5348.0, p_value = 0.39562715736612863)
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5378.5, p_value = 0.3554787752062616)
# 1 upper right
# Analysing data from 10 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5205.0, p_value = 0.6167754566750421)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5002.5, p_value = 0.9960959617968559)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5394.0, p_value = 0.33580836814149073)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5368.5, p_value = 0.36815976614093915)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5237.5, p_value = 0.5622420680848601)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5447.5, p_value = 0.27437499193344717)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5511.5, p_value = 0.21154457060402698)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5597.0, p_value = 0.1447055725485688)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5753.5, p_value = 0.06559183851983812)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5861.0, p_value = 0.03534520631847372)
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5490.5, p_value = 0.2307121324925746)
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5372.0, p_value = 0.3636365447821889)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5048.0, p_value = 0.907510356453119)
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5058.5, p_value = 0.8872061251686096)
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5260.5, p_value = 0.524847521459794)
# 2 lower right
# Analysing data from 25 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5146.5, p_value = 0.7207912366226225)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4928.0, p_value = 0.8610870490898119)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5739.5, p_value = 0.07038715575008114)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5282.0, p_value = 0.49080046792773724)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4676.0, p_value = 0.42840251046434463)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5171.0, p_value = 0.6764287063180812)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5131.5, p_value = 0.7484985306460857)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5626.0, p_value = 0.1258373709753664)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5742.5, p_value = 0.06927871958974025)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5376.5, p_value = 0.357064538754592)
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4409.5, p_value = 0.14854963251214723)
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4359.5, p_value = 0.11674285357024952)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4066.5, p_value = 0.022242403763197346)
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4078.0, p_value = 0.023930614279127488)
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4169.5, p_value = 0.04180496145430994)
# 3 lower right
# Analysing data from 40 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4559.0, p_value = 0.2809916349700865)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4711.5, p_value = 0.48043260171644075)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5532.0, p_value = 0.19322483809258617)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5121.0, p_value = 0.7680889439088013)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5179.0, p_value = 0.6621184669403373)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5103.5, p_value = 0.8009039437951817)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5339.5, p_value = 0.4060819925562813)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5660.5, p_value = 0.10597604118270004)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5766.5, p_value = 0.060623355741455755)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 5726.5, p_value = 0.0751273506586724)
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4606.0, p_value = 0.3346696613966429)
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4749.0, p_value = 0.5392346955975372)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4234.0, p_value = 0.06027447741272823)
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4461.5, p_value = 0.18682230837742952)
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4570.5, p_value = 0.2926071161029554)
# 4 lower right
# Analysing data from 85 Retraining Chars
#
# N Trials -> 1
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 3110.5, p_value = 3.560576633539655e-06)
#
# N Trials -> 2
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4307.5, p_value = 0.08938339110889804)
#
# N Trials -> 3
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 6491.0, p_value = 0.0002572474443950962)
#
# N Trials -> 4
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 4220.0, p_value = 0.0552661564566612)
#
# N Trials -> 5
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 6854.5, p_value = 5.366236122829299e-06)
#
# N Trials -> 6
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5142.0, p_value = 0.7282656475149694)
#
# N Trials -> 7
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5426.0, p_value = 0.2953214634135407)
#
# N Trials -> 8
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5403.0, p_value = 0.3224778431849794)
#
# N Trials -> 9
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 6104.5, p_value = 0.006594396657701525)
#
# N Trials -> 10
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 5825.0, p_value = 0.04267898913750296)
#
# N Trials -> 11
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 3799.0, p_value = 0.0031625859876064626)
#
# N Trials -> 12
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 3504.5, p_value = 0.0002376518293013077)
#
# N Trials -> 13
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - False
#
# Mann Whitney U Test results: (F-stat = 3598.0, p_value = 0.0005311545936715999)
#
# N Trials -> 14
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 4941.5, p_value = 0.8841941489263401)
#
# N Trials -> 15
#
# Is data Normally Distributed? - False
# Is Variance Homogeneous? - True
#
# Mann Whitney U Test results: (F-stat = 3053.0, p_value = 1.6602019700006134e-06)
# 5 lower right
